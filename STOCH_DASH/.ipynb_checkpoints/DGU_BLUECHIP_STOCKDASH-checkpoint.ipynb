# %% [markdown]
# # <center>동국블루칩 포트폴리오 최적화 서비스</center>
# ---

# %% [markdown]
# #### 예측 성능을 보여드리기 위하여 현재 시점을 2020/12/18로 가정하였습니다.
# #### 따라서 위 시점 기준으로 3개월 이후의 주가를 예측하실 수 있습니다.

# %%
import matplotlib
from matplotlib import cbook
#%matplotlib tk
#matplotlib.use( 'Agg' )

import numpy as np
import pandas as pd
from mpldatacursor import datacursor

from numpy import array
#from permetrics.regression import Metrics

import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from matplotlib import style

import ipywidgets as widgets
from ipywidgets import Layout

from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib.image as img

import sys
mod = sys.modules[__name__]

# %%
font_name = font_manager.FontProperties(fname=".fonts/malgunsl.ttf").get_name()
rc('font',family=font_name)
#style.use('ggplot')

# %%
predict_A000100=pd.read_csv("LGBM예측/A000100_prediction_REAL1.csv")
predict_A000120=pd.read_csv("엔비츠예측/A000120n_beats_prediction_(3200, 800).csv")
predict_A000270=pd.read_csv("LGBM예측/A000270_prediction_REAL1.csv")
predict_A000660=pd.read_csv("엔비츠예측/A000660n_beats_prediction_(3200, 800).csv")
predict_A000720=pd.read_csv("LGBM예측/A000720_prediction_REAL1.csv")
predict_A000810=pd.read_csv("LGBM예측/A000810_prediction_REAL1.csv")
predict_A002790=pd.read_csv("LGBM예측/A002790_prediction_REAL1.csv")
predict_A003410=pd.read_csv("엔비츠예측/A003410n_beats_prediction_(3200, 800).csv")
predict_A003490=pd.read_csv("LGBM예측/A003490_prediction_REAL1.csv")
predict_A003550=pd.read_csv("엔비츠예측/A003550n_beats_prediction_(3200, 800).csv")
predict_A003670=pd.read_csv("LGBM예측/A003670_prediction_REAL1.csv")
predict_A004020=pd.read_csv("LGBM예측/A004020_prediction_REAL1.csv")
predict_A004990=pd.read_csv("LGBM예측/A004990_prediction_REAL1.csv")
predict_A005380=pd.read_csv("엔비츠예측/A005380n_beats_prediction_(3200, 800).csv")
predict_A005387=pd.read_csv("LGBM예측/A005387_prediction_REAL1.csv")
predict_A005490=pd.read_csv("LGBM예측/A005490_prediction_REAL1.csv")
predict_A005830=pd.read_csv("엔비츠예측/A005830n_beats_prediction_(3200, 800).csv")
predict_A005930=pd.read_csv("엔비츠예측/A005930n_beats_prediction_(3200, 800).csv")
predict_A005935=pd.read_csv("엔비츠예측/A005935n_beats_prediction_(3200, 800).csv")
predict_A005940=pd.read_csv("LGBM예측/A005940_prediction_REAL1.csv")
predict_A006280=pd.read_csv("엔비츠예측/A006280n_beats_prediction_(3200, 800).csv")
predict_A006360=pd.read_csv("LGBM예측/A006360_prediction_REAL1.csv")
predict_A006400=pd.read_csv("엔비츠예측/A006400n_beats_prediction_(3200, 800).csv")
predict_A006800=pd.read_csv("엔비츠예측/A006800n_beats_prediction_(3200, 800).csv")
predict_A007070=pd.read_csv("엔비츠예측/A007070n_beats_prediction_(3200, 800).csv")
predict_A008560=pd.read_csv("엔비츠예측/A008560n_beats_prediction_(3200, 800).csv")
predict_A008770=pd.read_csv("엔비츠예측/A008770n_beats_prediction_(3200, 800).csv")
predict_A008930=pd.read_csv("엔비츠예측/A008930n_beats_prediction_(3200, 800).csv")
predict_A009150=pd.read_csv("엔비츠예측/A009150n_beats_prediction_(3200, 800).csv")
predict_A009540=pd.read_csv("엔비츠예측/A009540n_beats_prediction_(3200, 800).csv")
predict_A009830=pd.read_csv("엔비츠예측/A009830n_beats_prediction_(3200, 800).csv")
predict_A010130=pd.read_csv("LGBM예측/A010130_prediction_REAL1.csv")
predict_A010140=pd.read_csv("엔비츠예측/A010140n_beats_prediction_(3200, 800).csv")
predict_A010950=pd.read_csv("엔비츠예측/A010950n_beats_prediction_(3200, 800).csv")
predict_A011070=pd.read_csv("LGBM예측/A011070_prediction_REAL1.csv")
predict_A011170=pd.read_csv("엔비츠예측/A011170n_beats_prediction_(3200, 800).csv")
predict_A011200=pd.read_csv("LGBM예측/A011200_prediction_REAL1.csv")
predict_A011780=pd.read_csv("엔비츠예측/A011780n_beats_prediction_(3200, 800).csv")
predict_A011790=pd.read_csv("LGBM예측/A011790_prediction_REAL1.csv")
predict_A012330=pd.read_csv("LGBM예측/A012330_prediction_REAL1.csv")
predict_A012510=pd.read_csv("LGBM예측/A012510_prediction_REAL1.csv")
predict_A012750=pd.read_csv("엔비츠예측/A012750n_beats_prediction_(3200, 800).csv")
predict_A015760=pd.read_csv("LGBM예측/A015760_prediction_REAL1.csv")
predict_A016360=pd.read_csv("엔비츠예측/A016360n_beats_prediction_(3200, 800).csv")
predict_A017670=pd.read_csv("엔비츠예측/A017670n_beats_prediction_(3200, 800).csv")
predict_A018260=pd.read_csv("LGBM예측/A018260_prediction_REAL1.csv")
predict_A018880=pd.read_csv("엔비츠예측/A018880n_beats_prediction_(3200, 800).csv")
predict_A021240=pd.read_csv("LGBM예측/A021240_prediction_REAL1.csv")
predict_A023530=pd.read_csv("LGBM예측/A023530_prediction_REAL1.csv")
predict_A024110=pd.read_csv("LGBM예측/A024110_prediction_REAL1.csv")
predict_A026960=pd.read_csv("엔비츠예측/A026960n_beats_prediction_(3200, 800).csv")
predict_A028260=pd.read_csv("엔비츠예측/A028260n_beats_prediction_(3200, 800).csv")
predict_A028670=pd.read_csv("LGBM예측/A028670_prediction_REAL1.csv")
predict_A029780=pd.read_csv("LGBM예측/A029780_prediction_REAL1.csv")
predict_A030200=pd.read_csv("LGBM예측/A030200_prediction_REAL1.csv")
predict_A032640=pd.read_csv("엔비츠예측/A032640n_beats_prediction_(3200, 800).csv")
predict_A032830=pd.read_csv("엔비츠예측/A032830n_beats_prediction_(3200, 800).csv")
predict_A033780=pd.read_csv("LGBM예측/A033780_prediction_REAL1.csv")
predict_A034020=pd.read_csv("LGBM예측/A034020_prediction_REAL1.csv")
predict_A034220=pd.read_csv("엔비츠예측/A034220n_beats_prediction_(3200, 800).csv")
predict_A034730=pd.read_csv("LGBM예측/A034730_prediction_REAL1.csv")
predict_A035250=pd.read_csv("엔비츠예측/A035250n_beats_prediction_(3200, 800).csv")
predict_A035420=pd.read_csv("LGBM예측/A035420_prediction_REAL1.csv")
predict_A035720=pd.read_csv("LGBM예측/A035720_prediction_REAL1.csv")
predict_A036460=pd.read_csv("LGBM예측/A036460_prediction_REAL1.csv")
predict_A036570=pd.read_csv("엔비츠예측/A036570n_beats_prediction_(3200, 800).csv")
predict_A039490=pd.read_csv("엔비츠예측/A039490n_beats_prediction_(3200, 800).csv")
predict_A047810=pd.read_csv("엔비츠예측/A047810n_beats_prediction_(3200, 800).csv")
predict_A051900=pd.read_csv("LGBM예측/A051900_prediction_REAL1.csv")
predict_A051910=pd.read_csv("LGBM예측/A051910_prediction_REAL1.csv")
predict_A055550=pd.read_csv("LGBM예측/A055550_prediction_REAL1.csv")
predict_A066570=pd.read_csv("LGBM예측/A066570_prediction_REAL1.csv")
predict_A068270=pd.read_csv("엔비츠예측/A068270n_beats_prediction_(3200, 800).csv")
predict_A071050=pd.read_csv("엔비츠예측/A071050n_beats_prediction_(3200, 800).csv")
predict_A078930=pd.read_csv("LGBM예측/A078930_prediction_REAL1.csv")
predict_A086280=pd.read_csv("LGBM예측/A086280_prediction_REAL1.csv")
predict_A086790=pd.read_csv("LGBM예측/A086790_prediction_REAL1.csv")
predict_A090430=pd.read_csv("엔비츠예측/A090430n_beats_prediction_(3200, 800).csv")
predict_A096770=pd.read_csv("엔비츠예측/A096770n_beats_prediction_(3200, 800).csv")
predict_A097950=pd.read_csv("엔비츠예측/A097950n_beats_prediction_(3200, 800).csv")
predict_A105560=pd.read_csv("LGBM예측/A105560_prediction_REAL1.csv")
predict_A128940=pd.read_csv("엔비츠예측/A128940n_beats_prediction_(3200, 800).csv")
predict_A139480=pd.read_csv("엔비츠예측/A139480n_beats_prediction_(3200, 800).csv")
predict_A161390=pd.read_csv("엔비츠예측/A161390n_beats_prediction_(3200, 800).csv")
predict_A180640=pd.read_csv("LGBM예측/A180640_prediction_REAL1.csv")
predict_A204320=pd.read_csv("LGBM예측/A204320_prediction_REAL1.csv")

# %%
predict_A000100.Date=pd.to_datetime(predict_A000100.Date,format='%Y-%m-%d %H:%M:%S')
predict_A000120.Date=pd.to_datetime(predict_A000120.Date,format='%Y-%m-%d %H:%M:%S')
predict_A000270.Date=pd.to_datetime(predict_A000270.Date,format='%Y-%m-%d %H:%M:%S')
predict_A000660.Date=pd.to_datetime(predict_A000660.Date,format='%Y-%m-%d %H:%M:%S')
predict_A000720.Date=pd.to_datetime(predict_A000720.Date,format='%Y-%m-%d %H:%M:%S')
predict_A000810.Date=pd.to_datetime(predict_A000810.Date,format='%Y-%m-%d %H:%M:%S')
predict_A002790.Date=pd.to_datetime(predict_A002790.Date,format='%Y-%m-%d %H:%M:%S')
predict_A003410.Date=pd.to_datetime(predict_A003410.Date,format='%Y-%m-%d %H:%M:%S')
predict_A003490.Date=pd.to_datetime(predict_A003490.Date,format='%Y-%m-%d %H:%M:%S')
predict_A003550.Date=pd.to_datetime(predict_A003550.Date,format='%Y-%m-%d %H:%M:%S')
predict_A003670.Date=pd.to_datetime(predict_A003670.Date,format='%Y-%m-%d %H:%M:%S')
predict_A004020.Date=pd.to_datetime(predict_A004020.Date,format='%Y-%m-%d %H:%M:%S')
predict_A004990.Date=pd.to_datetime(predict_A004990.Date,format='%Y-%m-%d %H:%M:%S')
predict_A005380.Date=pd.to_datetime(predict_A005380.Date,format='%Y-%m-%d %H:%M:%S')
predict_A005387.Date=pd.to_datetime(predict_A005387.Date,format='%Y-%m-%d %H:%M:%S')
predict_A005490.Date=pd.to_datetime(predict_A005490.Date,format='%Y-%m-%d %H:%M:%S')
predict_A005830.Date=pd.to_datetime(predict_A005830.Date,format='%Y-%m-%d %H:%M:%S')
predict_A005930.Date=pd.to_datetime(predict_A005930.Date,format='%Y-%m-%d %H:%M:%S')
predict_A005935.Date=pd.to_datetime(predict_A005935.Date,format='%Y-%m-%d %H:%M:%S')
predict_A005940.Date=pd.to_datetime(predict_A005940.Date,format='%Y-%m-%d %H:%M:%S')
predict_A006280.Date=pd.to_datetime(predict_A006280.Date,format='%Y-%m-%d %H:%M:%S')
predict_A006360.Date=pd.to_datetime(predict_A006360.Date,format='%Y-%m-%d %H:%M:%S')
predict_A006400.Date=pd.to_datetime(predict_A006400.Date,format='%Y-%m-%d %H:%M:%S')
predict_A006800.Date=pd.to_datetime(predict_A006800.Date,format='%Y-%m-%d %H:%M:%S')
predict_A007070.Date=pd.to_datetime(predict_A007070.Date,format='%Y-%m-%d %H:%M:%S')
predict_A008560.Date=pd.to_datetime(predict_A008560.Date,format='%Y-%m-%d %H:%M:%S')
predict_A008770.Date=pd.to_datetime(predict_A008770.Date,format='%Y-%m-%d %H:%M:%S')
predict_A008930.Date=pd.to_datetime(predict_A008930.Date,format='%Y-%m-%d %H:%M:%S')
predict_A009150.Date=pd.to_datetime(predict_A009150.Date,format='%Y-%m-%d %H:%M:%S')
predict_A009540.Date=pd.to_datetime(predict_A009540.Date,format='%Y-%m-%d %H:%M:%S')
predict_A009830.Date=pd.to_datetime(predict_A009830.Date,format='%Y-%m-%d %H:%M:%S')
predict_A010130.Date=pd.to_datetime(predict_A010130.Date,format='%Y-%m-%d %H:%M:%S')
predict_A010140.Date=pd.to_datetime(predict_A010140.Date,format='%Y-%m-%d %H:%M:%S')
predict_A010950.Date=pd.to_datetime(predict_A010950.Date,format='%Y-%m-%d %H:%M:%S')
predict_A011070.Date=pd.to_datetime(predict_A011070.Date,format='%Y-%m-%d %H:%M:%S')
predict_A011170.Date=pd.to_datetime(predict_A011170.Date,format='%Y-%m-%d %H:%M:%S')
predict_A011200.Date=pd.to_datetime(predict_A011200.Date,format='%Y-%m-%d %H:%M:%S')
predict_A011780.Date=pd.to_datetime(predict_A011780.Date,format='%Y-%m-%d %H:%M:%S')
predict_A011790.Date=pd.to_datetime(predict_A011790.Date,format='%Y-%m-%d %H:%M:%S')
predict_A012330.Date=pd.to_datetime(predict_A012330.Date,format='%Y-%m-%d %H:%M:%S')
predict_A012510.Date=pd.to_datetime(predict_A012510.Date,format='%Y-%m-%d %H:%M:%S')
predict_A012750.Date=pd.to_datetime(predict_A012750.Date,format='%Y-%m-%d %H:%M:%S')
predict_A015760.Date=pd.to_datetime(predict_A015760.Date,format='%Y-%m-%d %H:%M:%S')
predict_A016360.Date=pd.to_datetime(predict_A016360.Date,format='%Y-%m-%d %H:%M:%S')
predict_A017670.Date=pd.to_datetime(predict_A017670.Date,format='%Y-%m-%d %H:%M:%S')
predict_A018260.Date=pd.to_datetime(predict_A018260.Date,format='%Y-%m-%d %H:%M:%S')
predict_A018880.Date=pd.to_datetime(predict_A018880.Date,format='%Y-%m-%d %H:%M:%S')
predict_A021240.Date=pd.to_datetime(predict_A021240.Date,format='%Y-%m-%d %H:%M:%S')
predict_A023530.Date=pd.to_datetime(predict_A023530.Date,format='%Y-%m-%d %H:%M:%S')
predict_A024110.Date=pd.to_datetime(predict_A024110.Date,format='%Y-%m-%d %H:%M:%S')
predict_A026960.Date=pd.to_datetime(predict_A026960.Date,format='%Y-%m-%d %H:%M:%S')
predict_A028260.Date=pd.to_datetime(predict_A028260.Date,format='%Y-%m-%d %H:%M:%S')
predict_A028670.Date=pd.to_datetime(predict_A028670.Date,format='%Y-%m-%d %H:%M:%S')
predict_A029780.Date=pd.to_datetime(predict_A029780.Date,format='%Y-%m-%d %H:%M:%S')
predict_A030200.Date=pd.to_datetime(predict_A030200.Date,format='%Y-%m-%d %H:%M:%S')
predict_A032640.Date=pd.to_datetime(predict_A032640.Date,format='%Y-%m-%d %H:%M:%S')
predict_A032830.Date=pd.to_datetime(predict_A032830.Date,format='%Y-%m-%d %H:%M:%S')
predict_A033780.Date=pd.to_datetime(predict_A033780.Date,format='%Y-%m-%d %H:%M:%S')
predict_A034020.Date=pd.to_datetime(predict_A034020.Date,format='%Y-%m-%d %H:%M:%S')
predict_A034220.Date=pd.to_datetime(predict_A034220.Date,format='%Y-%m-%d %H:%M:%S')
predict_A034730.Date=pd.to_datetime(predict_A034730.Date,format='%Y-%m-%d %H:%M:%S')
predict_A035250.Date=pd.to_datetime(predict_A035250.Date,format='%Y-%m-%d %H:%M:%S')
predict_A035420.Date=pd.to_datetime(predict_A035420.Date,format='%Y-%m-%d %H:%M:%S')
predict_A035720.Date=pd.to_datetime(predict_A035720.Date,format='%Y-%m-%d %H:%M:%S')
predict_A036460.Date=pd.to_datetime(predict_A036460.Date,format='%Y-%m-%d %H:%M:%S')
predict_A036570.Date=pd.to_datetime(predict_A036570.Date,format='%Y-%m-%d %H:%M:%S')
predict_A039490.Date=pd.to_datetime(predict_A039490.Date,format='%Y-%m-%d %H:%M:%S')
predict_A047810.Date=pd.to_datetime(predict_A047810.Date,format='%Y-%m-%d %H:%M:%S')
predict_A051900.Date=pd.to_datetime(predict_A051900.Date,format='%Y-%m-%d %H:%M:%S')
predict_A051910.Date=pd.to_datetime(predict_A051910.Date,format='%Y-%m-%d %H:%M:%S')
predict_A055550.Date=pd.to_datetime(predict_A055550.Date,format='%Y-%m-%d %H:%M:%S')
predict_A066570.Date=pd.to_datetime(predict_A066570.Date,format='%Y-%m-%d %H:%M:%S')
predict_A068270.Date=pd.to_datetime(predict_A068270.Date,format='%Y-%m-%d %H:%M:%S')
predict_A071050.Date=pd.to_datetime(predict_A071050.Date,format='%Y-%m-%d %H:%M:%S')
predict_A078930.Date=pd.to_datetime(predict_A078930.Date,format='%Y-%m-%d %H:%M:%S')
predict_A086280.Date=pd.to_datetime(predict_A086280.Date,format='%Y-%m-%d %H:%M:%S')
predict_A086790.Date=pd.to_datetime(predict_A086790.Date,format='%Y-%m-%d %H:%M:%S')
predict_A090430.Date=pd.to_datetime(predict_A090430.Date,format='%Y-%m-%d %H:%M:%S')
predict_A096770.Date=pd.to_datetime(predict_A096770.Date,format='%Y-%m-%d %H:%M:%S')
predict_A097950.Date=pd.to_datetime(predict_A097950.Date,format='%Y-%m-%d %H:%M:%S')
predict_A105560.Date=pd.to_datetime(predict_A105560.Date,format='%Y-%m-%d %H:%M:%S')
predict_A128940.Date=pd.to_datetime(predict_A128940.Date,format='%Y-%m-%d %H:%M:%S')
predict_A139480.Date=pd.to_datetime(predict_A139480.Date,format='%Y-%m-%d %H:%M:%S')
predict_A161390.Date=pd.to_datetime(predict_A161390.Date,format='%Y-%m-%d %H:%M:%S')
predict_A180640.Date=pd.to_datetime(predict_A180640.Date,format='%Y-%m-%d %H:%M:%S')
predict_A204320.Date=pd.to_datetime(predict_A204320.Date,format='%Y-%m-%d %H:%M:%S')

# %%
predict_A000100['예측 시가']=predict_A000100['예측 시가'].round()
predict_A000120['예측 시가']=predict_A000120['예측 시가'].round()
predict_A000270['예측 시가']=predict_A000270['예측 시가'].round()
predict_A000660['예측 시가']=predict_A000660['예측 시가'].round()
predict_A000720['예측 시가']=predict_A000720['예측 시가'].round()
predict_A000810['예측 시가']=predict_A000810['예측 시가'].round()
predict_A002790['예측 시가']=predict_A002790['예측 시가'].round()
predict_A003410['예측 시가']=predict_A003410['예측 시가'].round()
predict_A003490['예측 시가']=predict_A003490['예측 시가'].round()
predict_A003550['예측 시가']=predict_A003550['예측 시가'].round()
predict_A003670['예측 시가']=predict_A003670['예측 시가'].round()
predict_A004020['예측 시가']=predict_A004020['예측 시가'].round()
predict_A004990['예측 시가']=predict_A004990['예측 시가'].round()
predict_A005380['예측 시가']=predict_A005380['예측 시가'].round()
predict_A005387['예측 시가']=predict_A005387['예측 시가'].round()
predict_A005490['예측 시가']=predict_A005490['예측 시가'].round()
predict_A005830['예측 시가']=predict_A005830['예측 시가'].round()
predict_A005930['예측 시가']=predict_A005930['예측 시가'].round()
predict_A005935['예측 시가']=predict_A005935['예측 시가'].round()
predict_A005940['예측 시가']=predict_A005940['예측 시가'].round()
predict_A006280['예측 시가']=predict_A006280['예측 시가'].round()
predict_A006360['예측 시가']=predict_A006360['예측 시가'].round()
predict_A006400['예측 시가']=predict_A006400['예측 시가'].round()
predict_A006800['예측 시가']=predict_A006800['예측 시가'].round()
predict_A007070['예측 시가']=predict_A007070['예측 시가'].round()
predict_A008560['예측 시가']=predict_A008560['예측 시가'].round()
predict_A008770['예측 시가']=predict_A008770['예측 시가'].round()
predict_A008930['예측 시가']=predict_A008930['예측 시가'].round()
predict_A009150['예측 시가']=predict_A009150['예측 시가'].round()
predict_A009540['예측 시가']=predict_A009540['예측 시가'].round()
predict_A009830['예측 시가']=predict_A009830['예측 시가'].round()
predict_A010130['예측 시가']=predict_A010130['예측 시가'].round()
predict_A010140['예측 시가']=predict_A010140['예측 시가'].round()
predict_A010950['예측 시가']=predict_A010950['예측 시가'].round()
predict_A011070['예측 시가']=predict_A011070['예측 시가'].round()
predict_A011170['예측 시가']=predict_A011170['예측 시가'].round()
predict_A011200['예측 시가']=predict_A011200['예측 시가'].round()
predict_A011780['예측 시가']=predict_A011780['예측 시가'].round()
predict_A011790['예측 시가']=predict_A011790['예측 시가'].round()
predict_A012330['예측 시가']=predict_A012330['예측 시가'].round()
predict_A012510['예측 시가']=predict_A012510['예측 시가'].round()
predict_A012750['예측 시가']=predict_A012750['예측 시가'].round()
predict_A015760['예측 시가']=predict_A015760['예측 시가'].round()
predict_A016360['예측 시가']=predict_A016360['예측 시가'].round()
predict_A017670['예측 시가']=predict_A017670['예측 시가'].round()
predict_A018260['예측 시가']=predict_A018260['예측 시가'].round()
predict_A018880['예측 시가']=predict_A018880['예측 시가'].round()
predict_A021240['예측 시가']=predict_A021240['예측 시가'].round()
predict_A023530['예측 시가']=predict_A023530['예측 시가'].round()
predict_A024110['예측 시가']=predict_A024110['예측 시가'].round()
predict_A026960['예측 시가']=predict_A026960['예측 시가'].round()
predict_A028260['예측 시가']=predict_A028260['예측 시가'].round()
predict_A028670['예측 시가']=predict_A028670['예측 시가'].round()
predict_A029780['예측 시가']=predict_A029780['예측 시가'].round()
predict_A030200['예측 시가']=predict_A030200['예측 시가'].round()
predict_A032640['예측 시가']=predict_A032640['예측 시가'].round()
predict_A032830['예측 시가']=predict_A032830['예측 시가'].round()
predict_A033780['예측 시가']=predict_A033780['예측 시가'].round()
predict_A034020['예측 시가']=predict_A034020['예측 시가'].round()
predict_A034220['예측 시가']=predict_A034220['예측 시가'].round()
predict_A034730['예측 시가']=predict_A034730['예측 시가'].round()
predict_A035250['예측 시가']=predict_A035250['예측 시가'].round()
predict_A035420['예측 시가']=predict_A035420['예측 시가'].round()
predict_A035720['예측 시가']=predict_A035720['예측 시가'].round()
predict_A036460['예측 시가']=predict_A036460['예측 시가'].round()
predict_A036570['예측 시가']=predict_A036570['예측 시가'].round()
predict_A039490['예측 시가']=predict_A039490['예측 시가'].round()
predict_A047810['예측 시가']=predict_A047810['예측 시가'].round()
predict_A051900['예측 시가']=predict_A051900['예측 시가'].round()
predict_A051910['예측 시가']=predict_A051910['예측 시가'].round()
predict_A055550['예측 시가']=predict_A055550['예측 시가'].round()
predict_A066570['예측 시가']=predict_A066570['예측 시가'].round()
predict_A068270['예측 시가']=predict_A068270['예측 시가'].round()
predict_A071050['예측 시가']=predict_A071050['예측 시가'].round()
predict_A078930['예측 시가']=predict_A078930['예측 시가'].round()
predict_A086280['예측 시가']=predict_A086280['예측 시가'].round()
predict_A086790['예측 시가']=predict_A086790['예측 시가'].round()
predict_A090430['예측 시가']=predict_A090430['예측 시가'].round()
predict_A096770['예측 시가']=predict_A096770['예측 시가'].round()
predict_A097950['예측 시가']=predict_A097950['예측 시가'].round()
predict_A105560['예측 시가']=predict_A105560['예측 시가'].round()
predict_A128940['예측 시가']=predict_A128940['예측 시가'].round()
predict_A139480['예측 시가']=predict_A139480['예측 시가'].round()
predict_A161390['예측 시가']=predict_A161390['예측 시가'].round()
predict_A180640['예측 시가']=predict_A180640['예측 시가'].round()
predict_A204320['예측 시가']=predict_A204320['예측 시가'].round()

# %%
csv_list=["A000100",
"A000120",
"A000270",
"A000660",
"A000720",
"A000810",
"A002790",
"A003410",
"A003490",
"A003550",
"A003670",
"A004020",
"A004990",
"A005380",
"A005387",
"A005490",
"A005830",
"A005930",
"A005935",
"A005940",
"A006280",
"A006360",
"A006400",
"A006800",
"A007070",
"A008560",
"A008770",
"A008930",
"A009150",
"A009540",
"A009830",
"A010130",
"A010140",
"A010950",
"A011070",
"A011170",
"A011200",
"A011780",
"A011790",
"A012330",
"A012510",
"A012750",
"A015760",
"A016360",
"A017670",
"A018260",
"A018880",
"A021240",
"A023530",
"A024110",
"A026960",
"A028260",
"A028670",
"A029780",
"A030200",
"A032640",
"A032830",
"A033780",
"A034020",
"A034220",
"A034730",
"A035250",
"A035420",
"A035720",
"A036460",
"A036570",
"A039490",
"A047810",
"A051900",
"A051910",
"A055550",
"A066570",
"A068270",
"A071050",
"A078930",
"A086280",
"A086790",
"A090430",
"A096770",
"A097950",
"A105560",
"A128940",
"A139480",
"A161390",
"A180640",
"A204320"]

# %%
stock=["유한양행",
"CJ대한통운",
"기아차",
"SK하이닉스",
"현대건설",
"삼성화재",
"아모레G",
"쌍용양회",
"대한항공",
"LG",
"포스코케미칼",
"현대제철",
"롯데지주",
"현대차",
"현대차2우B",
"POSCO",
"DB손해보험",
"삼성전자",
"삼성전자우",
"NH투자증권",
"녹십자",
"GS건설",
"삼성SDI",
"미래에셋대우",
"GS리테일",
"메리츠증권",
"호텔신라",
"한미사이언스",
"삼성전기",
"한국조선해양",
"한화솔루션",
"고려아연",
"삼성중공업",
"S-Oil",
"LG이노텍",
"롯데케미칼",
"HMM",
"금호석유",
"SKC",
"현대모비스",
"더존비즈온",
"에스원",
"한국전력",
"삼성증권",
"SK텔레콤",
"삼성에스디에스",
"한온시스템",
"코웨이",
"롯데쇼핑",
"기업은행",
"동서",
"삼성물산",
"팬오션",
"삼성카드",
"KT",
"LG유플러스",
"삼성생명",
"KT&G",
"두산중공업",
"LG디스플레이",
"SK",
"강원랜드",
"NAVER",
"카카오",
"한국가스공사",
"엔씨소프트",
"키움증권",
"한국항공우주",
"LG생활건강",
"LG화학",
"신한지주",
"LG전자",
"셀트리온",
"한국금융지주",
"GS",
"현대글로비스",
"하나금융지주",
"아모레퍼시픽",
"SK이노베이션",
"CJ제일제당",
"KB금융",
"한미약품",
"이마트",
"한국타이어앤테크놀로지",
"한진칼",
"만도"]
print("\n\n")

# %% [markdown]
# ### 원하는 종목의 주가 예측 그래프를 확인해보세요!

# %%
y_future_predict_A000100=predict_A000100.loc[3170:3963,['예측 시가']]
y_future_predict_A000120=predict_A000120.loc[3200:4000,['예측 시가']]
y_future_predict_A000270=predict_A000270.loc[3170:3963,['예측 시가']]
y_future_predict_A000660=predict_A000660.loc[3200:4000,['예측 시가']]
y_future_predict_A000720=predict_A000720.loc[3170:3963,['예측 시가']]
y_future_predict_A000810=predict_A000810.loc[3170:3963,['예측 시가']]
y_future_predict_A002790=predict_A002790.loc[3170:3963,['예측 시가']]
y_future_predict_A003410=predict_A003410.loc[3200:4000,['예측 시가']]
y_future_predict_A003490=predict_A003490.loc[3170:3963,['예측 시가']]
y_future_predict_A003550=predict_A003550.loc[3200:4000,['예측 시가']]
y_future_predict_A003670=predict_A003670.loc[3170:3963,['예측 시가']]
y_future_predict_A004020=predict_A004020.loc[3170:3963,['예측 시가']]
y_future_predict_A004990=predict_A004990.loc[3170:3963,['예측 시가']]
y_future_predict_A005380=predict_A005380.loc[3200:4000,['예측 시가']]
y_future_predict_A005387=predict_A005387.loc[3170:3963,['예측 시가']]
y_future_predict_A005490=predict_A005490.loc[3170:3963,['예측 시가']]
y_future_predict_A005830=predict_A005830.loc[3200:4000,['예측 시가']]
y_future_predict_A005930=predict_A005930.loc[3200:4000,['예측 시가']]
y_future_predict_A005935=predict_A005935.loc[3200:4000,['예측 시가']]
y_future_predict_A005940=predict_A005940.loc[3170:3963,['예측 시가']]
y_future_predict_A006280=predict_A006280.loc[3200:4000,['예측 시가']]
y_future_predict_A006360=predict_A006360.loc[3170:3963,['예측 시가']]
y_future_predict_A006400=predict_A006400.loc[3200:4000,['예측 시가']]
y_future_predict_A006800=predict_A006800.loc[3200:4000,['예측 시가']]
y_future_predict_A007070=predict_A007070.loc[3200:4000,['예측 시가']]
y_future_predict_A008560=predict_A008560.loc[3200:4000,['예측 시가']]
y_future_predict_A008770=predict_A008770.loc[3200:4000,['예측 시가']]
y_future_predict_A008930=predict_A008930.loc[3200:4000,['예측 시가']]
y_future_predict_A009150=predict_A009150.loc[3200:4000,['예측 시가']]
y_future_predict_A009540=predict_A009540.loc[3200:4000,['예측 시가']]
y_future_predict_A009830=predict_A009830.loc[3200:4000,['예측 시가']]
y_future_predict_A010130=predict_A010130.loc[3170:3963,['예측 시가']]
y_future_predict_A010140=predict_A010140.loc[3200:4000,['예측 시가']]
y_future_predict_A010950=predict_A010950.loc[3200:4000,['예측 시가']]
y_future_predict_A011070=predict_A011070.loc[3170:3963,['예측 시가']]
y_future_predict_A011170=predict_A011170.loc[3200:4000,['예측 시가']]
y_future_predict_A011200=predict_A011200.loc[3170:3963,['예측 시가']]
y_future_predict_A011780=predict_A011780.loc[3200:4000,['예측 시가']]
y_future_predict_A011790=predict_A011790.loc[3170:3963,['예측 시가']]
y_future_predict_A012330=predict_A012330.loc[3170:3963,['예측 시가']]
y_future_predict_A012510=predict_A012510.loc[3170:3963,['예측 시가']]
y_future_predict_A012750=predict_A012750.loc[3200:4000,['예측 시가']]
y_future_predict_A015760=predict_A015760.loc[3170:3963,['예측 시가']]
y_future_predict_A016360=predict_A016360.loc[3200:4000,['예측 시가']]
y_future_predict_A017670=predict_A017670.loc[3200:4000,['예측 시가']]
y_future_predict_A018260=predict_A018260.loc[3170:3963,['예측 시가']]
y_future_predict_A018880=predict_A018880.loc[3200:4000,['예측 시가']]
y_future_predict_A021240=predict_A021240.loc[3170:3963,['예측 시가']]
y_future_predict_A023530=predict_A023530.loc[3170:3963,['예측 시가']]
y_future_predict_A024110=predict_A024110.loc[3170:3963,['예측 시가']]
y_future_predict_A026960=predict_A026960.loc[3200:4000,['예측 시가']]
y_future_predict_A028260=predict_A028260.loc[3200:4000,['예측 시가']]
y_future_predict_A028670=predict_A028670.loc[3170:3963,['예측 시가']]
y_future_predict_A029780=predict_A029780.loc[3170:3963,['예측 시가']]
y_future_predict_A030200=predict_A030200.loc[3170:3963,['예측 시가']]
y_future_predict_A032640=predict_A032640.loc[3200:4000,['예측 시가']]
y_future_predict_A032830=predict_A032830.loc[3200:4000,['예측 시가']]
y_future_predict_A033780=predict_A033780.loc[3170:3963,['예측 시가']]
y_future_predict_A034020=predict_A034020.loc[3170:3963,['예측 시가']]
y_future_predict_A034220=predict_A034220.loc[3200:4000,['예측 시가']]
y_future_predict_A034730=predict_A034730.loc[3170:3963,['예측 시가']]
y_future_predict_A035250=predict_A035250.loc[3200:4000,['예측 시가']]
y_future_predict_A035420=predict_A035420.loc[3170:3963,['예측 시가']]
y_future_predict_A035720=predict_A035720.loc[3170:3963,['예측 시가']]
y_future_predict_A036460=predict_A036460.loc[3170:3963,['예측 시가']]
y_future_predict_A036570=predict_A036570.loc[3200:4000,['예측 시가']]
y_future_predict_A039490=predict_A039490.loc[3200:4000,['예측 시가']]
y_future_predict_A047810=predict_A047810.loc[3200:4000,['예측 시가']]
y_future_predict_A051900=predict_A051900.loc[3170:3963,['예측 시가']]
y_future_predict_A051910=predict_A051910.loc[3170:3963,['예측 시가']]
y_future_predict_A055550=predict_A055550.loc[3170:3963,['예측 시가']]
y_future_predict_A066570=predict_A066570.loc[3170:3963,['예측 시가']]
y_future_predict_A068270=predict_A068270.loc[3200:4000,['예측 시가']]
y_future_predict_A071050=predict_A071050.loc[3200:4000,['예측 시가']]
y_future_predict_A078930=predict_A078930.loc[3170:3963,['예측 시가']]
y_future_predict_A086280=predict_A086280.loc[3170:3963,['예측 시가']]
y_future_predict_A086790=predict_A086790.loc[3170:3963,['예측 시가']]
y_future_predict_A090430=predict_A090430.loc[3200:4000,['예측 시가']]
y_future_predict_A096770=predict_A096770.loc[3200:4000,['예측 시가']]
y_future_predict_A097950=predict_A097950.loc[3200:4000,['예측 시가']]
y_future_predict_A105560=predict_A105560.loc[3170:3963,['예측 시가']]
y_future_predict_A128940=predict_A128940.loc[3200:4000,['예측 시가']]
y_future_predict_A139480=predict_A139480.loc[3200:4000,['예측 시가']]
y_future_predict_A161390=predict_A161390.loc[3200:4000,['예측 시가']]
y_future_predict_A180640=predict_A180640.loc[3170:3963,['예측 시가']]
y_future_predict_A204320=predict_A204320.loc[3170:3963,['예측 시가']]

# %%
y_past_predict_A000100=predict_A000100.loc[0:3170,['실제 시가']]
y_past_predict_A000120=predict_A000120.loc[0:3200,['실제 시가']]
y_past_predict_A000270=predict_A000270.loc[0:3170,['실제 시가']]
y_past_predict_A000660=predict_A000660.loc[0:3200,['실제 시가']]
y_past_predict_A000720=predict_A000720.loc[0:3170,['실제 시가']]
y_past_predict_A000810=predict_A000810.loc[0:3170,['실제 시가']]
y_past_predict_A002790=predict_A002790.loc[0:3170,['실제 시가']]
y_past_predict_A003410=predict_A003410.loc[0:3200,['실제 시가']]
y_past_predict_A003490=predict_A003490.loc[0:3170,['실제 시가']]
y_past_predict_A003550=predict_A003550.loc[0:3200,['실제 시가']]
y_past_predict_A003670=predict_A003670.loc[0:3170,['실제 시가']]
y_past_predict_A004020=predict_A004020.loc[0:3170,['실제 시가']]
y_past_predict_A004990=predict_A004990.loc[0:3170,['실제 시가']]
y_past_predict_A005380=predict_A005380.loc[0:3200,['실제 시가']]
y_past_predict_A005387=predict_A005387.loc[0:3170,['실제 시가']]
y_past_predict_A005490=predict_A005490.loc[0:3170,['실제 시가']]
y_past_predict_A005830=predict_A005830.loc[0:3200,['실제 시가']]
y_past_predict_A005930=predict_A005930.loc[0:3200,['실제 시가']]
y_past_predict_A005935=predict_A005935.loc[0:3200,['실제 시가']]
y_past_predict_A005940=predict_A005940.loc[0:3170,['실제 시가']]
y_past_predict_A006280=predict_A006280.loc[0:3200,['실제 시가']]
y_past_predict_A006360=predict_A006360.loc[0:3170,['실제 시가']]
y_past_predict_A006400=predict_A006400.loc[0:3200,['실제 시가']]
y_past_predict_A006800=predict_A006800.loc[0:3200,['실제 시가']]
y_past_predict_A007070=predict_A007070.loc[0:3200,['실제 시가']]
y_past_predict_A008560=predict_A008560.loc[0:3200,['실제 시가']]
y_past_predict_A008770=predict_A008770.loc[0:3200,['실제 시가']]
y_past_predict_A008930=predict_A008930.loc[0:3200,['실제 시가']]
y_past_predict_A009150=predict_A009150.loc[0:3200,['실제 시가']]
y_past_predict_A009540=predict_A009540.loc[0:3200,['실제 시가']]
y_past_predict_A009830=predict_A009830.loc[0:3200,['실제 시가']]
y_past_predict_A010130=predict_A010130.loc[0:3170,['실제 시가']]
y_past_predict_A010140=predict_A010140.loc[0:3200,['실제 시가']]
y_past_predict_A010950=predict_A010950.loc[0:3200,['실제 시가']]
y_past_predict_A011070=predict_A011070.loc[0:3170,['실제 시가']]
y_past_predict_A011170=predict_A011170.loc[0:3200,['실제 시가']]
y_past_predict_A011200=predict_A011200.loc[0:3170,['실제 시가']]
y_past_predict_A011780=predict_A011780.loc[0:3200,['실제 시가']]
y_past_predict_A011790=predict_A011790.loc[0:3170,['실제 시가']]
y_past_predict_A012330=predict_A012330.loc[0:3170,['실제 시가']]
y_past_predict_A012510=predict_A012510.loc[0:3170,['실제 시가']]
y_past_predict_A012750=predict_A012750.loc[0:3200,['실제 시가']]
y_past_predict_A015760=predict_A015760.loc[0:3170,['실제 시가']]
y_past_predict_A016360=predict_A016360.loc[0:3200,['실제 시가']]
y_past_predict_A017670=predict_A017670.loc[0:3200,['실제 시가']]
y_past_predict_A018260=predict_A018260.loc[0:3170,['실제 시가']]
y_past_predict_A018880=predict_A018880.loc[0:3200,['실제 시가']]
y_past_predict_A021240=predict_A021240.loc[0:3170,['실제 시가']]
y_past_predict_A023530=predict_A023530.loc[0:3170,['실제 시가']]
y_past_predict_A024110=predict_A024110.loc[0:3170,['실제 시가']]
y_past_predict_A026960=predict_A026960.loc[0:3200,['실제 시가']]
y_past_predict_A028260=predict_A028260.loc[0:3200,['실제 시가']]
y_past_predict_A028670=predict_A028670.loc[0:3170,['실제 시가']]
y_past_predict_A029780=predict_A029780.loc[0:3170,['실제 시가']]
y_past_predict_A030200=predict_A030200.loc[0:3170,['실제 시가']]
y_past_predict_A032640=predict_A032640.loc[0:3200,['실제 시가']]
y_past_predict_A032830=predict_A032830.loc[0:3200,['실제 시가']]
y_past_predict_A033780=predict_A033780.loc[0:3170,['실제 시가']]
y_past_predict_A034020=predict_A034020.loc[0:3170,['실제 시가']]
y_past_predict_A034220=predict_A034220.loc[0:3200,['실제 시가']]
y_past_predict_A034730=predict_A034730.loc[0:3170,['실제 시가']]
y_past_predict_A035250=predict_A035250.loc[0:3200,['실제 시가']]
y_past_predict_A035420=predict_A035420.loc[0:3170,['실제 시가']]
y_past_predict_A035720=predict_A035720.loc[0:3170,['실제 시가']]
y_past_predict_A036460=predict_A036460.loc[0:3170,['실제 시가']]
y_past_predict_A036570=predict_A036570.loc[0:3200,['실제 시가']]
y_past_predict_A039490=predict_A039490.loc[0:3200,['실제 시가']]
y_past_predict_A047810=predict_A047810.loc[0:3200,['실제 시가']]
y_past_predict_A051900=predict_A051900.loc[0:3170,['실제 시가']]
y_past_predict_A051910=predict_A051910.loc[0:3170,['실제 시가']]
y_past_predict_A055550=predict_A055550.loc[0:3170,['실제 시가']]
y_past_predict_A066570=predict_A066570.loc[0:3170,['실제 시가']]
y_past_predict_A068270=predict_A068270.loc[0:3200,['실제 시가']]
y_past_predict_A071050=predict_A071050.loc[0:3200,['실제 시가']]
y_past_predict_A078930=predict_A078930.loc[0:3170,['실제 시가']]
y_past_predict_A086280=predict_A086280.loc[0:3170,['실제 시가']]
y_past_predict_A086790=predict_A086790.loc[0:3170,['실제 시가']]
y_past_predict_A090430=predict_A090430.loc[0:3200,['실제 시가']]
y_past_predict_A096770=predict_A096770.loc[0:3200,['실제 시가']]
y_past_predict_A097950=predict_A097950.loc[0:3200,['실제 시가']]
y_past_predict_A105560=predict_A105560.loc[0:3170,['실제 시가']]
y_past_predict_A128940=predict_A128940.loc[0:3200,['실제 시가']]
y_past_predict_A139480=predict_A139480.loc[0:3200,['실제 시가']]
y_past_predict_A161390=predict_A161390.loc[0:3200,['실제 시가']]
y_past_predict_A180640=predict_A180640.loc[0:3170,['실제 시가']]
y_past_predict_A204320=predict_A204320.loc[0:3170,['실제 시가']]

# %%
x_future_predict_A000100=predict_A000100.loc[3170:3963,['Date']]
x_future_predict_A000120=predict_A000120.loc[3200:4000,['Date']]
x_future_predict_A000270=predict_A000270.loc[3170:3963,['Date']]
x_future_predict_A000660=predict_A000660.loc[3200:4000,['Date']]
x_future_predict_A000720=predict_A000720.loc[3170:3963,['Date']]
x_future_predict_A000810=predict_A000810.loc[3170:3963,['Date']]
x_future_predict_A002790=predict_A002790.loc[3170:3963,['Date']]
x_future_predict_A003410=predict_A003410.loc[3200:4000,['Date']]
x_future_predict_A003490=predict_A003490.loc[3170:3963,['Date']]
x_future_predict_A003550=predict_A003550.loc[3200:4000,['Date']]
x_future_predict_A003670=predict_A003670.loc[3170:3963,['Date']]
x_future_predict_A004020=predict_A004020.loc[3170:3963,['Date']]
x_future_predict_A004990=predict_A004990.loc[3170:3963,['Date']]
x_future_predict_A005380=predict_A005380.loc[3200:4000,['Date']]
x_future_predict_A005387=predict_A005387.loc[3170:3963,['Date']]
x_future_predict_A005490=predict_A005490.loc[3170:3963,['Date']]
x_future_predict_A005830=predict_A005830.loc[3200:4000,['Date']]
x_future_predict_A005930=predict_A005930.loc[3200:4000,['Date']]
x_future_predict_A005935=predict_A005935.loc[3200:4000,['Date']]
x_future_predict_A005940=predict_A005940.loc[3170:3963,['Date']]
x_future_predict_A006280=predict_A006280.loc[3200:4000,['Date']]
x_future_predict_A006360=predict_A006360.loc[3170:3963,['Date']]
x_future_predict_A006400=predict_A006400.loc[3200:4000,['Date']]
x_future_predict_A006800=predict_A006800.loc[3200:4000,['Date']]
x_future_predict_A007070=predict_A007070.loc[3200:4000,['Date']]
x_future_predict_A008560=predict_A008560.loc[3200:4000,['Date']]
x_future_predict_A008770=predict_A008770.loc[3200:4000,['Date']]
x_future_predict_A008930=predict_A008930.loc[3200:4000,['Date']]
x_future_predict_A009150=predict_A009150.loc[3200:4000,['Date']]
x_future_predict_A009540=predict_A009540.loc[3200:4000,['Date']]
x_future_predict_A009830=predict_A009830.loc[3200:4000,['Date']]
x_future_predict_A010130=predict_A010130.loc[3170:3963,['Date']]
x_future_predict_A010140=predict_A010140.loc[3200:4000,['Date']]
x_future_predict_A010950=predict_A010950.loc[3200:4000,['Date']]
x_future_predict_A011070=predict_A011070.loc[3170:3963,['Date']]
x_future_predict_A011170=predict_A011170.loc[3200:4000,['Date']]
x_future_predict_A011200=predict_A011200.loc[3170:3963,['Date']]
x_future_predict_A011780=predict_A011780.loc[3200:4000,['Date']]
x_future_predict_A011790=predict_A011790.loc[3170:3963,['Date']]
x_future_predict_A012330=predict_A012330.loc[3170:3963,['Date']]
x_future_predict_A012510=predict_A012510.loc[3170:3963,['Date']]
x_future_predict_A012750=predict_A012750.loc[3200:4000,['Date']]
x_future_predict_A015760=predict_A015760.loc[3170:3963,['Date']]
x_future_predict_A016360=predict_A016360.loc[3200:4000,['Date']]
x_future_predict_A017670=predict_A017670.loc[3200:4000,['Date']]
x_future_predict_A018260=predict_A018260.loc[3170:3963,['Date']]
x_future_predict_A018880=predict_A018880.loc[3200:4000,['Date']]
x_future_predict_A021240=predict_A021240.loc[3170:3963,['Date']]
x_future_predict_A023530=predict_A023530.loc[3170:3963,['Date']]
x_future_predict_A024110=predict_A024110.loc[3170:3963,['Date']]
x_future_predict_A026960=predict_A026960.loc[3200:4000,['Date']]
x_future_predict_A028260=predict_A028260.loc[3200:4000,['Date']]
x_future_predict_A028670=predict_A028670.loc[3170:3963,['Date']]
x_future_predict_A029780=predict_A029780.loc[3170:3963,['Date']]
x_future_predict_A030200=predict_A030200.loc[3170:3963,['Date']]
x_future_predict_A032640=predict_A032640.loc[3200:4000,['Date']]
x_future_predict_A032830=predict_A032830.loc[3200:4000,['Date']]
x_future_predict_A033780=predict_A033780.loc[3170:3963,['Date']]
x_future_predict_A034020=predict_A034020.loc[3170:3963,['Date']]
x_future_predict_A034220=predict_A034220.loc[3200:4000,['Date']]
x_future_predict_A034730=predict_A034730.loc[3170:3963,['Date']]
x_future_predict_A035250=predict_A035250.loc[3200:4000,['Date']]
x_future_predict_A035420=predict_A035420.loc[3170:3963,['Date']]
x_future_predict_A035720=predict_A035720.loc[3170:3963,['Date']]
x_future_predict_A036460=predict_A036460.loc[3170:3963,['Date']]
x_future_predict_A036570=predict_A036570.loc[3200:4000,['Date']]
x_future_predict_A039490=predict_A039490.loc[3200:4000,['Date']]
x_future_predict_A047810=predict_A047810.loc[3200:4000,['Date']]
x_future_predict_A051900=predict_A051900.loc[3170:3963,['Date']]
x_future_predict_A051910=predict_A051910.loc[3170:3963,['Date']]
x_future_predict_A055550=predict_A055550.loc[3170:3963,['Date']]
x_future_predict_A066570=predict_A066570.loc[3170:3963,['Date']]
x_future_predict_A068270=predict_A068270.loc[3200:4000,['Date']]
x_future_predict_A071050=predict_A071050.loc[3200:4000,['Date']]
x_future_predict_A078930=predict_A078930.loc[3170:3963,['Date']]
x_future_predict_A086280=predict_A086280.loc[3170:3963,['Date']]
x_future_predict_A086790=predict_A086790.loc[3170:3963,['Date']]
x_future_predict_A090430=predict_A090430.loc[3200:4000,['Date']]
x_future_predict_A096770=predict_A096770.loc[3200:4000,['Date']]
x_future_predict_A097950=predict_A097950.loc[3200:4000,['Date']]
x_future_predict_A105560=predict_A105560.loc[3170:3963,['Date']]
x_future_predict_A128940=predict_A128940.loc[3200:4000,['Date']]
x_future_predict_A139480=predict_A139480.loc[3200:4000,['Date']]
x_future_predict_A161390=predict_A161390.loc[3200:4000,['Date']]
x_future_predict_A180640=predict_A180640.loc[3170:3963,['Date']]
x_future_predict_A204320=predict_A204320.loc[3170:3963,['Date']]

# %%
def stock_plot(stock):
    if stock=='유한양행': 
        p=plt.plot(x_past_predict_A000100,y_past_predict_A000100,label='유한양행_Open')
        p=plt.plot(x_future_predict_A000100,y_future_predict_A000100,label='유한양행_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='CJ대한통운': 
        p=plt.plot(x_past_predict_A000120,y_past_predict_A000120,label='CJ대한통운_Open')
        p=plt.plot(x_future_predict_A000120,y_future_predict_A000120,label='CJ대한통운_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='기아차': 
        p=plt.plot(x_past_predict_A000270,y_past_predict_A000270,label='기아차_Open')
        p=plt.plot(x_future_predict_A000270,y_future_predict_A000270,label='기아차_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK하이닉스': 
        p=plt.plot(x_past_predict_A000660,y_past_predict_A000660,label='SK하이닉스_Open')
        p=plt.plot(x_future_predict_A000660,y_future_predict_A000660,label='SK하이닉스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대건설': 
        p=plt.plot(x_past_predict_A000720,y_past_predict_A000720,label='현대건설_Open')
        p=plt.plot(x_future_predict_A000720,y_future_predict_A000720,label='현대건설_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성화재': 
        p=plt.plot(x_past_predict_A000810,y_past_predict_A000810,label='삼성화재_Open')
        p=plt.plot(x_future_predict_A000810,y_future_predict_A000810,label='삼성화재_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='아모레G': 
        p=plt.plot(x_past_predict_A002790,y_past_predict_A002790,label='아모레G_Open')
        p=plt.plot(x_future_predict_A002790,y_future_predict_A002790,label='아모레G_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='쌍용양회': 
        p=plt.plot(x_past_predict_A003410,y_past_predict_A003410,label='쌍용양회_Open')
        p=plt.plot(x_future_predict_A003410,y_future_predict_A003410,label='쌍용양회_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='대한항공': 
        p=plt.plot(x_past_predict_A003490,y_past_predict_A003490,label='대한항공_Open')
        p=plt.plot(x_future_predict_A003490,y_future_predict_A003490,label='대한항공_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG': 
        p=plt.plot(x_past_predict_A003550,y_past_predict_A003550,label='LG_Open')
        p=plt.plot(x_future_predict_A003550,y_future_predict_A003550,label='LG_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='포스코케미칼': 
        p=plt.plot(x_past_predict_A003670,y_past_predict_A003670,label='포스코케미칼_Open')
        p=plt.plot(x_future_predict_A003670,y_future_predict_A003670,label='포스코케미칼_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대제철': 
        p=plt.plot(x_past_predict_A004020,y_past_predict_A004020,label='현대제철_Open')
        p=plt.plot(x_future_predict_A004020,y_future_predict_A004020,label='현대제철_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='롯데지주': 
        p=plt.plot(x_past_predict_A004990,y_past_predict_A004990,label='롯데지주_Open')
        p=plt.plot(x_future_predict_A004990,y_future_predict_A004990,label='롯데지주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대차': 
        p=plt.plot(x_past_predict_A005380,y_past_predict_A005380,label='현대차_Open')
        p=plt.plot(x_future_predict_A005380,y_future_predict_A005380,label='현대차_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대차2우B': 
        p=plt.plot(x_past_predict_A005387,y_past_predict_A005387,label='현대차2우B_Open')
        p=plt.plot(x_future_predict_A005387,y_future_predict_A005387,label='현대차2우B_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='POSCO': 
        p=plt.plot(x_past_predict_A005490,y_past_predict_A005490,label='POSCO_Open')
        p=plt.plot(x_future_predict_A005490,y_future_predict_A005490,label='POSCO_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='DB손해보험': 
        p=plt.plot(x_past_predict_A005830,y_past_predict_A005830,label='DB손해보험_Open')
        p=plt.plot(x_future_predict_A005830,y_future_predict_A005830,label='DB손해보험_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성전자': 
        p=plt.plot(x_past_predict_A005930,y_past_predict_A005930,label='삼성전자_Open')
        p=plt.plot(x_future_predict_A005930,y_future_predict_A005930,label='삼성전자_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성전자우': 
        p=plt.plot(x_past_predict_A005935,y_past_predict_A005935,label='삼성전자우_Open')
        p=plt.plot(x_future_predict_A005935,y_future_predict_A005935,label='삼성전자우_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='NH투자증권': 
        p=plt.plot(x_past_predict_A005940,y_past_predict_A005940,label='NH투자증권_Open')
        p=plt.plot(x_future_predict_A005940,y_future_predict_A005940,label='NH투자증권_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='녹십자': 
        p=plt.plot(x_past_predict_A006280,y_past_predict_A006280,label='녹십자_Open')
        p=plt.plot(x_future_predict_A006280,y_future_predict_A006280,label='녹십자_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='GS건설': 
        p=plt.plot(x_past_predict_A006360,y_past_predict_A006360,label='GS건설_Open')
        p=plt.plot(x_future_predict_A006360,y_future_predict_A006360,label='GS건설_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성SDI': 
        p=plt.plot(x_past_predict_A006400,y_past_predict_A006400,label='삼성SDI_Open')
        p=plt.plot(x_future_predict_A006400,y_future_predict_A006400,label='삼성SDI_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='미래에셋대우': 
        p=plt.plot(x_past_predict_A006800,y_past_predict_A006800,label='미래에셋대우_Open')
        p=plt.plot(x_future_predict_A006800,y_future_predict_A006800,label='미래에셋대우_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='GS리테일': 
        p=plt.plot(x_past_predict_A007070,y_past_predict_A007070,label='GS리테일_Open')
        p=plt.plot(x_future_predict_A007070,y_future_predict_A007070,label='GS리테일_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='메리츠증권': 
        p=plt.plot(x_past_predict_A008560,y_past_predict_A008560,label='메리츠증권_Open')
        p=plt.plot(x_future_predict_A008560,y_future_predict_A008560,label='메리츠증권_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='호텔신라': 
        p=plt.plot(x_past_predict_A008770,y_past_predict_A008770,label='호텔신라_Open')
        p=plt.plot(x_future_predict_A008770,y_future_predict_A008770,label='호텔신라_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한미사이언스': 
        p=plt.plot(x_past_predict_A008930,y_past_predict_A008930,label='한미사이언스_Open')
        p=plt.plot(x_future_predict_A008930,y_future_predict_A008930,label='한미사이언스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성전기': 
        p=plt.plot(x_past_predict_A009150,y_past_predict_A009150,label='삼성전기_Open')
        p=plt.plot(x_future_predict_A009150,y_future_predict_A009150,label='삼성전기_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국조선해양': 
        p=plt.plot(x_past_predict_A009540,y_past_predict_A009540,label='한국조선해양_Open')
        p=plt.plot(x_future_predict_A009540,y_future_predict_A009540,label='한국조선해양_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한화솔루션': 
        p=plt.plot(x_past_predict_A009830,y_past_predict_A009830,label='한화솔루션_Open')
        p=plt.plot(x_future_predict_A009830,y_future_predict_A009830,label='한화솔루션_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='고려아연': 
        p=plt.plot(x_past_predict_A010130,y_past_predict_A010130,label='고려아연_Open')
        p=plt.plot(x_future_predict_A010130,y_future_predict_A010130,label='고려아연_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성중공업': 
        p=plt.plot(x_past_predict_A010140,y_past_predict_A010140,label='삼성중공업_Open')
        p=plt.plot(x_future_predict_A010140,y_future_predict_A010140,label='삼성중공업_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='S-Oil': 
        p=plt.plot(x_past_predict_A010950,y_past_predict_A010950,label='S-Oil_Open')
        p=plt.plot(x_future_predict_A010950,y_future_predict_A010950,label='S-Oil_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG이노텍': 
        p=plt.plot(x_past_predict_A011070,y_past_predict_A011070,label='LG이노텍_Open')
        p=plt.plot(x_future_predict_A011070,y_future_predict_A011070,label='LG이노텍_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='롯데케미칼': 
        p=plt.plot(x_past_predict_A011170,y_past_predict_A011170,label='롯데케미칼_Open')
        p=plt.plot(x_future_predict_A011170,y_future_predict_A011170,label='롯데케미칼_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='HMM': 
        p=plt.plot(x_past_predict_A011200,y_past_predict_A011200,label='HMM_Open')
        p=plt.plot(x_future_predict_A011200,y_future_predict_A011200,label='HMM_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='금호석유': 
        p=plt.plot(x_past_predict_A011780,y_past_predict_A011780,label='금호석유_Open')
        p=plt.plot(x_future_predict_A011780,y_future_predict_A011780,label='금호석유_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SKC': 
        p=plt.plot(x_past_predict_A011790,y_past_predict_A011790,label='SKC_Open')
        p=plt.plot(x_future_predict_A011790,y_future_predict_A011790,label='SKC_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대모비스': 
        p=plt.plot(x_past_predict_A012330,y_past_predict_A012330,label='현대모비스_Open')
        p=plt.plot(x_future_predict_A012330,y_future_predict_A012330,label='현대모비스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='더존비즈온': 
        p=plt.plot(x_past_predict_A012510,y_past_predict_A012510,label='더존비즈온_Open')
        p=plt.plot(x_future_predict_A012510,y_future_predict_A012510,label='더존비즈온_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='에스원': 
        p=plt.plot(x_past_predict_A012750,y_past_predict_A012750,label='에스원_Open')
        p=plt.plot(x_future_predict_A012750,y_future_predict_A012750,label='에스원_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국전력': 
        p=plt.plot(x_past_predict_A015760,y_past_predict_A015760,label='한국전력_Open')
        p=plt.plot(x_future_predict_A015760,y_future_predict_A015760,label='한국전력_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성증권': 
        p=plt.plot(x_past_predict_A016360,y_past_predict_A016360,label='삼성증권_Open')
        p=plt.plot(x_future_predict_A016360,y_future_predict_A016360,label='삼성증권_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK텔레콤': 
        p=plt.plot(x_past_predict_A017670,y_past_predict_A017670,label='SK텔레콤_Open')
        p=plt.plot(x_future_predict_A017670,y_future_predict_A017670,label='SK텔레콤_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성에스디에스': 
        p=plt.plot(x_past_predict_A018260,y_past_predict_A018260,label='삼성에스디에스_Open')
        p=plt.plot(x_future_predict_A018260,y_future_predict_A018260,label='삼성에스디에스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한온시스템': 
        p=plt.plot(x_past_predict_A018880,y_past_predict_A018880,label='한온시스템_Open')
        p=plt.plot(x_future_predict_A018880,y_future_predict_A018880,label='한온시스템_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='코웨이': 
        p=plt.plot(x_past_predict_A021240,y_past_predict_A021240,label='코웨이_Open')
        p=plt.plot(x_future_predict_A021240,y_future_predict_A021240,label='코웨이_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='롯데쇼핑': 
        p=plt.plot(x_past_predict_A023530,y_past_predict_A023530,label='롯데쇼핑_Open')
        p=plt.plot(x_future_predict_A023530,y_future_predict_A023530,label='롯데쇼핑_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='기업은행': 
        p=plt.plot(x_past_predict_A024110,y_past_predict_A024110,label='기업은행_Open')
        p=plt.plot(x_future_predict_A024110,y_future_predict_A024110,label='기업은행_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='동서': 
        p=plt.plot(x_past_predict_A026960,y_past_predict_A026960,label='동서_Open')
        p=plt.plot(x_future_predict_A026960,y_future_predict_A026960,label='동서_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성물산': 
        p=plt.plot(x_past_predict_A028260,y_past_predict_A028260,label='삼성물산_Open')
        p=plt.plot(x_future_predict_A028260,y_future_predict_A028260,label='삼성물산_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='팬오션': 
        p=plt.plot(x_past_predict_A028670,y_past_predict_A028670label='팬오션_Open')
        p=plt.plot(x_future_predict_A028670,y_future_predict_A028670,label='팬오션_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성카드': 
        p=plt.plot(x_past_predict_A029780,y_past_predict_A029780,label='삼성카드_Open')
        p=plt.plot(x_future_predict_A029780,y_future_predict_A029780,label='삼성카드_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='KT': 
        p=plt.plot(x_past_predict_A030200,y_past_predict_A030200,label='KT_Open')
        p=plt.plot(x_future_predict_A030200,y_future_predict_A030200label='KT_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG유플러스': 
        p=plt.plot(x_past_predict_A032640,y_past_predict_A032640,label='LG유플러스_Open')
        p=plt.plot(x_future_predict_A032640,y_future_predict_A032640,label='LG유플러스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성생명': 
        p=plt.plot(x_past_predict_A032830,y_past_predict_A032830,label='삼성생명_Open')
        p=plt.plot(x_future_predict_A032830,y_future_predict_A032830,label='삼성생명_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='KT&G': 
        p=plt.plot(x_past_predict_A033780,y_past_predict_A033780,label='KT&G_Open')
        p=plt.plot(x_future_predict_A033780,y_future_predict_A033780,label='KT&G_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='두산중공업': 
        p=plt.plot(x_past_predict_A034020,y_past_predict_A034020,label='두산중공업_Open')
        p=plt.plot(x_future_predict_A034020,y_future_predict_A034020,label='두산중공업_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG디스플레이': 
        p=plt.plot(x_past_predict_A034220,y_past_predict_A034220,label='LG디스플레이_Open')
        p=plt.plot(x_future_predict_A034220,y_future_predict_A034220,label='LG디스플레이_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK': 
        p=plt.plot(x_past_predict_A034730,y_past_predict_A034730,label='SK_Open')
        p=plt.plot(x_future_predict_A034730,y_future_predict_A034730,label='SK_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='강원랜드': 
        p=plt.plot(x_past_predict_A035250,y_past_predict_A035250,label='강원랜드_Open')
        p=plt.plot(x_future_predict_A035250,y_future_predict_A035250,label='강원랜드_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='NAVER': 
        p=plt.plot(x_past_predict_A035420,y_past_predict_A035420,label='NAVER_Open')
        p=plt.plot(x_future_predict_A035420,y_future_predict_A035420,label='NAVER_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='카카오': 
        p=plt.plot(x_past_predict_A035720,y_past_predict_A035720,label='카카오_Open')
        p=plt.plot(x_future_predict_A035720,y_future_predict_A035720,label='카카오_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국가스공사': 
        p=plt.plot(x_past_predict_A036460,y_past_predict_A036460,label='한국가스공사_Open')
        p=plt.plot(x_future_predict_A036460,y_future_predict_A036460,label='한국가스공사_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='엔씨소프트': 
        p=plt.plot(x_past_predict_A036570,y_past_predict_A036570,label='엔씨소프트_Open')
        p=plt.plot(x_future_predict_A036570,y_future_predict_A036570,label='엔씨소프트_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='키움증권': 
        p=plt.plot(x_past_predict_A039490,y_past_predict_A039490,label='키움증권_Open')
        p=plt.plot(x_future_predict_A039490,y_future_predict_A039490,label='키움증권_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국항공우주': 
        p=plt.plot(x_past_predict_A047810,y_past_predict_A047810,label='한국항공우주_Open')
        p=plt.plot(x_future_predict_A047810,y_future_predict_A047810,label='한국항공우주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG생활건강': 
        p=plt.plot(x_past_predict_A051900,y_past_predict_A051900,label='LG생활건강_Open')
        p=plt.plot(x_future_predict_A051900,y_future_predict_A051900,label='LG생활건강_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG화학': 
        p=plt.plot(x_past_predict_A051910,y_past_predict_A051910,label='LG화학_Open')
        p=plt.plot(x_future_predict_A051910,y_future_predict_A051910,label='LG화학_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='신한지주': 
        p=plt.plot(x_past_predict_A055550,y_past_predict_A055550,label='신한지주_Open')
        p=plt.plot(x_future_predict_A055550,y_future_predict_A055550,label='신한지주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG전자': 
        p=plt.plot(x_past_predict_A066570,y_past_predict_A066570,label='LG전자_Open')
        p=plt.plot(x_future_predict_A066570,y_future_predict_A066570,label='LG전자_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='셀트리온': 
        p=plt.plot(x_past_predict_A068270,y_past_predict_A068270,label='셀트리온_Open')
        p=plt.plot(x_future_predict_A068270,y_future_predict_A068270,label='셀트리온_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국금융지주': 
        p=plt.plot(x_past_predict_A071050,y_past_predict_A071050,label='한국금융지주_Open')
        p=plt.plot(x_future_predict_A071050,y_future_predict_A071050,label='한국금융지주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='GS': 
        p=plt.plot(x_past_predict_A078930,y_past_predict_A078930,label='GS_Open')
        p=plt.plot(x_future_predict_A078930,y_future_predict_A078930,label='GS_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대글로비스': 
        p=plt.plot(x_past_predict_A086280,y_past_predict_A086280,label='현대글로비스_Open')
        p=plt.plot(x_future_predict_A086280,y_future_predict_A086280,label='현대글로비스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='하나금융지주': 
        p=plt.plot(x_past_predict_A086790,y_past_predict_A086790,label='하나금융지주_Open')
        p=plt.plot(x_future_predict_A086790,y_future_predict_A086790,label='하나금융지주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='아모레퍼시픽': 
        p=plt.plot(x_past_predict_A090430,y_past_predict_A0904300,label='아모레퍼시픽_Open')
        p=plt.plot(x_future_predict_A090430,y_future_predict_A090430,label='아모레퍼시픽_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK이노베이션': 
        p=plt.plot(x_past_predict_A096770,y_past_predict_A096770,label='SK이노베이션_Open')
        p=plt.plot(x_future_predict_A096770,y_future_predict_A096770,label='SK이노베이션_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='CJ제일제당': 
        p=plt.plot(x_past_predict_A097950,y_past_predict_A097950,label='CJ제일제당_Open')
        p=plt.plot(x_future_predict_A097950,y_future_predict_A097950,label='CJ제일제당_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='KB금융': 
        p=plt.plot(x_past_predict_A105560,y_past_predict_A105560,label='KB금융_Open')
        p=plt.plot(x_future_predict_A105560,y_future_predict_A105560,label='KB금융_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한미약품': 
        p=plt.plot(x_past_predict_A128940,y_past_predict_A128940,label='한미약품_Open')
        p=plt.plot(x_future_predict_A128940,y_future_predict_A128940,label='한미약품_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='이마트': 
        p=plt.plot(x_past_predict_A139480,y_past_predict_A139480,label='이마트_Open')
        p=plt.plot(x_future_predict_A139480,y_future_predict_A139480,label='이마트_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국타이어앤테크놀로지': 
        p=plt.plot(x_past_predict_A161390,y_past_predict_A161390,label='한국타이어앤테크놀로지_Open')
        p=plt.plot(x_future_predict_A161390,y_future_predict_A1613900,label='한국타이어앤테크놀로지_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한진칼': 
        p=plt.plot(x_past_predict_A180640,y_past_predict_A180640,label='한진칼_Open')
        p=plt.plot(x_future_predict_A180640,y_future_predict_A1806400,label='한진칼_Prediction',color='red')
        datacursor(p)
        plt.legend()
    else: 
        p=plt.plot(x_past_predict_A204320,y_past_predict_A204320,label='만도_Open')
        p=plt.plot(x_future_predict_A204320,y_future_predict_A204320,label='만도_Prediction',color='red')
        datacursor(p)
        plt.legend()

    plt.rc('axes', unicode_minus=False)
    plt.show()

# %%
x_past_predict_A000100=predict_A000100.loc[0:3170,['Date']]
x_past_predict_A000120=predict_A000120.loc[0:3200,['Date']]
x_past_predict_A000270=predict_A000270.loc[0:3170,['Date']]
x_past_predict_A000660=predict_A000660.loc[0:3200,['Date']]
x_past_predict_A000720=predict_A000720.loc[0:3170,['Date']]
x_past_predict_A000810=predict_A000810.loc[0:3170,['Date']]
x_past_predict_A002790=predict_A002790.loc[0:3170,['Date']]
x_past_predict_A003410=predict_A003410.loc[0:3200,['Date']]
x_past_predict_A003490=predict_A003490.loc[0:3170,['Date']]
x_past_predict_A003550=predict_A003550.loc[0:3200,['Date']]
x_past_predict_A003670=predict_A003670.loc[0:3170,['Date']]
x_past_predict_A004020=predict_A004020.loc[0:3170,['Date']]
x_past_predict_A004990=predict_A004990.loc[0:3170,['Date']]
x_past_predict_A005380=predict_A005380.loc[0:3200,['Date']]
x_past_predict_A005387=predict_A005387.loc[0:3170,['Date']]
x_past_predict_A005490=predict_A005490.loc[0:3170,['Date']]
x_past_predict_A005830=predict_A005830.loc[0:3200,['Date']]
x_past_predict_A005930=predict_A005930.loc[0:3200,['Date']]
x_past_predict_A005935=predict_A005935.loc[0:3200,['Date']]
x_past_predict_A005940=predict_A005940.loc[0:3170,['Date']]
x_past_predict_A006280=predict_A006280.loc[0:3200,['Date']]
x_past_predict_A006360=predict_A006360.loc[0:3170,['Date']]
x_past_predict_A006400=predict_A006400.loc[0:3200,['Date']]
x_past_predict_A006800=predict_A006800.loc[0:3200,['Date']]
x_past_predict_A007070=predict_A007070.loc[0:3200,['Date']]
x_past_predict_A008560=predict_A008560.loc[0:3200,['Date']]
x_past_predict_A008770=predict_A008770.loc[0:3200,['Date']]
x_past_predict_A008930=predict_A008930.loc[0:3200,['Date']]
x_past_predict_A009150=predict_A009150.loc[0:3200,['Date']]
x_past_predict_A009540=predict_A009540.loc[0:3200,['Date']]
x_past_predict_A009830=predict_A009830.loc[0:3200,['Date']]
x_past_predict_A010130=predict_A010130.loc[0:3170,['Date']]
x_past_predict_A010140=predict_A010140.loc[0:3200,['Date']]
x_past_predict_A010950=predict_A010950.loc[0:3200,['Date']]
x_past_predict_A011070=predict_A011070.loc[0:3170,['Date']]
x_past_predict_A011170=predict_A011170.loc[0:3200,['Date']]
x_past_predict_A011200=predict_A011200.loc[0:3170,['Date']]
x_past_predict_A011780=predict_A011780.loc[0:3200,['Date']]
x_past_predict_A011790=predict_A011790.loc[0:3170,['Date']]
x_past_predict_A012330=predict_A012330.loc[0:3170,['Date']]
x_past_predict_A012510=predict_A012510.loc[0:3170,['Date']]
x_past_predict_A012750=predict_A012750.loc[0:3200,['Date']]
x_past_predict_A015760=predict_A015760.loc[0:3170,['Date']]
x_past_predict_A016360=predict_A016360.loc[0:3200,['Date']]
x_past_predict_A017670=predict_A017670.loc[0:3200,['Date']]
x_past_predict_A018260=predict_A018260.loc[0:3170,['Date']]
x_past_predict_A018880=predict_A018880.loc[0:3200,['Date']]
x_past_predict_A021240=predict_A021240.loc[0:3170,['Date']]
x_past_predict_A023530=predict_A023530.loc[0:3170,['Date']]
x_past_predict_A024110=predict_A024110.loc[0:3170,['Date']]
x_past_predict_A026960=predict_A026960.loc[0:3200,['Date']]
x_past_predict_A028260=predict_A028260.loc[0:3200,['Date']]
x_past_predict_A028670=predict_A028670.loc[0:3170,['Date']]
x_past_predict_A029780=predict_A029780.loc[0:3170,['Date']]
x_past_predict_A030200=predict_A030200.loc[0:3170,['Date']]
x_past_predict_A032640=predict_A032640.loc[0:3200,['Date']]
x_past_predict_A032830=predict_A032830.loc[0:3200,['Date']]
x_past_predict_A033780=predict_A033780.loc[0:3170,['Date']]
x_past_predict_A034020=predict_A034020.loc[0:3170,['Date']]
x_past_predict_A034220=predict_A034220.loc[0:3200,['Date']]
x_past_predict_A034730=predict_A034730.loc[0:3170,['Date']]
x_past_predict_A035250=predict_A035250.loc[0:3200,['Date']]
x_past_predict_A035420=predict_A035420.loc[0:3170,['Date']]
x_past_predict_A035720=predict_A035720.loc[0:3170,['Date']]
x_past_predict_A036460=predict_A036460.loc[0:3170,['Date']]
x_past_predict_A036570=predict_A036570.loc[0:3200,['Date']]
x_past_predict_A039490=predict_A039490.loc[0:3200,['Date']]
x_past_predict_A047810=predict_A047810.loc[0:3200,['Date']]
x_past_predict_A051900=predict_A051900.loc[0:3170,['Date']]
x_past_predict_A051910=predict_A051910.loc[0:3170,['Date']]
x_past_predict_A055550=predict_A055550.loc[0:3170,['Date']]
x_past_predict_A066570=predict_A066570.loc[0:3170,['Date']]
x_past_predict_A068270=predict_A068270.loc[0:3200,['Date']]
x_past_predict_A071050=predict_A071050.loc[0:3200,['Date']]
x_past_predict_A078930=predict_A078930.loc[0:3170,['Date']]
x_past_predict_A086280=predict_A086280.loc[0:3170,['Date']]
x_past_predict_A086790=predict_A086790.loc[0:3170,['Date']]
x_past_predict_A090430=predict_A090430.loc[0:3200,['Date']]
x_past_predict_A096770=predict_A096770.loc[0:3200,['Date']]
x_past_predict_A097950=predict_A097950.loc[0:3200,['Date']]
x_past_predict_A105560=predict_A105560.loc[0:3170,['Date']]
x_past_predict_A128940=predict_A128940.loc[0:3200,['Date']]
x_past_predict_A139480=predict_A139480.loc[0:3200,['Date']]
x_past_predict_A161390=predict_A161390.loc[0:3200,['Date']]
x_past_predict_A180640=predict_A180640.loc[0:3170,['Date']]
x_past_predict_A204320=predict_A204320.loc[0:3170,['Date']]

# %%
#86개의 종목을 선택할 수 있게 하는 위젯 코드
#이 위젯을 통해 종목별 그래프를 나타나게 하며 voila 사용 시 html에 위젯 및 그래프가 나타난다.
widgets.interactive(stock_plot, stock=stock)
# Out:
# interactive(children=(Dropdown(description='stock', options=('유한양행', 'CJ대한통운', '기아차', 'SK하이닉스', '현대건설', '삼성화재'…

# %%
print("\n\n")

# %% [markdown]
# ### 원하는 종목의 주가를 확인해보세요!

# %%
predict_open_A000100=predict_A000100.loc[3170:3960,['Date','예측 시가']]
predict_open_A000120=predict_A000120.loc[3200:3997,['Date','예측 시가']]
predict_open_A000270=predict_A000270.loc[3170:3960,['Date','예측 시가']]
predict_open_A000660=predict_A000660.loc[3200:3997,['Date','예측 시가']]
predict_open_A000720=predict_A000720.loc[3170:3960,['Date','예측 시가']]
predict_open_A000810=predict_A000810.loc[3170:3960,['Date','예측 시가']]
predict_open_A002790=predict_A002790.loc[3170:3960,['Date','예측 시가']]
predict_open_A003410=predict_A003410.loc[3200:3997,['Date','예측 시가']]
predict_open_A003490=predict_A003490.loc[3170:3960,['Date','예측 시가']]
predict_open_A003550=predict_A003550.loc[3200:3997,['Date','예측 시가']]
predict_open_A003670=predict_A003670.loc[3170:3960,['Date','예측 시가']]
predict_open_A004020=predict_A004020.loc[3170:3960,['Date','예측 시가']]
predict_open_A004990=predict_A004990.loc[3170:3960,['Date','예측 시가']]
predict_open_A005380=predict_A005380.loc[3200:3997,['Date','예측 시가']]
predict_open_A005387=predict_A005387.loc[3170:3960,['Date','예측 시가']]
predict_open_A005490=predict_A005490.loc[3170:3960,['Date','예측 시가']]
predict_open_A005830=predict_A005830.loc[3200:3997,['Date','예측 시가']]
predict_open_A005930=predict_A005930.loc[3200:3997,['Date','예측 시가']]
predict_open_A005935=predict_A005935.loc[3200:3997,['Date','예측 시가']]
predict_open_A005940=predict_A005940.loc[3170:3960,['Date','예측 시가']]
predict_open_A006280=predict_A006280.loc[3200:3997,['Date','예측 시가']]
predict_open_A006360=predict_A006360.loc[3170:3960,['Date','예측 시가']]
predict_open_A006400=predict_A006400.loc[3200:3997,['Date','예측 시가']]
predict_open_A006800=predict_A006800.loc[3200:3997,['Date','예측 시가']]
predict_open_A007070=predict_A007070.loc[3200:3997,['Date','예측 시가']]
predict_open_A008560=predict_A008560.loc[3200:3997,['Date','예측 시가']]
predict_open_A008770=predict_A008770.loc[3200:3997,['Date','예측 시가']]
predict_open_A008930=predict_A008930.loc[3200:3997,['Date','예측 시가']]
predict_open_A009150=predict_A009150.loc[3200:3997,['Date','예측 시가']]
predict_open_A009540=predict_A009540.loc[3200:3997,['Date','예측 시가']]
predict_open_A009830=predict_A009830.loc[3200:3997,['Date','예측 시가']]
predict_open_A010130=predict_A010130.loc[3170:3960,['Date','예측 시가']]
predict_open_A010140=predict_A010140.loc[3200:3997,['Date','예측 시가']]
predict_open_A010950=predict_A010950.loc[3200:3997,['Date','예측 시가']]
predict_open_A011070=predict_A011070.loc[3170:3960,['Date','예측 시가']]
predict_open_A011170=predict_A011170.loc[3200:3997,['Date','예측 시가']]
predict_open_A011200=predict_A011200.loc[3170:3960,['Date','예측 시가']]
predict_open_A011780=predict_A011780.loc[3200:3997,['Date','예측 시가']]
predict_open_A011790=predict_A011790.loc[3170:3960,['Date','예측 시가']]
predict_open_A012330=predict_A012330.loc[3170:3960,['Date','예측 시가']]
predict_open_A012510=predict_A012510.loc[3170:3960,['Date','예측 시가']]
predict_open_A012750=predict_A012750.loc[3200:3997,['Date','예측 시가']]
predict_open_A015760=predict_A015760.loc[3170:3960,['Date','예측 시가']]
predict_open_A016360=predict_A016360.loc[3200:3997,['Date','예측 시가']]
predict_open_A017670=predict_A017670.loc[3200:3997,['Date','예측 시가']]
predict_open_A018260=predict_A018260.loc[3170:3960,['Date','예측 시가']]
predict_open_A018880=predict_A018880.loc[3200:3997,['Date','예측 시가']]
predict_open_A021240=predict_A021240.loc[3170:3960,['Date','예측 시가']]
predict_open_A023530=predict_A023530.loc[3170:3960,['Date','예측 시가']]
predict_open_A024110=predict_A024110.loc[3170:3960,['Date','예측 시가']]
predict_open_A026960=predict_A026960.loc[3200:3997,['Date','예측 시가']]
predict_open_A028260=predict_A028260.loc[3200:3997,['Date','예측 시가']]
predict_open_A028670=predict_A028670.loc[3170:3960,['Date','예측 시가']]
predict_open_A029780=predict_A029780.loc[3170:3960,['Date','예측 시가']]
predict_open_A030200=predict_A030200.loc[3170:3960,['Date','예측 시가']]
predict_open_A032640=predict_A032640.loc[3200:3997,['Date','예측 시가']]
predict_open_A032830=predict_A032830.loc[3200:3997,['Date','예측 시가']]
predict_open_A033780=predict_A033780.loc[3170:3960,['Date','예측 시가']]
predict_open_A034020=predict_A034020.loc[3170:3960,['Date','예측 시가']]
predict_open_A034220=predict_A034220.loc[3200:3997,['Date','예측 시가']]
predict_open_A034730=predict_A034730.loc[3170:3960,['Date','예측 시가']]
predict_open_A035250=predict_A035250.loc[3200:3997,['Date','예측 시가']]
predict_open_A035420=predict_A035420.loc[3170:3960,['Date','예측 시가']]
predict_open_A035720=predict_A035720.loc[3170:3960,['Date','예측 시가']]
predict_open_A036460=predict_A036460.loc[3170:3960,['Date','예측 시가']]
predict_open_A036570=predict_A036570.loc[3200:3997,['Date','예측 시가']]
predict_open_A039490=predict_A039490.loc[3200:3997,['Date','예측 시가']]
predict_open_A047810=predict_A047810.loc[3200:3997,['Date','예측 시가']]
predict_open_A051900=predict_A051900.loc[3170:3960,['Date','예측 시가']]
predict_open_A051910=predict_A051910.loc[3170:3960,['Date','예측 시가']]
predict_open_A055550=predict_A055550.loc[3170:3960,['Date','예측 시가']]
predict_open_A066570=predict_A066570.loc[3170:3960,['Date','예측 시가']]
predict_open_A068270=predict_A068270.loc[3200:3997,['Date','예측 시가']]
predict_open_A071050=predict_A071050.loc[3200:3997,['Date','예측 시가']]
predict_open_A078930=predict_A078930.loc[3170:3960,['Date','예측 시가']]
predict_open_A086280=predict_A086280.loc[3170:3960,['Date','예측 시가']]
predict_open_A086790=predict_A086790.loc[3170:3960,['Date','예측 시가']]
predict_open_A090430=predict_A090430.loc[3200:3997,['Date','예측 시가']]
predict_open_A096770=predict_A096770.loc[3200:3997,['Date','예측 시가']]
predict_open_A097950=predict_A097950.loc[3200:3997,['Date','예측 시가']]
predict_open_A105560=predict_A105560.loc[3170:3960,['Date','예측 시가']]
predict_open_A128940=predict_A128940.loc[3200:3997,['Date','예측 시가']]
predict_open_A139480=predict_A139480.loc[3200:3997,['Date','예측 시가']]
predict_open_A161390=predict_A161390.loc[3200:3997,['Date','예측 시가']]
predict_open_A180640=predict_A180640.loc[3170:3960,['Date','예측 시가']]
predict_open_A204320=predict_A204320.loc[3170:3960,['Date','예측 시가']]

# %%
predict_dic = {'유한양행':predict_open_A000100,
               'CJ대한통운':predict_open_A000120,
               '기아차':predict_open_A000270,
               'SK하이닉스':predict_open_A000660,
               '현대건설':predict_open_A000720,
               '삼성화재':predict_open_A000810,
               '아모레G':predict_open_A002790,
               '쌍용양회':predict_open_A003410,
               '대한항공':predict_open_A003490,
               'LG':predict_open_A003550,
               '포스코케미칼':predict_open_A003670,
               '현대제철':predict_open_A004020,
               '롯데지주':predict_open_A004990,
               '현대차':predict_open_A005380,
               '현대차2우B':predict_open_A005387,
               'POSCO':predict_open_A005490,
               'DB손해보험':predict_open_A005830,
               '삼성전자':predict_open_A005930,
               '삼성전자우':predict_open_A005935,
               'NH투자증권':predict_open_A005940,
               '녹십자':predict_open_A006280,
               'GS건설':predict_open_A006360,
               '삼성SDI':predict_open_A006400,
               '미래에셋대우':predict_open_A006800,
               'GS리테일':predict_open_A007070,
               '메리츠증권':predict_open_A008560,
               '호텔신라':predict_open_A008770,
               '한미사이언스':predict_open_A008930,
               '삼성전기':predict_open_A009150,
               '한국조선해양':predict_open_A009540,
               '한화솔루션':predict_open_A009830,
               '고려아연':predict_open_A010130,
               '삼성중공업':predict_open_A010140,
               'S-Oil':predict_open_A010950,
               'LG이노텍':predict_open_A011070,
               '롯데케미칼':predict_open_A011170,
               'HMM':predict_open_A011200,
               '금호석유':predict_open_A011780,
               'SKC':predict_open_A011790,
               '현대모비스':predict_open_A012330,
               '더존비즈온':predict_open_A012510,
               '에스원':predict_open_A012750,
               '한국전력':predict_open_A015760,
               '삼성증권':predict_open_A016360,
               'SK텔레콤':predict_open_A017670,
               '삼성에스디에스':predict_open_A018260,
               '한온시스템':predict_open_A018880,
               '코웨이':predict_open_A021240,
               '롯데쇼핑':predict_open_A023530,
               '기업은행':predict_open_A024110,
               '동서':predict_open_A026960,
               '삼성물산':predict_open_A028260,
               '팬오션':predict_open_A028670,
               '삼성카드':predict_open_A029780,
               'KT':predict_open_A030200,
               'LG유플러스':predict_open_A032640,
               '삼성생명':predict_open_A032830,
               'KT&G':predict_open_A033780,
               '두산중공업':predict_open_A034020,
               'LG디스플레이':predict_open_A034220,
               'SK':predict_open_A034730,
               '강원랜드':predict_open_A035250,
               'NAVER':predict_open_A035420,
               '카카오':predict_open_A035720,
               '한국가스공사':predict_open_A036460,
               '엔씨소프트':predict_open_A036570,
               '키움증권':predict_open_A039490,
               '한국항공우주':predict_open_A047810,
               'LG생활건강':predict_open_A051900,
               'LG화학':predict_open_A051910,
               '신한지주':predict_open_A055550,
               'LG전자':predict_open_A066570,
               '셀트리온':predict_open_A068270,
               '한국금융지주':predict_open_A071050,
               'GS':predict_open_A078930,
               '현대글로비스':predict_open_A086280,
               '하나금융지주':predict_open_A086790,
               '아모레퍼시픽':predict_open_A090430,
               'SK이노베이션':predict_open_A096770,
               'CJ제일제당':predict_open_A097950,
               'KB금융':predict_open_A105560,
               '한미약품':predict_open_A128940,
               '이마트':predict_open_A139480,
               '한국타이어앤테크':predict_open_A161390,
               '한진칼':predict_open_A180640,
               '만도':predict_open_A204320
               }

# %%
predict_stock=list(predict_dic.keys())
predict_open=list(predict_dic.values())
predict_date=list(predict_open_A000100['Date'])

# %%
def predict(predict_stock,predict_date):
    print(predict_dic[predict_stock][predict_dic[predict_stock]['Date']==predict_date])

# %%
widgets.interactive(predict, predict_stock=predict_stock,predict_date=predict_date)
# Out:
# interactive(children=(Dropdown(description='predict_stock', options=('유한양행', 'CJ대한통운', '기아차', 'SK하이닉스', '현대건설'…

# %%
print("\n\n")

# %% [markdown]
# ### 원하는 종목의 예측 성능을 그래프로 확인해보세요!

# %% [markdown]
# #### 성능을 제시하기 위한 최근 3개월(2020/9/18~20/12/18) 시가 예측 그래프입니다.

# %%
check_A000100=pd.read_csv("LGBM성능확인/A000100_performance1.csv")
check_A000120=pd.read_csv("엔비츠성능확인/A000120n_beats_test_performance_(3200, 800).csv")
check_A000270=pd.read_csv("LGBM성능확인/A000270_performance1.csv")
check_A000660=pd.read_csv("엔비츠성능확인/A000660n_beats_test_performance_(3200, 800).csv")
check_A000720=pd.read_csv("LGBM성능확인/A000720_performance1.csv")
check_A000810=pd.read_csv("LGBM성능확인/A000810_performance1.csv")
check_A002790=pd.read_csv("LGBM성능확인/A002790_performance1.csv")
check_A003410=pd.read_csv("엔비츠성능확인/A003410n_beats_test_performance_(3200, 800).csv")
check_A003490=pd.read_csv("LGBM성능확인/A003490_performance1.csv")
check_A003550=pd.read_csv("엔비츠성능확인/A003550n_beats_test_performance_(3200, 800).csv")
check_A003670=pd.read_csv("LGBM성능확인/A003670_performance1.csv")
check_A004020=pd.read_csv("LGBM성능확인/A004020_performance1.csv")
check_A004990=pd.read_csv("LGBM성능확인/A004990_performance1.csv")
check_A005380=pd.read_csv("엔비츠성능확인/A005380n_beats_test_performance_(3200, 800).csv")
check_A005387=pd.read_csv("LGBM성능확인/A005387_performance1.csv")
check_A005490=pd.read_csv("LGBM성능확인/A005490_performance1.csv")
check_A005830=pd.read_csv("엔비츠성능확인/A005830n_beats_test_performance_(3200, 800).csv")
check_A005930=pd.read_csv("엔비츠성능확인/A005930n_beats_test_performance_(3200, 800).csv")
check_A005935=pd.read_csv("엔비츠성능확인/A005935n_beats_test_performance_(3200, 800).csv")
check_A005940=pd.read_csv("LGBM성능확인/A005940_performance1.csv")
check_A006280=pd.read_csv("엔비츠성능확인/A006280n_beats_test_performance_(3200, 800).csv")
check_A006360=pd.read_csv("LGBM성능확인/A006360_performance1.csv")
check_A006400=pd.read_csv("엔비츠성능확인/A006400n_beats_test_performance_(3200, 800).csv")
check_A006800=pd.read_csv("엔비츠성능확인/A006800n_beats_test_performance_(3200, 800).csv")
check_A007070=pd.read_csv("엔비츠성능확인/A007070n_beats_test_performance_(3200, 800).csv")
check_A008560=pd.read_csv("엔비츠성능확인/A008560n_beats_test_performance_(3200, 800).csv")
check_A008770=pd.read_csv("엔비츠성능확인/A008770n_beats_test_performance_(3200, 800).csv")
check_A008930=pd.read_csv("엔비츠성능확인/A008930n_beats_test_performance_(3200, 800).csv")
check_A009150=pd.read_csv("엔비츠성능확인/A009150n_beats_test_performance_(3200, 800).csv")
check_A009540=pd.read_csv("엔비츠성능확인/A009540n_beats_test_performance_(3200, 800).csv")
check_A009830=pd.read_csv("엔비츠성능확인/A009830n_beats_test_performance_(3200, 800).csv")
check_A010130=pd.read_csv("LGBM성능확인/A010130_performance1.csv")
check_A010140=pd.read_csv("엔비츠성능확인/A010140n_beats_test_performance_(3200, 800).csv")
check_A010950=pd.read_csv("엔비츠성능확인/A010950n_beats_test_performance_(3200, 800).csv")
check_A011070=pd.read_csv("LGBM성능확인/A011070_performance1.csv")
check_A011170=pd.read_csv("엔비츠성능확인/A011170n_beats_test_performance_(3200, 800).csv")
check_A011200=pd.read_csv("LGBM성능확인/A011200_performance1.csv")
check_A011780=pd.read_csv("엔비츠성능확인/A011780n_beats_test_performance_(3200, 800).csv")
check_A011790=pd.read_csv("LGBM성능확인/A011790_performance1.csv")
check_A012330=pd.read_csv("LGBM성능확인/A012330_performance1.csv")
check_A012510=pd.read_csv("LGBM성능확인/A012510_performance1.csv")
check_A012750=pd.read_csv("엔비츠성능확인/A012750n_beats_test_performance_(3200, 800).csv")
check_A015760=pd.read_csv("LGBM성능확인/A015760_performance1.csv")
check_A016360=pd.read_csv("엔비츠성능확인/A016360n_beats_test_performance_(3200, 800).csv")
check_A017670=pd.read_csv("엔비츠성능확인/A017670n_beats_test_performance_(3200, 800).csv")
check_A018260=pd.read_csv("LGBM성능확인/A018260_performance1.csv")
check_A018880=pd.read_csv("엔비츠성능확인/A018880n_beats_test_performance_(3200, 800).csv")
check_A021240=pd.read_csv("LGBM성능확인/A021240_performance1.csv")
check_A023530=pd.read_csv("LGBM성능확인/A023530_performance1.csv")
check_A024110=pd.read_csv("LGBM성능확인/A024110_performance1.csv")
check_A026960=pd.read_csv("엔비츠성능확인/A026960n_beats_test_performance_(3200, 800).csv")
check_A028260=pd.read_csv("엔비츠성능확인/A028260n_beats_test_performance_(3200, 800).csv")
check_A028670=pd.read_csv("LGBM성능확인/A028670_performance1.csv")
check_A029780=pd.read_csv("LGBM성능확인/A029780_performance1.csv")
check_A030200=pd.read_csv("LGBM성능확인/A030200_performance1.csv")
check_A032640=pd.read_csv("엔비츠성능확인/A032640n_beats_test_performance_(3200, 800).csv")
check_A032830=pd.read_csv("엔비츠성능확인/A032830n_beats_test_performance_(3200, 800).csv")
check_A033780=pd.read_csv("LGBM성능확인/A033780_performance1.csv")
check_A034020=pd.read_csv("LGBM성능확인/A034020_performance1.csv")
check_A034220=pd.read_csv("엔비츠성능확인/A034220n_beats_test_performance_(3200, 800).csv")
check_A034730=pd.read_csv("LGBM성능확인/A034730_performance1.csv")
check_A035250=pd.read_csv("엔비츠성능확인/A035250n_beats_test_performance_(3200, 800).csv")
check_A035420=pd.read_csv("LGBM성능확인/A035420_performance1.csv")
check_A035720=pd.read_csv("LGBM성능확인/A035720_performance1.csv")
check_A036460=pd.read_csv("LGBM성능확인/A036460_performance1.csv")
check_A036570=pd.read_csv("엔비츠성능확인/A036570n_beats_test_performance_(3200, 800).csv")
check_A039490=pd.read_csv("엔비츠성능확인/A039490n_beats_test_performance_(3200, 800).csv")
check_A047810=pd.read_csv("엔비츠성능확인/A047810n_beats_test_performance_(3200, 800).csv")
check_A051900=pd.read_csv("LGBM성능확인/A051900_performance1.csv")
check_A051910=pd.read_csv("LGBM성능확인/A051910_performance1.csv")
check_A055550=pd.read_csv("LGBM성능확인/A055550_performance1.csv")
check_A066570=pd.read_csv("LGBM성능확인/A066570_performance1.csv")
check_A068270=pd.read_csv("엔비츠성능확인/A068270n_beats_test_performance_(3200, 800).csv")
check_A071050=pd.read_csv("엔비츠성능확인/A071050n_beats_test_performance_(3200, 800).csv")
check_A078930=pd.read_csv("LGBM성능확인/A078930_performance1.csv")
check_A086280=pd.read_csv("LGBM성능확인/A086280_performance1.csv")
check_A086790=pd.read_csv("LGBM성능확인/A086790_performance1.csv")
check_A090430=pd.read_csv("엔비츠성능확인/A090430n_beats_test_performance_(3200, 800).csv")
check_A096770=pd.read_csv("엔비츠성능확인/A096770n_beats_test_performance_(3200, 800).csv")
check_A097950=pd.read_csv("엔비츠성능확인/A097950n_beats_test_performance_(3200, 800).csv")
check_A105560=pd.read_csv("LGBM성능확인/A105560_performance1.csv")
check_A128940=pd.read_csv("엔비츠성능확인/A128940n_beats_test_performance_(3200, 800).csv")
check_A139480=pd.read_csv("엔비츠성능확인/A139480n_beats_test_performance_(3200, 800).csv")
check_A161390=pd.read_csv("엔비츠성능확인/A161390n_beats_test_performance_(3200, 800).csv")
check_A180640=pd.read_csv("LGBM성능확인/A180640_performance1.csv")
check_A204320=pd.read_csv("LGBM성능확인/A204320_performance1.csv")

# %%
check_A000100.Date=pd.to_datetime(check_A000100.Date,format='%Y-%m-%d %H:%M:%S')
check_A000120.Date=pd.to_datetime(check_A000120.Date,format='%Y-%m-%d %H:%M:%S')
check_A000270.Date=pd.to_datetime(check_A000270.Date,format='%Y-%m-%d %H:%M:%S')
check_A000660.Date=pd.to_datetime(check_A000660.Date,format='%Y-%m-%d %H:%M:%S')
check_A000720.Date=pd.to_datetime(check_A000720.Date,format='%Y-%m-%d %H:%M:%S')
check_A000810.Date=pd.to_datetime(check_A000810.Date,format='%Y-%m-%d %H:%M:%S')
check_A002790.Date=pd.to_datetime(check_A002790.Date,format='%Y-%m-%d %H:%M:%S')
check_A003410.Date=pd.to_datetime(check_A003410.Date,format='%Y-%m-%d %H:%M:%S')
check_A003490.Date=pd.to_datetime(check_A003490.Date,format='%Y-%m-%d %H:%M:%S')
check_A003550.Date=pd.to_datetime(check_A003550.Date,format='%Y-%m-%d %H:%M:%S')
check_A003670.Date=pd.to_datetime(check_A003670.Date,format='%Y-%m-%d %H:%M:%S')
check_A004020.Date=pd.to_datetime(check_A004020.Date,format='%Y-%m-%d %H:%M:%S')
check_A004990.Date=pd.to_datetime(check_A004990.Date,format='%Y-%m-%d %H:%M:%S')
check_A005380.Date=pd.to_datetime(check_A005380.Date,format='%Y-%m-%d %H:%M:%S')
check_A005387.Date=pd.to_datetime(check_A005387.Date,format='%Y-%m-%d %H:%M:%S')
check_A005490.Date=pd.to_datetime(check_A005490.Date,format='%Y-%m-%d %H:%M:%S')
check_A005830.Date=pd.to_datetime(check_A005830.Date,format='%Y-%m-%d %H:%M:%S')
check_A005930.Date=pd.to_datetime(check_A005930.Date,format='%Y-%m-%d %H:%M:%S')
check_A005935.Date=pd.to_datetime(check_A005935.Date,format='%Y-%m-%d %H:%M:%S')
check_A005940.Date=pd.to_datetime(check_A005940.Date,format='%Y-%m-%d %H:%M:%S')
check_A006280.Date=pd.to_datetime(check_A006280.Date,format='%Y-%m-%d %H:%M:%S')
check_A006360.Date=pd.to_datetime(check_A006360.Date,format='%Y-%m-%d %H:%M:%S')
check_A006400.Date=pd.to_datetime(check_A006400.Date,format='%Y-%m-%d %H:%M:%S')
check_A006800.Date=pd.to_datetime(check_A006800.Date,format='%Y-%m-%d %H:%M:%S')
check_A007070.Date=pd.to_datetime(check_A007070.Date,format='%Y-%m-%d %H:%M:%S')
check_A008560.Date=pd.to_datetime(check_A008560.Date,format='%Y-%m-%d %H:%M:%S')
check_A008770.Date=pd.to_datetime(check_A008770.Date,format='%Y-%m-%d %H:%M:%S')
check_A008930.Date=pd.to_datetime(check_A008930.Date,format='%Y-%m-%d %H:%M:%S')
check_A009150.Date=pd.to_datetime(check_A009150.Date,format='%Y-%m-%d %H:%M:%S')
check_A009540.Date=pd.to_datetime(check_A009540.Date,format='%Y-%m-%d %H:%M:%S')
check_A009830.Date=pd.to_datetime(check_A009830.Date,format='%Y-%m-%d %H:%M:%S')
check_A010130.Date=pd.to_datetime(check_A010130.Date,format='%Y-%m-%d %H:%M:%S')
check_A010140.Date=pd.to_datetime(check_A010140.Date,format='%Y-%m-%d %H:%M:%S')
check_A010950.Date=pd.to_datetime(check_A010950.Date,format='%Y-%m-%d %H:%M:%S')
check_A011070.Date=pd.to_datetime(check_A011070.Date,format='%Y-%m-%d %H:%M:%S')
check_A011170.Date=pd.to_datetime(check_A011170.Date,format='%Y-%m-%d %H:%M:%S')
check_A011200.Date=pd.to_datetime(check_A011200.Date,format='%Y-%m-%d %H:%M:%S')
check_A011780.Date=pd.to_datetime(check_A011780.Date,format='%Y-%m-%d %H:%M:%S')
check_A011790.Date=pd.to_datetime(check_A011790.Date,format='%Y-%m-%d %H:%M:%S')
check_A012330.Date=pd.to_datetime(check_A012330.Date,format='%Y-%m-%d %H:%M:%S')
check_A012510.Date=pd.to_datetime(check_A012510.Date,format='%Y-%m-%d %H:%M:%S')
check_A012750.Date=pd.to_datetime(check_A012750.Date,format='%Y-%m-%d %H:%M:%S')
check_A015760.Date=pd.to_datetime(check_A015760.Date,format='%Y-%m-%d %H:%M:%S')
check_A016360.Date=pd.to_datetime(check_A016360.Date,format='%Y-%m-%d %H:%M:%S')
check_A017670.Date=pd.to_datetime(check_A017670.Date,format='%Y-%m-%d %H:%M:%S')
check_A018260.Date=pd.to_datetime(check_A018260.Date,format='%Y-%m-%d %H:%M:%S')
check_A018880.Date=pd.to_datetime(check_A018880.Date,format='%Y-%m-%d %H:%M:%S')
check_A021240.Date=pd.to_datetime(check_A021240.Date,format='%Y-%m-%d %H:%M:%S')
check_A023530.Date=pd.to_datetime(check_A023530.Date,format='%Y-%m-%d %H:%M:%S')
check_A024110.Date=pd.to_datetime(check_A024110.Date,format='%Y-%m-%d %H:%M:%S')
check_A026960.Date=pd.to_datetime(check_A026960.Date,format='%Y-%m-%d %H:%M:%S')
check_A028260.Date=pd.to_datetime(check_A028260.Date,format='%Y-%m-%d %H:%M:%S')
check_A028670.Date=pd.to_datetime(check_A028670.Date,format='%Y-%m-%d %H:%M:%S')
check_A029780.Date=pd.to_datetime(check_A029780.Date,format='%Y-%m-%d %H:%M:%S')
check_A030200.Date=pd.to_datetime(check_A030200.Date,format='%Y-%m-%d %H:%M:%S')
check_A032640.Date=pd.to_datetime(check_A032640.Date,format='%Y-%m-%d %H:%M:%S')
check_A032830.Date=pd.to_datetime(check_A032830.Date,format='%Y-%m-%d %H:%M:%S')
check_A033780.Date=pd.to_datetime(check_A033780.Date,format='%Y-%m-%d %H:%M:%S')
check_A034020.Date=pd.to_datetime(check_A034020.Date,format='%Y-%m-%d %H:%M:%S')
check_A034220.Date=pd.to_datetime(check_A034220.Date,format='%Y-%m-%d %H:%M:%S')
check_A034730.Date=pd.to_datetime(check_A034730.Date,format='%Y-%m-%d %H:%M:%S')
check_A035250.Date=pd.to_datetime(check_A035250.Date,format='%Y-%m-%d %H:%M:%S')
check_A035420.Date=pd.to_datetime(check_A035420.Date,format='%Y-%m-%d %H:%M:%S')
check_A035720.Date=pd.to_datetime(check_A035720.Date,format='%Y-%m-%d %H:%M:%S')
check_A036460.Date=pd.to_datetime(check_A036460.Date,format='%Y-%m-%d %H:%M:%S')
check_A036570.Date=pd.to_datetime(check_A036570.Date,format='%Y-%m-%d %H:%M:%S')
check_A039490.Date=pd.to_datetime(check_A039490.Date,format='%Y-%m-%d %H:%M:%S')
check_A047810.Date=pd.to_datetime(check_A047810.Date,format='%Y-%m-%d %H:%M:%S')
check_A051900.Date=pd.to_datetime(check_A051900.Date,format='%Y-%m-%d %H:%M:%S')
check_A051910.Date=pd.to_datetime(check_A051910.Date,format='%Y-%m-%d %H:%M:%S')
check_A055550.Date=pd.to_datetime(check_A055550.Date,format='%Y-%m-%d %H:%M:%S')
check_A066570.Date=pd.to_datetime(check_A066570.Date,format='%Y-%m-%d %H:%M:%S')
check_A068270.Date=pd.to_datetime(check_A068270.Date,format='%Y-%m-%d %H:%M:%S')
check_A071050.Date=pd.to_datetime(check_A071050.Date,format='%Y-%m-%d %H:%M:%S')
check_A078930.Date=pd.to_datetime(check_A078930.Date,format='%Y-%m-%d %H:%M:%S')
check_A086280.Date=pd.to_datetime(check_A086280.Date,format='%Y-%m-%d %H:%M:%S')
check_A086790.Date=pd.to_datetime(check_A086790.Date,format='%Y-%m-%d %H:%M:%S')
check_A090430.Date=pd.to_datetime(check_A090430.Date,format='%Y-%m-%d %H:%M:%S')
check_A096770.Date=pd.to_datetime(check_A096770.Date,format='%Y-%m-%d %H:%M:%S')
check_A097950.Date=pd.to_datetime(check_A097950.Date,format='%Y-%m-%d %H:%M:%S')
check_A105560.Date=pd.to_datetime(check_A105560.Date,format='%Y-%m-%d %H:%M:%S')
check_A128940.Date=pd.to_datetime(check_A128940.Date,format='%Y-%m-%d %H:%M:%S')
check_A139480.Date=pd.to_datetime(check_A139480.Date,format='%Y-%m-%d %H:%M:%S')
check_A161390.Date=pd.to_datetime(check_A161390.Date,format='%Y-%m-%d %H:%M:%S')
check_A180640.Date=pd.to_datetime(check_A180640.Date,format='%Y-%m-%d %H:%M:%S')
check_A204320.Date=pd.to_datetime(check_A204320.Date,format='%Y-%m-%d %H:%M:%S')

# %%
check_A000100['predict']=check_A000100['predict'].round()
check_A000120['예측 시가']=check_A000120['예측 시가'].round()
check_A000270['predict']=check_A000270['predict'].round()
check_A000660['예측 시가']=check_A000660['예측 시가'].round()
check_A000720['predict']=check_A000720['predict'].round()
check_A000810['predict']=check_A000810['predict'].round()
check_A002790['predict']=check_A002790['predict'].round()
check_A003410['예측 시가']=check_A003410['예측 시가'].round()
check_A003490['predict']=check_A003490['predict'].round()
check_A003550['예측 시가']=check_A003550['예측 시가'].round()
check_A003670['predict']=check_A003670['predict'].round()
check_A004020['predict']=check_A004020['predict'].round()
check_A004990['predict']=check_A004990['predict'].round()
check_A005380['예측 시가']=check_A005380['예측 시가'].round()
check_A005387['predict']=check_A005387['predict'].round()
check_A005490['predict']=check_A005490['predict'].round()
check_A005830['예측 시가']=check_A005830['예측 시가'].round()
check_A005930['예측 시가']=check_A005930['예측 시가'].round()
check_A005935['예측 시가']=check_A005935['예측 시가'].round()
check_A005940['predict']=check_A005940['predict'].round()
check_A006280['예측 시가']=check_A006280['예측 시가'].round()
check_A006360['predict']=check_A006360['predict'].round()
check_A006400['예측 시가']=check_A006400['예측 시가'].round()
check_A006800['예측 시가']=check_A006800['예측 시가'].round()
check_A007070['예측 시가']=check_A007070['예측 시가'].round()
check_A008560['예측 시가']=check_A008560['예측 시가'].round()
check_A008770['예측 시가']=check_A008770['예측 시가'].round()
check_A008930['예측 시가']=check_A008930['예측 시가'].round()
check_A009150['예측 시가']=check_A009150['예측 시가'].round()
check_A009540['예측 시가']=check_A009540['예측 시가'].round()
check_A009830['예측 시가']=check_A009830['예측 시가'].round()
check_A010130['predict']=check_A010130['predict'].round()
check_A010140['예측 시가']=check_A010140['예측 시가'].round()
check_A010950['예측 시가']=check_A010950['예측 시가'].round()
check_A011070['predict']=check_A011070['predict'].round()
check_A011170['예측 시가']=check_A011170['예측 시가'].round()
check_A011200['predict']=check_A011200['predict'].round()
check_A011780['예측 시가']=check_A011780['예측 시가'].round()
check_A011790['predict']=check_A011790['predict'].round()
check_A012330['predict']=check_A012330['predict'].round()
check_A012510['predict']=check_A012510['predict'].round()
check_A012750['예측 시가']=check_A012750['예측 시가'].round()
check_A015760['predict']=check_A015760['predict'].round()
check_A016360['예측 시가']=check_A016360['예측 시가'].round()
check_A017670['예측 시가']=check_A017670['예측 시가'].round()
check_A018260['predict']=check_A018260['predict'].round()
check_A018880['예측 시가']=check_A018880['예측 시가'].round()
check_A021240['predict']=check_A021240['predict'].round()
check_A023530['predict']=check_A023530['predict'].round()
check_A024110['predict']=check_A024110['predict'].round()
check_A026960['예측 시가']=check_A026960['예측 시가'].round()
check_A028260['예측 시가']=check_A028260['예측 시가'].round()
check_A028670['predict']=check_A028670['predict'].round()
check_A029780['predict']=check_A029780['predict'].round()
check_A030200['predict']=check_A030200['predict'].round()
check_A032640['예측 시가']=check_A032640['예측 시가'].round()
check_A032830['예측 시가']=check_A032830['예측 시가'].round()
check_A033780['predict']=check_A033780['predict'].round()
check_A034020['predict']=check_A034020['predict'].round()
check_A034220['예측 시가']=check_A034220['예측 시가'].round()
check_A034730['predict']=check_A034730['predict'].round()
check_A035250['예측 시가']=check_A035250['예측 시가'].round()
check_A035420['predict']=check_A035420['predict'].round()
check_A035720['predict']=check_A035720['predict'].round()
check_A036460['predict']=check_A036460['predict'].round()
check_A036570['예측 시가']=check_A036570['예측 시가'].round()
check_A039490['예측 시가']=check_A039490['예측 시가'].round()
check_A047810['예측 시가']=check_A047810['예측 시가'].round()
check_A051900['predict']=check_A051900['predict'].round()
check_A051910['predict']=check_A051910['predict'].round()
check_A055550['predict']=check_A055550['predict'].round()
check_A066570['predict']=check_A066570['predict'].round()
check_A068270['예측 시가']=check_A068270['예측 시가'].round()
check_A071050['예측 시가']=check_A071050['예측 시가'].round()
check_A078930['predict']=check_A078930['predict'].round()
check_A086280['predict']=check_A086280['predict'].round()
check_A086790['predict']=check_A086790['predict'].round()
check_A090430['예측 시가']=check_A090430['예측 시가'].round()
check_A096770['예측 시가']=check_A096770['예측 시가'].round()
check_A097950['예측 시가']=check_A097950['예측 시가'].round()
check_A105560['predict']=check_A105560['predict'].round()
check_A128940['예측 시가']=check_A128940['예측 시가'].round()
check_A139480['예측 시가']=check_A139480['예측 시가'].round()
check_A161390['예측 시가']=check_A161390['예측 시가'].round()
check_A180640['predict']=check_A180640['predict'].round()
check_A204320['predict']=check_A204320['predict'].round()

# %%
y_future_check_A000100=check_A000100.loc[3170:3963,['predict']]
y_future_check_A000120=check_A000120.loc[3200:4000,['예측 시가']]
y_future_check_A000270=check_A000270.loc[3170:3963,['predict']]
y_future_check_A000660=check_A000660.loc[3200:4000,['예측 시가']]
y_future_check_A000720=check_A000720.loc[3170:3963,['predict']]
y_future_check_A000810=check_A000810.loc[3170:3963,['predict']]
y_future_check_A002790=check_A002790.loc[3170:3963,['predict']]
y_future_check_A003410=check_A003410.loc[3200:4000,['예측 시가']]
y_future_check_A003490=check_A003490.loc[3170:3963,['predict']]
y_future_check_A003550=check_A003550.loc[3200:4000,['예측 시가']]
y_future_check_A003670=check_A003670.loc[3170:3963,['predict']]
y_future_check_A004020=check_A004020.loc[3170:3963,['predict']]
y_future_check_A004990=check_A004990.loc[3170:3963,['predict']]
y_future_check_A005380=check_A005380.loc[3200:4000,['예측 시가']]
y_future_check_A005387=check_A005387.loc[3170:3963,['predict']]
y_future_check_A005490=check_A005490.loc[3170:3963,['predict']]
y_future_check_A005830=check_A005830.loc[3200:4000,['예측 시가']]
y_future_check_A005930=check_A005930.loc[3200:4000,['예측 시가']]
y_future_check_A005935=check_A005935.loc[3200:4000,['예측 시가']]
y_future_check_A005940=check_A005940.loc[3170:3963,['predict']]
y_future_check_A006280=check_A006280.loc[3200:4000,['예측 시가']]
y_future_check_A006360=check_A006360.loc[3170:3963,['predict']]
y_future_check_A006400=check_A006400.loc[3200:4000,['예측 시가']]
y_future_check_A006800=check_A006800.loc[3200:4000,['예측 시가']]
y_future_check_A007070=check_A007070.loc[3200:4000,['예측 시가']]
y_future_check_A008560=check_A008560.loc[3200:4000,['예측 시가']]
y_future_check_A008770=check_A008770.loc[3200:4000,['예측 시가']]
y_future_check_A008930=check_A008930.loc[3200:4000,['예측 시가']]
y_future_check_A009150=check_A009150.loc[3200:4000,['예측 시가']]
y_future_check_A009540=check_A009540.loc[3200:4000,['예측 시가']]
y_future_check_A009830=check_A009830.loc[3200:4000,['예측 시가']]
y_future_check_A010130=check_A010130.loc[3170:3963,['predict']]
y_future_check_A010140=check_A010140.loc[3200:4000,['예측 시가']]
y_future_check_A010950=check_A010950.loc[3200:4000,['예측 시가']]
y_future_check_A011070=check_A011070.loc[3170:3963,['predict']]
y_future_check_A011170=check_A011170.loc[3200:4000,['예측 시가']]
y_future_check_A011200=check_A011200.loc[3170:3963,['predict']]
y_future_check_A011780=check_A011780.loc[3200:4000,['예측 시가']]
y_future_check_A011790=check_A011790.loc[3170:3963,['predict']]
y_future_check_A012330=check_A012330.loc[3170:3963,['predict']]
y_future_check_A012510=check_A012510.loc[3170:3963,['predict']]
y_future_check_A012750=check_A012750.loc[3200:4000,['예측 시가']]
y_future_check_A015760=check_A015760.loc[3170:3963,['predict']]
y_future_check_A016360=check_A016360.loc[3200:4000,['예측 시가']]
y_future_check_A017670=check_A017670.loc[3200:4000,['예측 시가']]
y_future_check_A018260=check_A018260.loc[3170:3963,['predict']]
y_future_check_A018880=check_A018880.loc[3200:4000,['예측 시가']]
y_future_check_A021240=check_A021240.loc[3170:3963,['predict']]
y_future_check_A023530=check_A023530.loc[3170:3963,['predict']]
y_future_check_A024110=check_A024110.loc[3170:3963,['predict']]
y_future_check_A026960=check_A026960.loc[3200:4000,['예측 시가']]
y_future_check_A028260=check_A028260.loc[3200:4000,['예측 시가']]
y_future_check_A028670=check_A028670.loc[3170:3963,['predict']]
y_future_check_A029780=check_A029780.loc[3170:3963,['predict']]
y_future_check_A030200=check_A030200.loc[3170:3963,['predict']]
y_future_check_A032640=check_A032640.loc[3200:4000,['예측 시가']]
y_future_check_A032830=check_A032830.loc[3200:4000,['예측 시가']]
y_future_check_A033780=check_A033780.loc[3170:3963,['predict']]
y_future_check_A034020=check_A034020.loc[3170:3963,['predict']]
y_future_check_A034220=check_A034220.loc[3200:4000,['예측 시가']]
y_future_check_A034730=check_A034730.loc[3170:3963,['predict']]
y_future_check_A035250=check_A035250.loc[3200:4000,['예측 시가']]
y_future_check_A035420=check_A035420.loc[3170:3963,['predict']]
y_future_check_A035720=check_A035720.loc[3170:3963,['predict']]
y_future_check_A036460=check_A036460.loc[3170:3963,['predict']]
y_future_check_A036570=check_A036570.loc[3200:4000,['예측 시가']]
y_future_check_A039490=check_A039490.loc[3200:4000,['예측 시가']]
y_future_check_A047810=check_A047810.loc[3200:4000,['예측 시가']]
y_future_check_A051900=check_A051900.loc[3170:3963,['predict']]
y_future_check_A051910=check_A051910.loc[3170:3963,['predict']]
y_future_check_A055550=check_A055550.loc[3170:3963,['predict']]
y_future_check_A066570=check_A066570.loc[3170:3963,['predict']]
y_future_check_A068270=check_A068270.loc[3200:4000,['예측 시가']]
y_future_check_A071050=check_A071050.loc[3200:4000,['예측 시가']]
y_future_check_A078930=check_A078930.loc[3170:3963,['predict']]
y_future_check_A086280=check_A086280.loc[3170:3963,['predict']]
y_future_check_A086790=check_A086790.loc[3170:3963,['predict']]
y_future_check_A090430=check_A090430.loc[3200:4000,['예측 시가']]
y_future_check_A096770=check_A096770.loc[3200:4000,['예측 시가']]
y_future_check_A097950=check_A097950.loc[3200:4000,['예측 시가']]
y_future_check_A105560=check_A105560.loc[3170:3963,['predict']]
y_future_check_A128940=check_A128940.loc[3200:4000,['예측 시가']]
y_future_check_A139480=check_A139480.loc[3200:4000,['예측 시가']]
y_future_check_A161390=check_A161390.loc[3200:4000,['예측 시가']]
y_future_check_A180640=check_A180640.loc[3170:3963,['predict']]
y_future_check_A204320=check_A204320.loc[3170:3963,['predict']]

# %%
y_past_check_A000100=check_A000100.loc[0:3963,['Open']]
y_past_check_A000120=check_A000120.loc[0:4000,['실제 시가']]
y_past_check_A000270=check_A000270.loc[0:3963,['Open']]
y_past_check_A000660=check_A000660.loc[0:4000,['실제 시가']]
y_past_check_A000720=check_A000720.loc[0:3963,['Open']]
y_past_check_A000810=check_A000810.loc[0:3963,['Open']]
y_past_check_A002790=check_A002790.loc[0:3963,['Open']]
y_past_check_A003410=check_A003410.loc[0:4000,['실제 시가']]
y_past_check_A003490=check_A003490.loc[0:3963,['Open']]
y_past_check_A003550=check_A003550.loc[0:4000,['실제 시가']]
y_past_check_A003670=check_A003670.loc[0:3963,['Open']]
y_past_check_A004020=check_A004020.loc[0:3963,['Open']]
y_past_check_A004990=check_A004990.loc[0:3963,['Open']]
y_past_check_A005380=check_A005380.loc[0:4000,['실제 시가']]
y_past_check_A005387=check_A005387.loc[0:3963,['Open']]
y_past_check_A005490=check_A005490.loc[0:3963,['Open']]
y_past_check_A005830=check_A005830.loc[0:4000,['실제 시가']]
y_past_check_A005930=check_A005930.loc[0:4000,['실제 시가']]
y_past_check_A005935=check_A005935.loc[0:4000,['실제 시가']]
y_past_check_A005940=check_A005940.loc[0:3963,['Open']]
y_past_check_A006280=check_A006280.loc[0:4000,['실제 시가']]
y_past_check_A006360=check_A006360.loc[0:3963,['Open']]
y_past_check_A006400=check_A006400.loc[0:4000,['실제 시가']]
y_past_check_A006800=check_A006800.loc[0:4000,['실제 시가']]
y_past_check_A007070=check_A007070.loc[0:4000,['실제 시가']]
y_past_check_A008560=check_A008560.loc[0:4000,['실제 시가']]
y_past_check_A008770=check_A008770.loc[0:4000,['실제 시가']]
y_past_check_A008930=check_A008930.loc[0:4000,['실제 시가']]
y_past_check_A009150=check_A009150.loc[0:4000,['실제 시가']]
y_past_check_A009540=check_A009540.loc[0:4000,['실제 시가']]
y_past_check_A009830=check_A009830.loc[0:4000,['실제 시가']]
y_past_check_A010130=check_A010130.loc[0:3963,['Open']]
y_past_check_A010140=check_A010140.loc[0:4000,['실제 시가']]
y_past_check_A010950=check_A010950.loc[0:4000,['실제 시가']]
y_past_check_A011070=check_A011070.loc[0:3963,['Open']]
y_past_check_A011170=check_A011170.loc[0:4000,['실제 시가']]
y_past_check_A011200=check_A011200.loc[0:3963,['Open']]
y_past_check_A011780=check_A011780.loc[0:4000,['실제 시가']]
y_past_check_A011790=check_A011790.loc[0:3963,['Open']]
y_past_check_A012330=check_A012330.loc[0:3963,['Open']]
y_past_check_A012510=check_A012510.loc[0:3963,['Open']]
y_past_check_A012750=check_A012750.loc[0:4000,['실제 시가']]
y_past_check_A015760=check_A015760.loc[0:3963,['Open']]
y_past_check_A016360=check_A016360.loc[0:4000,['실제 시가']]
y_past_check_A017670=check_A017670.loc[0:4000,['실제 시가']]
y_past_check_A018260=check_A018260.loc[0:3963,['Open']]
y_past_check_A018880=check_A018880.loc[0:4000,['실제 시가']]
y_past_check_A021240=check_A021240.loc[0:3963,['Open']]
y_past_check_A023530=check_A023530.loc[0:3963,['Open']]
y_past_check_A024110=check_A024110.loc[0:3963,['Open']]
y_past_check_A026960=check_A026960.loc[0:4000,['실제 시가']]
y_past_check_A028260=check_A028260.loc[0:4000,['실제 시가']]
y_past_check_A028670=check_A028670.loc[0:3963,['Open']]
y_past_check_A029780=check_A029780.loc[0:3963,['Open']]
y_past_check_A030200=check_A030200.loc[0:3963,['Open']]
y_past_check_A032640=check_A032640.loc[0:4000,['실제 시가']]
y_past_check_A032830=check_A032830.loc[0:4000,['실제 시가']]
y_past_check_A033780=check_A033780.loc[0:3963,['Open']]
y_past_check_A034020=check_A034020.loc[0:3963,['Open']]
y_past_check_A034220=check_A034220.loc[0:4000,['실제 시가']]
y_past_check_A034730=check_A034730.loc[0:3963,['Open']]
y_past_check_A035250=check_A035250.loc[0:4000,['실제 시가']]
y_past_check_A035420=check_A035420.loc[0:3963,['Open']]
y_past_check_A035720=check_A035720.loc[0:3963,['Open']]
y_past_check_A036460=check_A036460.loc[0:3963,['Open']]
y_past_check_A036570=check_A036570.loc[0:4000,['실제 시가']]
y_past_check_A039490=check_A039490.loc[0:4000,['실제 시가']]
y_past_check_A047810=check_A047810.loc[0:4000,['실제 시가']]
y_past_check_A051900=check_A051900.loc[0:3963,['Open']]
y_past_check_A051910=check_A051910.loc[0:3963,['Open']]
y_past_check_A055550=check_A055550.loc[0:3963,['Open']]
y_past_check_A066570=check_A066570.loc[0:3963,['Open']]
y_past_check_A068270=check_A068270.loc[0:4000,['실제 시가']]
y_past_check_A071050=check_A071050.loc[0:4000,['실제 시가']]
y_past_check_A078930=check_A078930.loc[0:3963,['Open']]
y_past_check_A086280=check_A086280.loc[0:3963,['Open']]
y_past_check_A086790=check_A086790.loc[0:3963,['Open']]
y_past_check_A090430=check_A090430.loc[0:4000,['실제 시가']]
y_past_check_A096770=check_A096770.loc[0:4000,['실제 시가']]
y_past_check_A097950=check_A097950.loc[0:4000,['실제 시가']]
y_past_check_A105560=check_A105560.loc[0:3963,['Open']]
y_past_check_A128940=check_A128940.loc[0:4000,['실제 시가']]
y_past_check_A139480=check_A139480.loc[0:4000,['실제 시가']]
y_past_check_A161390=check_A161390.loc[0:4000,['실제 시가']]
y_past_check_A180640=check_A180640.loc[0:3963,['Open']]
y_past_check_A204320=check_A204320.loc[0:3963,['Open']]

# %%
x_future_check_A000100=check_A000100.loc[3170:3963,['Date']]
x_future_check_A000120=check_A000120.loc[3200:4000,['Date']]
x_future_check_A000270=check_A000270.loc[3170:3963,['Date']]
x_future_check_A000660=check_A000660.loc[3200:4000,['Date']]
x_future_check_A000720=check_A000720.loc[3170:3963,['Date']]
x_future_check_A000810=check_A000810.loc[3170:3963,['Date']]
x_future_check_A002790=check_A002790.loc[3170:3963,['Date']]
x_future_check_A003410=check_A003410.loc[3200:4000,['Date']]
x_future_check_A003490=check_A003490.loc[3170:3963,['Date']]
x_future_check_A003550=check_A003550.loc[3200:4000,['Date']]
x_future_check_A003670=check_A003670.loc[3170:3963,['Date']]
x_future_check_A004020=check_A004020.loc[3170:3963,['Date']]
x_future_check_A004990=check_A004990.loc[3170:3963,['Date']]
x_future_check_A005380=check_A005380.loc[3200:4000,['Date']]
x_future_check_A005387=check_A005387.loc[3170:3963,['Date']]
x_future_check_A005490=check_A005490.loc[3170:3963,['Date']]
x_future_check_A005830=check_A005830.loc[3200:4000,['Date']]
x_future_check_A005930=check_A005930.loc[3200:4000,['Date']]
x_future_check_A005935=check_A005935.loc[3200:4000,['Date']]
x_future_check_A005940=check_A005940.loc[3170:3963,['Date']]
x_future_check_A006280=check_A006280.loc[3200:4000,['Date']]
x_future_check_A006360=check_A006360.loc[3170:3963,['Date']]
x_future_check_A006400=check_A006400.loc[3200:4000,['Date']]
x_future_check_A006800=check_A006800.loc[3200:4000,['Date']]
x_future_check_A007070=check_A007070.loc[3200:4000,['Date']]
x_future_check_A008560=check_A008560.loc[3200:4000,['Date']]
x_future_check_A008770=check_A008770.loc[3200:4000,['Date']]
x_future_check_A008930=check_A008930.loc[3200:4000,['Date']]
x_future_check_A009150=check_A009150.loc[3200:4000,['Date']]
x_future_check_A009540=check_A009540.loc[3200:4000,['Date']]
x_future_check_A009830=check_A009830.loc[3200:4000,['Date']]
x_future_check_A010130=check_A010130.loc[3170:3963,['Date']]
x_future_check_A010140=check_A010140.loc[3200:4000,['Date']]
x_future_check_A010950=check_A010950.loc[3200:4000,['Date']]
x_future_check_A011070=check_A011070.loc[3170:3963,['Date']]
x_future_check_A011170=check_A011170.loc[3200:4000,['Date']]
x_future_check_A011200=check_A011200.loc[3170:3963,['Date']]
x_future_check_A011780=check_A011780.loc[3200:4000,['Date']]
x_future_check_A011790=check_A011790.loc[3170:3963,['Date']]
x_future_check_A012330=check_A012330.loc[3170:3963,['Date']]
x_future_check_A012510=check_A012510.loc[3170:3963,['Date']]
x_future_check_A012750=check_A012750.loc[3200:4000,['Date']]
x_future_check_A015760=check_A015760.loc[3170:3963,['Date']]
x_future_check_A016360=check_A016360.loc[3200:4000,['Date']]
x_future_check_A017670=check_A017670.loc[3200:4000,['Date']]
x_future_check_A018260=check_A018260.loc[3170:3963,['Date']]
x_future_check_A018880=check_A018880.loc[3200:4000,['Date']]
x_future_check_A021240=check_A021240.loc[3170:3963,['Date']]
x_future_check_A023530=check_A023530.loc[3170:3963,['Date']]
x_future_check_A024110=check_A024110.loc[3170:3963,['Date']]
x_future_check_A026960=check_A026960.loc[3200:4000,['Date']]
x_future_check_A028260=check_A028260.loc[3200:4000,['Date']]
x_future_check_A028670=check_A028670.loc[3170:3963,['Date']]
x_future_check_A029780=check_A029780.loc[3170:3963,['Date']]
x_future_check_A030200=check_A030200.loc[3170:3963,['Date']]
x_future_check_A032640=check_A032640.loc[3200:4000,['Date']]
x_future_check_A032830=check_A032830.loc[3200:4000,['Date']]
x_future_check_A033780=check_A033780.loc[3170:3963,['Date']]
x_future_check_A034020=check_A034020.loc[3170:3963,['Date']]
x_future_check_A034220=check_A034220.loc[3200:4000,['Date']]
x_future_check_A034730=check_A034730.loc[3170:3963,['Date']]
x_future_check_A035250=check_A035250.loc[3200:4000,['Date']]
x_future_check_A035420=check_A035420.loc[3170:3963,['Date']]
x_future_check_A035720=check_A035720.loc[3170:3963,['Date']]
x_future_check_A036460=check_A036460.loc[3170:3963,['Date']]
x_future_check_A036570=check_A036570.loc[3200:4000,['Date']]
x_future_check_A039490=check_A039490.loc[3200:4000,['Date']]
x_future_check_A047810=check_A047810.loc[3200:4000,['Date']]
x_future_check_A051900=check_A051900.loc[3170:3963,['Date']]
x_future_check_A051910=check_A051910.loc[3170:3963,['Date']]
x_future_check_A055550=check_A055550.loc[3170:3963,['Date']]
x_future_check_A066570=check_A066570.loc[3170:3963,['Date']]
x_future_check_A068270=check_A068270.loc[3200:4000,['Date']]
x_future_check_A071050=check_A071050.loc[3200:4000,['Date']]
x_future_check_A078930=check_A078930.loc[3170:3963,['Date']]
x_future_check_A086280=check_A086280.loc[3170:3963,['Date']]
x_future_check_A086790=check_A086790.loc[3170:3963,['Date']]
x_future_check_A090430=check_A090430.loc[3200:4000,['Date']]
x_future_check_A096770=check_A096770.loc[3200:4000,['Date']]
x_future_check_A097950=check_A097950.loc[3200:4000,['Date']]
x_future_check_A105560=check_A105560.loc[3170:3963,['Date']]
x_future_check_A128940=check_A128940.loc[3200:4000,['Date']]
x_future_check_A139480=check_A139480.loc[3200:4000,['Date']]
x_future_check_A161390=check_A161390.loc[3200:4000,['Date']]
x_future_check_A180640=check_A180640.loc[3170:3963,['Date']]
x_future_check_A204320=check_A204320.loc[3170:3963,['Date']]

# %%
x_past_check_A000100=check_A000100.loc[0:3963,['Date']]
x_past_check_A000120=check_A000120.loc[0:4000,['Date']]
x_past_check_A000270=check_A000270.loc[0:3963,['Date']]
x_past_check_A000660=check_A000660.loc[0:4000,['Date']]
x_past_check_A000720=check_A000720.loc[0:3963,['Date']]
x_past_check_A000810=check_A000810.loc[0:3963,['Date']]
x_past_check_A002790=check_A002790.loc[0:3963,['Date']]
x_past_check_A003410=check_A003410.loc[0:4000,['Date']]
x_past_check_A003490=check_A003490.loc[0:3963,['Date']]
x_past_check_A003550=check_A003550.loc[0:4000,['Date']]
x_past_check_A003670=check_A003670.loc[0:3963,['Date']]
x_past_check_A004020=check_A004020.loc[0:3963,['Date']]
x_past_check_A004990=check_A004990.loc[0:3963,['Date']]
x_past_check_A005380=check_A005380.loc[0:4000,['Date']]
x_past_check_A005387=check_A005387.loc[0:3963,['Date']]
x_past_check_A005490=check_A005490.loc[0:3963,['Date']]
x_past_check_A005830=check_A005830.loc[0:4000,['Date']]
x_past_check_A005930=check_A005930.loc[0:4000,['Date']]
x_past_check_A005935=check_A005935.loc[0:4000,['Date']]
x_past_check_A005940=check_A005940.loc[0:3963,['Date']]
x_past_check_A006280=check_A006280.loc[0:4000,['Date']]
x_past_check_A006360=check_A006360.loc[0:3963,['Date']]
x_past_check_A006400=check_A006400.loc[0:4000,['Date']]
x_past_check_A006800=check_A006800.loc[0:4000,['Date']]
x_past_check_A007070=check_A007070.loc[0:4000,['Date']]
x_past_check_A008560=check_A008560.loc[0:4000,['Date']]
x_past_check_A008770=check_A008770.loc[0:4000,['Date']]
x_past_check_A008930=check_A008930.loc[0:4000,['Date']]
x_past_check_A009150=check_A009150.loc[0:4000,['Date']]
x_past_check_A009540=check_A009540.loc[0:4000,['Date']]
x_past_check_A009830=check_A009830.loc[0:4000,['Date']]
x_past_check_A010130=check_A010130.loc[0:3963,['Date']]
x_past_check_A010140=check_A010140.loc[0:4000,['Date']]
x_past_check_A010950=check_A010950.loc[0:4000,['Date']]
x_past_check_A011070=check_A011070.loc[0:3963,['Date']]
x_past_check_A011170=check_A011170.loc[0:4000,['Date']]
x_past_check_A011200=check_A011200.loc[0:3963,['Date']]
x_past_check_A011780=check_A011780.loc[0:4000,['Date']]
x_past_check_A011790=check_A011790.loc[0:3963,['Date']]
x_past_check_A012330=check_A012330.loc[0:3963,['Date']]
x_past_check_A012510=check_A012510.loc[0:3963,['Date']]
x_past_check_A012750=check_A012750.loc[0:4000,['Date']]
x_past_check_A015760=check_A015760.loc[0:3963,['Date']]
x_past_check_A016360=check_A016360.loc[0:4000,['Date']]
x_past_check_A017670=check_A017670.loc[0:4000,['Date']]
x_past_check_A018260=check_A018260.loc[0:3963,['Date']]
x_past_check_A018880=check_A018880.loc[0:4000,['Date']]
x_past_check_A021240=check_A021240.loc[0:3963,['Date']]
x_past_check_A023530=check_A023530.loc[0:3963,['Date']]
x_past_check_A024110=check_A024110.loc[0:3963,['Date']]
x_past_check_A026960=check_A026960.loc[0:4000,['Date']]
x_past_check_A028260=check_A028260.loc[0:4000,['Date']]
x_past_check_A028670=check_A028670.loc[0:3963,['Date']]
x_past_check_A029780=check_A029780.loc[0:3963,['Date']]
x_past_check_A030200=check_A030200.loc[0:3963,['Date']]
x_past_check_A032640=check_A032640.loc[0:4000,['Date']]
x_past_check_A032830=check_A032830.loc[0:4000,['Date']]
x_past_check_A033780=check_A033780.loc[0:3963,['Date']]
x_past_check_A034020=check_A034020.loc[0:3963,['Date']]
x_past_check_A034220=check_A034220.loc[0:4000,['Date']]
x_past_check_A034730=check_A034730.loc[0:3963,['Date']]
x_past_check_A035250=check_A035250.loc[0:4000,['Date']]
x_past_check_A035420=check_A035420.loc[0:3963,['Date']]
x_past_check_A035720=check_A035720.loc[0:3963,['Date']]
x_past_check_A036460=check_A036460.loc[0:3963,['Date']]
x_past_check_A036570=check_A036570.loc[0:4000,['Date']]
x_past_check_A039490=check_A039490.loc[0:4000,['Date']]
x_past_check_A047810=check_A047810.loc[0:4000,['Date']]
x_past_check_A051900=check_A051900.loc[0:3963,['Date']]
x_past_check_A051910=check_A051910.loc[0:3963,['Date']]
x_past_check_A055550=check_A055550.loc[0:3963,['Date']]
x_past_check_A066570=check_A066570.loc[0:3963,['Date']]
x_past_check_A068270=check_A068270.loc[0:4000,['Date']]
x_past_check_A071050=check_A071050.loc[0:4000,['Date']]
x_past_check_A078930=check_A078930.loc[0:3963,['Date']]
x_past_check_A086280=check_A086280.loc[0:3963,['Date']]
x_past_check_A086790=check_A086790.loc[0:3963,['Date']]
x_past_check_A090430=check_A090430.loc[0:4000,['Date']]
x_past_check_A096770=check_A096770.loc[0:4000,['Date']]
x_past_check_A097950=check_A097950.loc[0:4000,['Date']]
x_past_check_A105560=check_A105560.loc[0:3963,['Date']]
x_past_check_A128940=check_A128940.loc[0:4000,['Date']]
x_past_check_A139480=check_A139480.loc[0:4000,['Date']]
x_past_check_A161390=check_A161390.loc[0:4000,['Date']]
x_past_check_A180640=check_A180640.loc[0:3963,['Date']]
x_past_check_A204320=check_A204320.loc[0:3963,['Date']]

# %%
performance=pd.read_excel("performance_87code.xlsx")

# %%
dataframe = {'종목코드':csv_list, '종목명':stock, 'SMAPE':performance.SMAPE, 'MASE': performance.MASE}
#new_prediction_data
df1 = pd.DataFrame(dataframe)

# %%
def check_plot(stock):
    df2=df1[df1['종목명']==stock]
    print(df2)
    if stock=='유한양행': 
        p=plt.plot(x_past_check_A000100,y_past_check_A000100,label='유한양행_Open')
        p=plt.plot(x_future_check_A000100,y_future_check_A000100,label='유한양행_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='CJ대한통운': 
        p=plt.plot(x_past_check_A000120,y_past_check_A000120,label='CJ대한통운_Open')
        p=plt.plot(x_future_check_A000120,y_future_check_A000120,label='CJ대한통운_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='기아차': 
        p=plt.plot(x_past_check_A000270,y_past_check_A000270,label='기아차_Open')
        p=plt.plot(x_future_check_A000270,y_future_check_A000270,label='기아차_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK하이닉스': 
        p=plt.plot(x_past_check_A000660,y_past_check_A000660,label='SK하이닉스_Open')
        p=plt.plot(x_future_check_A000660,y_future_check_A000660,label='SK하이닉스_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대건설': 
        p=plt.plot(x_past_check_A000720,y_past_check_A000720,label='현대건설_Open')
        p=plt.plot(x_future_check_A000720,y_future_check_A000720,label='현대건설_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성화재': 
        p=plt.plot(x_past_check_A000810,y_past_check_A000810,label='삼성화재_Open')
        p=plt.plot(x_future_check_A000810,y_future_check_A000810,label='삼성화재_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='아모레G': 
        p=plt.plot(x_past_check_A002790,y_past_check_A002790,label='아모레G_Open')
        p=plt.plot(x_future_check_A002790,y_future_check_A002790,label='아모레G_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='쌍용양회': 
        p=plt.plot(x_past_check_A003410,y_past_check_A003410,label='쌍용양회_Open')
        p=plt.plot(x_future_check_A003410,y_future_check_A003410,label='쌍용양회_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='대한항공': 
        p=plt.plot(x_past_check_A003490,y_past_check_A003490,label='대한항공_Open')
        p=plt.plot(x_future_check_A003490,y_future_check_A003490,label='대한항공_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG': 
        p=plt.plot(x_past_check_A003550,y_past_check_A003550,label='LG_Open')
        p=plt.plot(x_future_check_A003550,y_future_check_A003550,label='LG_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='포스코케미칼': 
        p=plt.plot(x_past_check_A003670,y_past_check_A003670,label='포스코케미칼_Open')
        p=plt.plot(x_future_check_A003670,y_future_check_A003670,label='포스코케미칼_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대제철': 
        p=plt.plot(x_past_check_A004020,y_past_check_A004020,label='현대제철_Open')
        p=plt.plot(x_future_check_A004020,y_future_check_A004020,label='현대제철_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='롯데지주': 
        p=plt.plot(x_past_check_A004990,y_past_check_A004990,label='롯데지주_Open')
        p=plt.plot(x_future_check_A004990,y_future_check_A004990,label='롯데지주_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대차': 
        p=plt.plot(x_past_check_A005380,y_past_check_A005380,label='현대차_Open')
        p=plt.plot(x_future_check_A005380,y_future_check_A005380,label='현대차_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대차2우B': 
        p=plt.plot(x_past_check_A005387,y_past_check_A005387,label='현대차2우B_Open')
        p=plt.plot(x_future_check_A005387,y_future_check_A005387,label='현대차2우B_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='POSCO': 
        p=plt.plot(x_past_check_A005490,y_past_check_A005490,label='POSCO_Open')
        p=plt.plot(x_future_check_A005490,y_future_check_A005490,label='POSCO_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='DB손해보험': 
        p=plt.plot(x_past_check_A005830,y_past_check_A005830,label='DB손해보험_Open')
        p=plt.plot(x_future_check_A005830,y_future_check_A005830,label='DB손해보험_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성전자': 
        p=plt.plot(x_past_check_A005930,y_past_check_A005930,label='삼성전자_Open')
        p=plt.plot(x_future_check_A005930,y_future_check_A005930,label='삼성전자_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성전자우': 
        p=plt.plot(x_past_check_A005935,y_past_check_A005935,label='삼성전자우_Open')
        p=plt.plot(x_future_check_A005935,y_future_check_A005935,label='삼성전자우_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='NH투자증권': 
        p=plt.plot(x_past_check_A005940,y_past_check_A005940,label='NH투자증권_Open')
        p=plt.plot(x_future_check_A005940,y_future_check_A005940,label='NH투자증권_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='녹십자': 
        p=plt.plot(x_past_check_A006280,y_past_check_A006280,label='녹십자_Open')
        p=plt.plot(x_future_check_A006280,y_future_check_A006280,label='녹십자_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='GS건설': 
        p=plt.plot(x_past_check_A006360,y_past_check_A006360,label='GS건설_Open')
        p=plt.plot(x_future_check_A006360,y_future_check_A006360,label='GS건설_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성SDI': 
        p=plt.plot(x_past_check_A006400,y_past_check_A006400,label='삼성SDI_Open')
        p=plt.plot(x_future_check_A006400,y_future_check_A006400,label='삼성SDI_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='미래에셋대우': 
        p=plt.plot(x_past_check_A006800,y_past_check_A006800,label='미래에셋대우_Open')
        p=plt.plot(x_future_check_A006800,y_future_check_A006800,label='미래에셋대우_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='GS리테일': 
        p=plt.plot(x_past_check_A007070,y_past_check_A007070,label='GS리테일_Open')
        p=plt.plot(x_future_check_A007070,y_future_check_A007070,label='GS리테일_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='메리츠증권': 
        p=plt.plot(x_past_check_A008560,y_past_check_A008560,label='메리츠증권_Open')
        p=plt.plot(x_future_check_A008560,y_future_check_A008560,label='메리츠증권_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='호텔신라': 
        p=plt.plot(x_past_check_A008770,y_past_check_A008770,label='호텔신라_Open')
        p=plt.plot(x_future_check_A008770,y_future_check_A008770,label='호텔신라_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한미사이언스': 
        p=plt.plot(x_past_check_A008930,y_past_check_A008930,label='한미사이언스_Open')
        p=plt.plot(x_future_check_A008930,y_future_check_A008930,label='한미사이언스_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성전기': 
        p=plt.plot(x_past_check_A009150,y_past_check_A009150,label='삼성전기_Open')
        p=plt.plot(x_future_check_A009150,y_future_check_A009150,label='삼성전기_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국조선해양': 
        p=plt.plot(x_past_check_A009540,y_past_check_A009540,label='한국조선해양_Open')
        p=plt.plot(x_future_check_A009540,y_future_check_A009540,label='한국조선해양_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한화솔루션': 
        p=plt.plot(x_past_check_A009830,y_past_check_A009830,label='한화솔루션_Open')
        p=plt.plot(x_future_check_A009830,y_future_check_A009830,label='한화솔루션_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='고려아연': 
        p=plt.plot(x_past_check_A010130,y_past_check_A010130,label='고려아연_Open')
        p=plt.plot(x_future_check_A010130,y_future_check_A010130,label='고려아연_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성중공업': 
        p=plt.plot(x_past_check_A010140,y_past_check_A010140,label='삼성중공업_Open')
        p=plt.plot(x_future_check_A010140,y_future_check_A010140,label='삼성중공업_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='S-Oil': 
        p=plt.plot(x_past_check_A010950,y_past_check_A010950,label='S-Oil_Open')
        p=plt.plot(x_future_check_A010950,y_future_check_A010950,label='S-Oil_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG이노텍': 
        p=plt.plot(x_past_check_A011070,y_past_check_A011070,label='LG이노텍_Open')
        p=plt.plot(x_future_check_A011070,y_future_check_A011070,label='LG이노텍_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='롯데케미칼': 
        p=plt.plot(x_past_check_A011170,y_past_check_A011170,label='롯데케미칼_Open')
        p=plt.plot(x_future_check_A011170,y_future_check_A011170,label='롯데케미칼_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='HMM': 
        p=plt.plot(x_past_check_A011200,y_past_check_A011200,label='HMM_Open')
        p=plt.plot(x_future_check_A011200,y_future_check_A011200,label='HMM_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='금호석유': 
        p=plt.plot(x_past_check_A011780,y_past_check_A011780,label='금호석유_Open')
        p=plt.plot(x_future_check_A011780,y_future_check_A011780,label='금호석유_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SKC': 
        p=plt.plot(x_past_check_A011790,y_past_check_A011790,label='SKC_Open')
        p=plt.plot(x_future_check_A011790,y_future_check_A011790,label='SKC_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대모비스': 
        p=plt.plot(x_past_check_A012330,y_past_check_A012330,label='현대모비스_Open')
        p=plt.plot(x_future_check_A012330,y_future_check_A012330,label='현대모비스_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='더존비즈온': 
        p=plt.plot(x_past_check_A012510,y_past_check_A012510,label='더존비즈온_Open')
        p=plt.plot(x_future_check_A012510,y_future_check_A012510,label='더존비즈온_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='에스원': 
        p=plt.plot(x_past_check_A012750,y_past_check_A012750,label='에스원_Open')
        p=plt.plot(x_future_check_A012750,y_future_check_A012750,label='에스원_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국전력': 
        p=plt.plot(x_past_check_A015760,y_past_check_A015760,label='한국전력_Open')
        p=plt.plot(x_future_check_A015760,y_future_check_A015760,label='한국전력_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성증권': 
        p=plt.plot(x_past_check_A016360,y_past_check_A016360,label='삼성증권_Open')
        p=plt.plot(x_future_check_A016360,y_future_check_A016360,label='삼성증권_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK텔레콤': 
        p=plt.plot(x_past_check_A017670,y_past_check_A017670,label='SK텔레콤_Open')
        p=plt.plot(x_future_check_A017670,y_future_check_A017670,label='SK텔레콤_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성에스디에스': 
        p=plt.plot(x_past_check_A018260,y_past_check_A018260,label='삼성에스디에스_Open')
        p=plt.plot(x_future_check_A018260,y_future_check_A018260,label='삼성에스디에스_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한온시스템': 
        p=plt.plot(x_past_check_A018880,y_past_check_A018880,label='한온시스템_Open')
        p=plt.plot(x_future_check_A018880,y_future_check_A018880,label='한온시스템_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='코웨이': 
        p=plt.plot(x_past_check_A021240,y_past_check_A021240,label='코웨이_Open')
        p=plt.plot(x_future_check_A021240,y_future_check_A021240,label='코웨이_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='롯데쇼핑': 
        p=plt.plot(x_past_check_A023530,y_past_check_A023530,label='롯데쇼핑_Open')
        p=plt.plot(x_future_check_A023530,y_future_check_A023530,label='롯데쇼핑_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='기업은행': 
        p=plt.plot(x_past_check_A024110,y_past_check_A024110,label='기업은행_Open')
        p=plt.plot(x_future_check_A024110,y_future_check_A024110,label='기업은행_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='동서': 
        p=plt.plot(x_past_check_A026960,y_past_check_A026960,label='동서_Open')
        p=plt.plot(x_future_check_A026960,y_future_check_A026960,label='동서_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성물산': 
        p=plt.plot(x_past_check_A028260,y_past_check_A028260,label='삼성물산_Open')
        p=plt.plot(x_future_check_A028260,y_future_check_A028260,label='삼성물산_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='팬오션': 
        p=plt.plot(x_past_check_A028670,y_past_check_A028670label='팬오션_Open')
        p=plt.plot(x_future_check_A028670,y_future_check_A028670,label='팬오션_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성카드': 
        p=plt.plot(x_past_check_A029780,y_past_check_A029780,label='삼성카드_Open')
        p=plt.plot(x_future_check_A029780,y_future_check_A029780,label='삼성카드_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='KT': 
        p=plt.plot(x_past_check_A030200,y_past_check_A030200,label='KT_Open')
        p=plt.plot(x_future_check_A030200,y_future_check_A030200label='KT_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG유플러스': 
        p=plt.plot(x_past_check_A032640,y_past_check_A032640,label='LG유플러스_Open')
        p=plt.plot(x_future_check_A032640,y_future_check_A032640,label='LG유플러스_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성생명': 
        p=plt.plot(x_past_check_A032830,y_past_check_A032830,label='삼성생명_Open')
        p=plt.plot(x_future_check_A032830,y_future_check_A032830,label='삼성생명_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='KT&G': 
        p=plt.plot(x_past_check_A033780,y_past_check_A033780,label='KT&G_Open')
        p=plt.plot(x_future_check_A033780,y_future_check_A033780,label='KT&G_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='두산중공업': 
        p=plt.plot(x_past_check_A034020,y_past_check_A034020,label='두산중공업_Open')
        p=plt.plot(x_future_check_A034020,y_future_check_A034020,label='두산중공업_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG디스플레이': 
        p=plt.plot(x_past_check_A034220,y_past_check_A034220,label='LG디스플레이_Open')
        p=plt.plot(x_future_check_A034220,y_future_check_A034220,label='LG디스플레이_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK': 
        p=plt.plot(x_past_check_A034730,y_past_check_A034730,label='SK_Open')
        p=plt.plot(x_future_check_A034730,y_future_check_A034730,label='SK_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='강원랜드': 
        p=plt.plot(x_past_check_A035250,y_past_check_A035250,label='강원랜드_Open')
        p=plt.plot(x_future_check_A035250,y_future_check_A035250,label='강원랜드_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='NAVER': 
        p=plt.plot(x_past_check_A035420,y_past_check_A035420,label='NAVER_Open')
        p=plt.plot(x_future_check_A035420,y_future_check_A035420,label='NAVER_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='카카오': 
        p=plt.plot(x_past_check_A035720,y_past_check_A035720,label='카카오_Open')
        p=plt.plot(x_future_check_A035720,y_future_check_A035720,label='카카오_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국가스공사': 
        p=plt.plot(x_past_check_A036460,y_past_check_A036460,label='한국가스공사_Open')
        p=plt.plot(x_future_check_A036460,y_future_check_A036460,label='한국가스공사_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='엔씨소프트': 
        p=plt.plot(x_past_check_A036570,y_past_check_A036570,label='엔씨소프트_Open')
        p=plt.plot(x_future_check_A036570,y_future_check_A036570,label='엔씨소프트_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='키움증권': 
        p=plt.plot(x_past_check_A039490,y_past_check_A039490,label='키움증권_Open')
        p=plt.plot(x_future_check_A039490,y_future_check_A039490,label='키움증권_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국항공우주': 
        p=plt.plot(x_past_check_A047810,y_past_check_A047810,label='한국항공우주_Open')
        p=plt.plot(x_future_check_A047810,y_future_check_A047810,label='한국항공우주_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG생활건강': 
        p=plt.plot(x_past_check_A051900,y_past_check_A051900,label='LG생활건강_Open')
        p=plt.plot(x_future_check_A051900,y_future_check_A051900,label='LG생활건강_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG화학': 
        p=plt.plot(x_past_check_A051910,y_past_check_A051910,label='LG화학_Open')
        p=plt.plot(x_future_check_A051910,y_future_check_A051910,label='LG화학_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='신한지주': 
        p=plt.plot(x_past_check_A055550,y_past_check_A055550,label='신한지주_Open')
        p=plt.plot(x_future_check_A055550,y_future_check_A055550,label='신한지주_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG전자': 
        p=plt.plot(x_past_check_A066570,y_past_check_A066570,label='LG전자_Open')
        p=plt.plot(x_future_check_A066570,y_future_check_A066570,label='LG전자_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='셀트리온': 
        p=plt.plot(x_past_check_A068270,y_past_check_A068270,label='셀트리온_Open')
        p=plt.plot(x_future_check_A068270,y_future_check_A068270,label='셀트리온_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국금융지주': 
        p=plt.plot(x_past_check_A071050,y_past_check_A071050,label='한국금융지주_Open')
        p=plt.plot(x_future_check_A071050,y_future_check_A071050,label='한국금융지주_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='GS': 
        p=plt.plot(x_past_check_A078930,y_past_check_A078930,label='GS_Open')
        p=plt.plot(x_future_check_A078930,y_future_check_A078930,label='GS_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대글로비스': 
        p=plt.plot(x_past_check_A086280,y_past_check_A086280,label='현대글로비스_Open')
        p=plt.plot(x_future_check_A086280,y_future_check_A086280,label='현대글로비스_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='하나금융지주': 
        p=plt.plot(x_past_check_A086790,y_past_check_A086790,label='하나금융지주_Open')
        p=plt.plot(x_future_check_A086790,y_future_check_A086790,label='하나금융지주_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='아모레퍼시픽': 
        p=plt.plot(x_past_check_A090430,y_past_check_A0904300,label='아모레퍼시픽_Open')
        p=plt.plot(x_future_check_A090430,y_future_check_A090430,label='아모레퍼시픽_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK이노베이션': 
        p=plt.plot(x_past_check_A096770,y_past_check_A096770,label='SK이노베이션_Open')
        p=plt.plot(x_future_check_A096770,y_future_check_A096770,label='SK이노베이션_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='CJ제일제당': 
        p=plt.plot(x_past_check_A097950,y_past_check_A097950,label='CJ제일제당_Open')
        p=plt.plot(x_future_check_A097950,y_future_check_A097950,label='CJ제일제당_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='KB금융': 
        p=plt.plot(x_past_check_A105560,y_past_check_A105560,label='KB금융_Open')
        p=plt.plot(x_future_check_A105560,y_future_check_A105560,label='KB금융_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한미약품': 
        p=plt.plot(x_past_check_A128940,y_past_check_A128940,label='한미약품_Open')
        p=plt.plot(x_future_check_A128940,y_future_check_A128940,label='한미약품_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='이마트': 
        p=plt.plot(x_past_check_A139480,y_past_check_A139480,label='이마트_Open')
        p=plt.plot(x_future_check_A139480,y_future_check_A139480,label='이마트_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국타이어앤테크놀로지': 
        p=plt.plot(x_past_check_A161390,y_past_check_A161390,label='한국타이어앤테크놀로지_Open')
        p=plt.plot(x_future_check_A161390,y_future_check_A1613900,label='한국타이어앤테크놀로지_Test',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한진칼': 
        p=plt.plot(x_past_check_A180640,y_past_check_A180640,label='한진칼_Open')
        p=plt.plot(x_future_check_A180640,y_future_check_A1806400,label='한진칼_Test',color='red')
        datacursor(p)
        plt.legend()
    else: 
        p=plt.plot(x_past_check_A204320,y_past_check_A204320,label='만도_Open')
        p=plt.plot(x_future_check_A204320,y_future_check_A204320,label='만도_Test',color='red')
        datacursor(p)
        plt.legend()

    plt.rc('axes', unicode_minus=False)
    plt.show()

# %%
widgets.interactive(check_plot, stock=stock)
# Out:
# interactive(children=(Dropdown(description='stock', options=('유한양행', 'CJ대한통운', '기아차', 'SK하이닉스', '현대건설', '삼성화재'…

# %%
print("\n\n\n\n\n\n")

# %% [markdown]
# ### 현재 시점에서는 알 수 없는 미래의 실제 성능을 보기 위한 그래프를 확인하세요!

# %% [markdown]
# #### 현재 시점(2020/12/18)에서는 알 수 없지만 성능을 알아보기 위해 미래의 실제 주가와 예측한 주가를 비교한 그래프입니다.

# %%
y2_future_predict_A000100=predict_A000100.loc[3170:3963,['예측 시가']]
y2_future_predict_A000120=predict_A000120.loc[3200:4000,['예측 시가']]
y2_future_predict_A000270=predict_A000270.loc[3170:3963,['예측 시가']]
y2_future_predict_A000660=predict_A000660.loc[3200:4000,['예측 시가']]
y2_future_predict_A000720=predict_A000720.loc[3170:3963,['예측 시가']]
y2_future_predict_A000810=predict_A000810.loc[3170:3963,['예측 시가']]
y2_future_predict_A002790=predict_A002790.loc[3170:3963,['예측 시가']]
y2_future_predict_A003410=predict_A003410.loc[3200:4000,['예측 시가']]
y2_future_predict_A003490=predict_A003490.loc[3170:3963,['예측 시가']]
y2_future_predict_A003550=predict_A003550.loc[3200:4000,['예측 시가']]
y2_future_predict_A003670=predict_A003670.loc[3170:3963,['예측 시가']]
y2_future_predict_A004020=predict_A004020.loc[3170:3963,['예측 시가']]
y2_future_predict_A004990=predict_A004990.loc[3170:3963,['예측 시가']]
y2_future_predict_A005380=predict_A005380.loc[3200:4000,['예측 시가']]
y2_future_predict_A005387=predict_A005387.loc[3170:3963,['예측 시가']]
y2_future_predict_A005490=predict_A005490.loc[3170:3963,['예측 시가']]
y2_future_predict_A005830=predict_A005830.loc[3200:4000,['예측 시가']]
y2_future_predict_A005930=predict_A005930.loc[3200:4000,['예측 시가']]
y2_future_predict_A005935=predict_A005935.loc[3200:4000,['예측 시가']]
y2_future_predict_A005940=predict_A005940.loc[3170:3963,['예측 시가']]
y2_future_predict_A006280=predict_A006280.loc[3200:4000,['예측 시가']]
y2_future_predict_A006360=predict_A006360.loc[3170:3963,['예측 시가']]
y2_future_predict_A006400=predict_A006400.loc[3200:4000,['예측 시가']]
y2_future_predict_A006800=predict_A006800.loc[3200:4000,['예측 시가']]
y2_future_predict_A007070=predict_A007070.loc[3200:4000,['예측 시가']]
y2_future_predict_A008560=predict_A008560.loc[3200:4000,['예측 시가']]
y2_future_predict_A008770=predict_A008770.loc[3200:4000,['예측 시가']]
y2_future_predict_A008930=predict_A008930.loc[3200:4000,['예측 시가']]
y2_future_predict_A009150=predict_A009150.loc[3200:4000,['예측 시가']]
y2_future_predict_A009540=predict_A009540.loc[3200:4000,['예측 시가']]
y2_future_predict_A009830=predict_A009830.loc[3200:4000,['예측 시가']]
y2_future_predict_A010130=predict_A010130.loc[3170:3963,['예측 시가']]
y2_future_predict_A010140=predict_A010140.loc[3200:4000,['예측 시가']]
y2_future_predict_A010950=predict_A010950.loc[3200:4000,['예측 시가']]
y2_future_predict_A011070=predict_A011070.loc[3170:3963,['예측 시가']]
y2_future_predict_A011170=predict_A011170.loc[3200:4000,['예측 시가']]
y2_future_predict_A011200=predict_A011200.loc[3170:3963,['예측 시가']]
y2_future_predict_A011780=predict_A011780.loc[3200:4000,['예측 시가']]
y2_future_predict_A011790=predict_A011790.loc[3170:3963,['예측 시가']]
y2_future_predict_A012330=predict_A012330.loc[3170:3963,['예측 시가']]
y2_future_predict_A012510=predict_A012510.loc[3170:3963,['예측 시가']]
y2_future_predict_A012750=predict_A012750.loc[3200:4000,['예측 시가']]
y2_future_predict_A015760=predict_A015760.loc[3170:3963,['예측 시가']]
y2_future_predict_A016360=predict_A016360.loc[3200:4000,['예측 시가']]
y2_future_predict_A017670=predict_A017670.loc[3200:4000,['예측 시가']]
y2_future_predict_A018260=predict_A018260.loc[3170:3963,['예측 시가']]
y2_future_predict_A018880=predict_A018880.loc[3200:4000,['예측 시가']]
y2_future_predict_A021240=predict_A021240.loc[3170:3963,['예측 시가']]
y2_future_predict_A023530=predict_A023530.loc[3170:3963,['예측 시가']]
y2_future_predict_A024110=predict_A024110.loc[3170:3963,['예측 시가']]
y2_future_predict_A026960=predict_A026960.loc[3200:4000,['예측 시가']]
y2_future_predict_A028260=predict_A028260.loc[3200:4000,['예측 시가']]
y2_future_predict_A028670=predict_A028670.loc[3170:3963,['예측 시가']]
y2_future_predict_A029780=predict_A029780.loc[3170:3963,['예측 시가']]
y2_future_predict_A030200=predict_A030200.loc[3170:3963,['예측 시가']]
y2_future_predict_A032640=predict_A032640.loc[3200:4000,['예측 시가']]
y2_future_predict_A032830=predict_A032830.loc[3200:4000,['예측 시가']]
y2_future_predict_A033780=predict_A033780.loc[3170:3963,['예측 시가']]
y2_future_predict_A034020=predict_A034020.loc[3170:3963,['예측 시가']]
y2_future_predict_A034220=predict_A034220.loc[3200:4000,['예측 시가']]
y2_future_predict_A034730=predict_A034730.loc[3170:3963,['예측 시가']]
y2_future_predict_A035250=predict_A035250.loc[3200:4000,['예측 시가']]
y2_future_predict_A035420=predict_A035420.loc[3170:3963,['예측 시가']]
y2_future_predict_A035720=predict_A035720.loc[3170:3963,['예측 시가']]
y2_future_predict_A036460=predict_A036460.loc[3170:3963,['예측 시가']]
y2_future_predict_A036570=predict_A036570.loc[3200:4000,['예측 시가']]
y2_future_predict_A039490=predict_A039490.loc[3200:4000,['예측 시가']]
y2_future_predict_A047810=predict_A047810.loc[3200:4000,['예측 시가']]
y2_future_predict_A051900=predict_A051900.loc[3170:3963,['예측 시가']]
y2_future_predict_A051910=predict_A051910.loc[3170:3963,['예측 시가']]
y2_future_predict_A055550=predict_A055550.loc[3170:3963,['예측 시가']]
y2_future_predict_A066570=predict_A066570.loc[3170:3963,['예측 시가']]
y2_future_predict_A068270=predict_A068270.loc[3200:4000,['예측 시가']]
y2_future_predict_A071050=predict_A071050.loc[3200:4000,['예측 시가']]
y2_future_predict_A078930=predict_A078930.loc[3170:3963,['예측 시가']]
y2_future_predict_A086280=predict_A086280.loc[3170:3963,['예측 시가']]
y2_future_predict_A086790=predict_A086790.loc[3170:3963,['예측 시가']]
y2_future_predict_A090430=predict_A090430.loc[3200:4000,['예측 시가']]
y2_future_predict_A096770=predict_A096770.loc[3200:4000,['예측 시가']]
y2_future_predict_A097950=predict_A097950.loc[3200:4000,['예측 시가']]
y2_future_predict_A105560=predict_A105560.loc[3170:3963,['예측 시가']]
y2_future_predict_A128940=predict_A128940.loc[3200:4000,['예측 시가']]
y2_future_predict_A139480=predict_A139480.loc[3200:4000,['예측 시가']]
y2_future_predict_A161390=predict_A161390.loc[3200:4000,['예측 시가']]
y2_future_predict_A180640=predict_A180640.loc[3170:3963,['예측 시가']]
y2_future_predict_A204320=predict_A204320.loc[3170:3963,['예측 시가']]

# %%
y2_past_predict_A000100=predict_A000100.loc[0:3963,['실제 시가']]
y2_past_predict_A000120=predict_A000120.loc[0:4000,['실제 시가']]
y2_past_predict_A000270=predict_A000270.loc[0:3963,['실제 시가']]
y2_past_predict_A000660=predict_A000660.loc[0:4000,['실제 시가']]
y2_past_predict_A000720=predict_A000720.loc[0:3963,['실제 시가']]
y2_past_predict_A000810=predict_A000810.loc[0:3963,['실제 시가']]
y2_past_predict_A002790=predict_A002790.loc[0:3963,['실제 시가']]
y2_past_predict_A003410=predict_A003410.loc[0:4000,['실제 시가']]
y2_past_predict_A003490=predict_A003490.loc[0:3963,['실제 시가']]
y2_past_predict_A003550=predict_A003550.loc[0:4000,['실제 시가']]
y2_past_predict_A003670=predict_A003670.loc[0:3963,['실제 시가']]
y2_past_predict_A004020=predict_A004020.loc[0:3963,['실제 시가']]
y2_past_predict_A004990=predict_A004990.loc[0:3963,['실제 시가']]
y2_past_predict_A005380=predict_A005380.loc[0:4000,['실제 시가']]
y2_past_predict_A005387=predict_A005387.loc[0:3963,['실제 시가']]
y2_past_predict_A005490=predict_A005490.loc[0:3963,['실제 시가']]
y2_past_predict_A005830=predict_A005830.loc[0:4000,['실제 시가']]
y2_past_predict_A005930=predict_A005930.loc[0:4000,['실제 시가']]
y2_past_predict_A005935=predict_A005935.loc[0:4000,['실제 시가']]
y2_past_predict_A005940=predict_A005940.loc[0:3963,['실제 시가']]
y2_past_predict_A006280=predict_A006280.loc[0:4000,['실제 시가']]
y2_past_predict_A006360=predict_A006360.loc[0:3963,['실제 시가']]
y2_past_predict_A006400=predict_A006400.loc[0:4000,['실제 시가']]
y2_past_predict_A006800=predict_A006800.loc[0:4000,['실제 시가']]
y2_past_predict_A007070=predict_A007070.loc[0:4000,['실제 시가']]
y2_past_predict_A008560=predict_A008560.loc[0:4000,['실제 시가']]
y2_past_predict_A008770=predict_A008770.loc[0:4000,['실제 시가']]
y2_past_predict_A008930=predict_A008930.loc[0:4000,['실제 시가']]
y2_past_predict_A009150=predict_A009150.loc[0:4000,['실제 시가']]
y2_past_predict_A009540=predict_A009540.loc[0:4000,['실제 시가']]
y2_past_predict_A009830=predict_A009830.loc[0:4000,['실제 시가']]
y2_past_predict_A010130=predict_A010130.loc[0:3963,['실제 시가']]
y2_past_predict_A010140=predict_A010140.loc[0:4000,['실제 시가']]
y2_past_predict_A010950=predict_A010950.loc[0:4000,['실제 시가']]
y2_past_predict_A011070=predict_A011070.loc[0:3963,['실제 시가']]
y2_past_predict_A011170=predict_A011170.loc[0:4000,['실제 시가']]
y2_past_predict_A011200=predict_A011200.loc[0:3963,['실제 시가']]
y2_past_predict_A011780=predict_A011780.loc[0:4000,['실제 시가']]
y2_past_predict_A011790=predict_A011790.loc[0:3963,['실제 시가']]
y2_past_predict_A012330=predict_A012330.loc[0:3963,['실제 시가']]
y2_past_predict_A012510=predict_A012510.loc[0:3963,['실제 시가']]
y2_past_predict_A012750=predict_A012750.loc[0:4000,['실제 시가']]
y2_past_predict_A015760=predict_A015760.loc[0:3963,['실제 시가']]
y2_past_predict_A016360=predict_A016360.loc[0:4000,['실제 시가']]
y2_past_predict_A017670=predict_A017670.loc[0:4000,['실제 시가']]
y2_past_predict_A018260=predict_A018260.loc[0:3963,['실제 시가']]
y2_past_predict_A018880=predict_A018880.loc[0:4000,['실제 시가']]
y2_past_predict_A021240=predict_A021240.loc[0:3963,['실제 시가']]
y2_past_predict_A023530=predict_A023530.loc[0:3963,['실제 시가']]
y2_past_predict_A024110=predict_A024110.loc[0:3963,['실제 시가']]
y2_past_predict_A026960=predict_A026960.loc[0:4000,['실제 시가']]
y2_past_predict_A028260=predict_A028260.loc[0:4000,['실제 시가']]
y2_past_predict_A028670=predict_A028670.loc[0:3963,['실제 시가']]
y2_past_predict_A029780=predict_A029780.loc[0:3963,['실제 시가']]
y2_past_predict_A030200=predict_A030200.loc[0:3963,['실제 시가']]
y2_past_predict_A032640=predict_A032640.loc[0:4000,['실제 시가']]
y2_past_predict_A032830=predict_A032830.loc[0:4000,['실제 시가']]
y2_past_predict_A033780=predict_A033780.loc[0:3963,['실제 시가']]
y2_past_predict_A034020=predict_A034020.loc[0:3963,['실제 시가']]
y2_past_predict_A034220=predict_A034220.loc[0:4000,['실제 시가']]
y2_past_predict_A034730=predict_A034730.loc[0:3963,['실제 시가']]
y2_past_predict_A035250=predict_A035250.loc[0:4000,['실제 시가']]
y2_past_predict_A035420=predict_A035420.loc[0:3963,['실제 시가']]
y2_past_predict_A035720=predict_A035720.loc[0:3963,['실제 시가']]
y2_past_predict_A036460=predict_A036460.loc[0:3963,['실제 시가']]
y2_past_predict_A036570=predict_A036570.loc[0:4000,['실제 시가']]
y2_past_predict_A039490=predict_A039490.loc[0:4000,['실제 시가']]
y2_past_predict_A047810=predict_A047810.loc[0:4000,['실제 시가']]
y2_past_predict_A051900=predict_A051900.loc[0:3963,['실제 시가']]
y2_past_predict_A051910=predict_A051910.loc[0:3963,['실제 시가']]
y2_past_predict_A055550=predict_A055550.loc[0:3963,['실제 시가']]
y2_past_predict_A066570=predict_A066570.loc[0:3963,['실제 시가']]
y2_past_predict_A068270=predict_A068270.loc[0:4000,['실제 시가']]
y2_past_predict_A071050=predict_A071050.loc[0:4000,['실제 시가']]
y2_past_predict_A078930=predict_A078930.loc[0:3963,['실제 시가']]
y2_past_predict_A086280=predict_A086280.loc[0:3963,['실제 시가']]
y2_past_predict_A086790=predict_A086790.loc[0:3963,['실제 시가']]
y2_past_predict_A090430=predict_A090430.loc[0:4000,['실제 시가']]
y2_past_predict_A096770=predict_A096770.loc[0:4000,['실제 시가']]
y2_past_predict_A097950=predict_A097950.loc[0:4000,['실제 시가']]
y2_past_predict_A105560=predict_A105560.loc[0:3963,['실제 시가']]
y2_past_predict_A128940=predict_A128940.loc[0:4000,['실제 시가']]
y2_past_predict_A139480=predict_A139480.loc[0:4000,['실제 시가']]
y2_past_predict_A161390=predict_A161390.loc[0:4000,['실제 시가']]
y2_past_predict_A180640=predict_A180640.loc[0:3963,['실제 시가']]
y2_past_predict_A204320=predict_A204320.loc[0:3963,['실제 시가']]

# %%
x2_future_predict_A000100=predict_A000100.loc[3170:3963,['Date']]
x2_future_predict_A000120=predict_A000120.loc[3200:4000,['Date']]
x2_future_predict_A000270=predict_A000270.loc[3170:3963,['Date']]
x2_future_predict_A000660=predict_A000660.loc[3200:4000,['Date']]
x2_future_predict_A000720=predict_A000720.loc[3170:3963,['Date']]
x2_future_predict_A000810=predict_A000810.loc[3170:3963,['Date']]
x2_future_predict_A002790=predict_A002790.loc[3170:3963,['Date']]
x2_future_predict_A003410=predict_A003410.loc[3200:4000,['Date']]
x2_future_predict_A003490=predict_A003490.loc[3170:3963,['Date']]
x2_future_predict_A003550=predict_A003550.loc[3200:4000,['Date']]
x2_future_predict_A003670=predict_A003670.loc[3170:3963,['Date']]
x2_future_predict_A004020=predict_A004020.loc[3170:3963,['Date']]
x2_future_predict_A004990=predict_A004990.loc[3170:3963,['Date']]
x2_future_predict_A005380=predict_A005380.loc[3200:4000,['Date']]
x2_future_predict_A005387=predict_A005387.loc[3170:3963,['Date']]
x2_future_predict_A005490=predict_A005490.loc[3170:3963,['Date']]
x2_future_predict_A005830=predict_A005830.loc[3200:4000,['Date']]
x2_future_predict_A005930=predict_A005930.loc[3200:4000,['Date']]
x2_future_predict_A005935=predict_A005935.loc[3200:4000,['Date']]
x2_future_predict_A005940=predict_A005940.loc[3170:3963,['Date']]
x2_future_predict_A006280=predict_A006280.loc[3200:4000,['Date']]
x2_future_predict_A006360=predict_A006360.loc[3170:3963,['Date']]
x2_future_predict_A006400=predict_A006400.loc[3200:4000,['Date']]
x2_future_predict_A006800=predict_A006800.loc[3200:4000,['Date']]
x2_future_predict_A007070=predict_A007070.loc[3200:4000,['Date']]
x2_future_predict_A008560=predict_A008560.loc[3200:4000,['Date']]
x2_future_predict_A008770=predict_A008770.loc[3200:4000,['Date']]
x2_future_predict_A008930=predict_A008930.loc[3200:4000,['Date']]
x2_future_predict_A009150=predict_A009150.loc[3200:4000,['Date']]
x2_future_predict_A009540=predict_A009540.loc[3200:4000,['Date']]
x2_future_predict_A009830=predict_A009830.loc[3200:4000,['Date']]
x2_future_predict_A010130=predict_A010130.loc[3170:3963,['Date']]
x2_future_predict_A010140=predict_A010140.loc[3200:4000,['Date']]
x2_future_predict_A010950=predict_A010950.loc[3200:4000,['Date']]
x2_future_predict_A011070=predict_A011070.loc[3170:3963,['Date']]
x2_future_predict_A011170=predict_A011170.loc[3200:4000,['Date']]
x2_future_predict_A011200=predict_A011200.loc[3170:3963,['Date']]
x2_future_predict_A011780=predict_A011780.loc[3200:4000,['Date']]
x2_future_predict_A011790=predict_A011790.loc[3170:3963,['Date']]
x2_future_predict_A012330=predict_A012330.loc[3170:3963,['Date']]
x2_future_predict_A012510=predict_A012510.loc[3170:3963,['Date']]
x2_future_predict_A012750=predict_A012750.loc[3200:4000,['Date']]
x2_future_predict_A015760=predict_A015760.loc[3170:3963,['Date']]
x2_future_predict_A016360=predict_A016360.loc[3200:4000,['Date']]
x2_future_predict_A017670=predict_A017670.loc[3200:4000,['Date']]
x2_future_predict_A018260=predict_A018260.loc[3170:3963,['Date']]
x2_future_predict_A018880=predict_A018880.loc[3200:4000,['Date']]
x2_future_predict_A021240=predict_A021240.loc[3170:3963,['Date']]
x2_future_predict_A023530=predict_A023530.loc[3170:3963,['Date']]
x2_future_predict_A024110=predict_A024110.loc[3170:3963,['Date']]
x2_future_predict_A026960=predict_A026960.loc[3200:4000,['Date']]
x2_future_predict_A028260=predict_A028260.loc[3200:4000,['Date']]
x2_future_predict_A028670=predict_A028670.loc[3170:3963,['Date']]
x2_future_predict_A029780=predict_A029780.loc[3170:3963,['Date']]
x2_future_predict_A030200=predict_A030200.loc[3170:3963,['Date']]
x2_future_predict_A032640=predict_A032640.loc[3200:4000,['Date']]
x2_future_predict_A032830=predict_A032830.loc[3200:4000,['Date']]
x2_future_predict_A033780=predict_A033780.loc[3170:3963,['Date']]
x2_future_predict_A034020=predict_A034020.loc[3170:3963,['Date']]
x2_future_predict_A034220=predict_A034220.loc[3200:4000,['Date']]
x2_future_predict_A034730=predict_A034730.loc[3170:3963,['Date']]
x2_future_predict_A035250=predict_A035250.loc[3200:4000,['Date']]
x2_future_predict_A035420=predict_A035420.loc[3170:3963,['Date']]
x2_future_predict_A035720=predict_A035720.loc[3170:3963,['Date']]
x2_future_predict_A036460=predict_A036460.loc[3170:3963,['Date']]
x2_future_predict_A036570=predict_A036570.loc[3200:4000,['Date']]
x2_future_predict_A039490=predict_A039490.loc[3200:4000,['Date']]
x2_future_predict_A047810=predict_A047810.loc[3200:4000,['Date']]
x2_future_predict_A051900=predict_A051900.loc[3170:3963,['Date']]
x2_future_predict_A051910=predict_A051910.loc[3170:3963,['Date']]
x2_future_predict_A055550=predict_A055550.loc[3170:3963,['Date']]
x2_future_predict_A066570=predict_A066570.loc[3170:3963,['Date']]
x2_future_predict_A068270=predict_A068270.loc[3200:4000,['Date']]
x2_future_predict_A071050=predict_A071050.loc[3200:4000,['Date']]
x2_future_predict_A078930=predict_A078930.loc[3170:3963,['Date']]
x2_future_predict_A086280=predict_A086280.loc[3170:3963,['Date']]
x2_future_predict_A086790=predict_A086790.loc[3170:3963,['Date']]
x2_future_predict_A090430=predict_A090430.loc[3200:4000,['Date']]
x2_future_predict_A096770=predict_A096770.loc[3200:4000,['Date']]
x2_future_predict_A097950=predict_A097950.loc[3200:4000,['Date']]
x2_future_predict_A105560=predict_A105560.loc[3170:3963,['Date']]
x2_future_predict_A128940=predict_A128940.loc[3200:4000,['Date']]
x2_future_predict_A139480=predict_A139480.loc[3200:4000,['Date']]
x2_future_predict_A161390=predict_A161390.loc[3200:4000,['Date']]
x2_future_predict_A180640=predict_A180640.loc[3170:3963,['Date']]
x2_future_predict_A204320=predict_A204320.loc[3170:3963,['Date']]

# %%
x2_past_predict_A000100=predict_A000100.loc[0:3963,['Date']]
x2_past_predict_A000120=predict_A000120.loc[0:4000,['Date']]
x2_past_predict_A000270=predict_A000270.loc[0:3963,['Date']]
x2_past_predict_A000660=predict_A000660.loc[0:4000,['Date']]
x2_past_predict_A000720=predict_A000720.loc[0:3963,['Date']]
x2_past_predict_A000810=predict_A000810.loc[0:3963,['Date']]
x2_past_predict_A002790=predict_A002790.loc[0:3963,['Date']]
x2_past_predict_A003410=predict_A003410.loc[0:4000,['Date']]
x2_past_predict_A003490=predict_A003490.loc[0:3963,['Date']]
x2_past_predict_A003550=predict_A003550.loc[0:4000,['Date']]
x2_past_predict_A003670=predict_A003670.loc[0:3963,['Date']]
x2_past_predict_A004020=predict_A004020.loc[0:3963,['Date']]
x2_past_predict_A004990=predict_A004990.loc[0:3963,['Date']]
x2_past_predict_A005380=predict_A005380.loc[0:4000,['Date']]
x2_past_predict_A005387=predict_A005387.loc[0:3963,['Date']]
x2_past_predict_A005490=predict_A005490.loc[0:3963,['Date']]
x2_past_predict_A005830=predict_A005830.loc[0:4000,['Date']]
x2_past_predict_A005930=predict_A005930.loc[0:4000,['Date']]
x2_past_predict_A005935=predict_A005935.loc[0:4000,['Date']]
x2_past_predict_A005940=predict_A005940.loc[0:3963,['Date']]
x2_past_predict_A006280=predict_A006280.loc[0:4000,['Date']]
x2_past_predict_A006360=predict_A006360.loc[0:3963,['Date']]
x2_past_predict_A006400=predict_A006400.loc[0:4000,['Date']]
x2_past_predict_A006800=predict_A006800.loc[0:4000,['Date']]
x2_past_predict_A007070=predict_A007070.loc[0:4000,['Date']]
x2_past_predict_A008560=predict_A008560.loc[0:4000,['Date']]
x2_past_predict_A008770=predict_A008770.loc[0:4000,['Date']]
x2_past_predict_A008930=predict_A008930.loc[0:4000,['Date']]
x2_past_predict_A009150=predict_A009150.loc[0:4000,['Date']]
x2_past_predict_A009540=predict_A009540.loc[0:4000,['Date']]
x2_past_predict_A009830=predict_A009830.loc[0:4000,['Date']]
x2_past_predict_A010130=predict_A010130.loc[0:3963,['Date']]
x2_past_predict_A010140=predict_A010140.loc[0:4000,['Date']]
x2_past_predict_A010950=predict_A010950.loc[0:4000,['Date']]
x2_past_predict_A011070=predict_A011070.loc[0:3963,['Date']]
x2_past_predict_A011170=predict_A011170.loc[0:4000,['Date']]
x2_past_predict_A011200=predict_A011200.loc[0:3963,['Date']]
x2_past_predict_A011780=predict_A011780.loc[0:4000,['Date']]
x2_past_predict_A011790=predict_A011790.loc[0:3963,['Date']]
x2_past_predict_A012330=predict_A012330.loc[0:3963,['Date']]
x2_past_predict_A012510=predict_A012510.loc[0:3963,['Date']]
x2_past_predict_A012750=predict_A012750.loc[0:4000,['Date']]
x2_past_predict_A015760=predict_A015760.loc[0:3963,['Date']]
x2_past_predict_A016360=predict_A016360.loc[0:4000,['Date']]
x2_past_predict_A017670=predict_A017670.loc[0:4000,['Date']]
x2_past_predict_A018260=predict_A018260.loc[0:3963,['Date']]
x2_past_predict_A018880=predict_A018880.loc[0:4000,['Date']]
x2_past_predict_A021240=predict_A021240.loc[0:3963,['Date']]
x2_past_predict_A023530=predict_A023530.loc[0:3963,['Date']]
x2_past_predict_A024110=predict_A024110.loc[0:3963,['Date']]
x2_past_predict_A026960=predict_A026960.loc[0:4000,['Date']]
x2_past_predict_A028260=predict_A028260.loc[0:4000,['Date']]
x2_past_predict_A028670=predict_A028670.loc[0:3963,['Date']]
x2_past_predict_A029780=predict_A029780.loc[0:3963,['Date']]
x2_past_predict_A030200=predict_A030200.loc[0:3963,['Date']]
x2_past_predict_A032640=predict_A032640.loc[0:4000,['Date']]
x2_past_predict_A032830=predict_A032830.loc[0:4000,['Date']]
x2_past_predict_A033780=predict_A033780.loc[0:3963,['Date']]
x2_past_predict_A034020=predict_A034020.loc[0:3963,['Date']]
x2_past_predict_A034220=predict_A034220.loc[0:4000,['Date']]
x2_past_predict_A034730=predict_A034730.loc[0:3963,['Date']]
x2_past_predict_A035250=predict_A035250.loc[0:4000,['Date']]
x2_past_predict_A035420=predict_A035420.loc[0:3963,['Date']]
x2_past_predict_A035720=predict_A035720.loc[0:3963,['Date']]
x2_past_predict_A036460=predict_A036460.loc[0:3963,['Date']]
x2_past_predict_A036570=predict_A036570.loc[0:4000,['Date']]
x2_past_predict_A039490=predict_A039490.loc[0:4000,['Date']]
x2_past_predict_A047810=predict_A047810.loc[0:4000,['Date']]
x2_past_predict_A051900=predict_A051900.loc[0:3963,['Date']]
x2_past_predict_A051910=predict_A051910.loc[0:3963,['Date']]
x2_past_predict_A055550=predict_A055550.loc[0:3963,['Date']]
x2_past_predict_A066570=predict_A066570.loc[0:3963,['Date']]
x2_past_predict_A068270=predict_A068270.loc[0:4000,['Date']]
x2_past_predict_A071050=predict_A071050.loc[0:4000,['Date']]
x2_past_predict_A078930=predict_A078930.loc[0:3963,['Date']]
x2_past_predict_A086280=predict_A086280.loc[0:3963,['Date']]
x2_past_predict_A086790=predict_A086790.loc[0:3963,['Date']]
x2_past_predict_A090430=predict_A090430.loc[0:4000,['Date']]
x2_past_predict_A096770=predict_A096770.loc[0:4000,['Date']]
x2_past_predict_A097950=predict_A097950.loc[0:4000,['Date']]
x2_past_predict_A105560=predict_A105560.loc[0:3963,['Date']]
x2_past_predict_A128940=predict_A128940.loc[0:4000,['Date']]
x2_past_predict_A139480=predict_A139480.loc[0:4000,['Date']]
x2_past_predict_A161390=predict_A161390.loc[0:4000,['Date']]
x2_past_predict_A180640=predict_A180640.loc[0:3963,['Date']]
x2_past_predict_A204320=predict_A204320.loc[0:3963,['Date']]

# %%
def stock_plot2(stock):
    if stock=='유한양행': 
        p=plt.plot(x2_past_predict_A000100,y2_past_predict_A000100,label='유한양행_Open')
        p=plt.plot(x2_future_predict_A000100,y2_future_predict_A000100,label='유한양행_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='CJ대한통운': 
        p=plt.plot(x2_past_predict_A000120,y2_past_predict_A000120,label='CJ대한통운_Open')
        p=plt.plot(x2_future_predict_A000120,y2_future_predict_A000120,label='CJ대한통운_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='기아차': 
        p=plt.plot(x2_past_predict_A000270,y2_past_predict_A000270,label='기아차_Open')
        p=plt.plot(x2_future_predict_A000270,y2_future_predict_A000270,label='기아차_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK하이닉스': 
        p=plt.plot(x2_past_predict_A000660,y2_past_predict_A000660,label='SK하이닉스_Open')
        p=plt.plot(x2_future_predict_A000660,y2_future_predict_A000660,label='SK하이닉스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대건설': 
        p=plt.plot(x2_past_predict_A000720,y2_past_predict_A000720,label='현대건설_Open')
        p=plt.plot(x2_future_predict_A000720,y2_future_predict_A000720,label='현대건설_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성화재': 
        p=plt.plot(x2_past_predict_A000810,y2_past_predict_A000810,label='삼성화재_Open')
        p=plt.plot(x2_future_predict_A000810,y2_future_predict_A000810,label='삼성화재_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='아모레G': 
        p=plt.plot(x2_past_predict_A002790,y2_past_predict_A002790,label='아모레G_Open')
        p=plt.plot(x2_future_predict_A002790,y2_future_predict_A002790,label='아모레G_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='쌍용양회': 
        p=plt.plot(x2_past_predict_A003410,y2_past_predict_A003410,label='쌍용양회_Open')
        p=plt.plot(x2_future_predict_A003410,y2_future_predict_A003410,label='쌍용양회_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='대한항공': 
        p=plt.plot(x2_past_predict_A003490,y2_past_predict_A003490,label='대한항공_Open')
        p=plt.plot(x2_future_predict_A003490,y2_future_predict_A003490,label='대한항공_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG': 
        p=plt.plot(x2_past_predict_A003550,y2_past_predict_A003550,label='LG_Open')
        p=plt.plot(x2_future_predict_A003550,y2_future_predict_A003550,label='LG_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='포스코케미칼': 
        p=plt.plot(x2_past_predict_A003670,y2_past_predict_A003670,label='포스코케미칼_Open')
        p=plt.plot(x2_future_predict_A003670,y2_future_predict_A003670,label='포스코케미칼_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대제철': 
        p=plt.plot(x2_past_predict_A004020,y2_past_predict_A004020,label='현대제철_Open')
        p=plt.plot(x2_future_predict_A004020,y2_future_predict_A004020,label='현대제철_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='롯데지주': 
        p=plt.plot(x2_past_predict_A004990,y2_past_predict_A004990,label='롯데지주_Open')
        p=plt.plot(x2_future_predict_A004990,y2_future_predict_A004990,label='롯데지주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대차': 
        p=plt.plot(x2_past_predict_A005380,y2_past_predict_A005380,label='현대차_Open')
        p=plt.plot(x2_future_predict_A005380,y2_future_predict_A005380,label='현대차_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대차2우B': 
        p=plt.plot(x2_past_predict_A005387,y2_past_predict_A005387,label='현대차2우B_Open')
        p=plt.plot(x2_future_predict_A005387,y2_future_predict_A005387,label='현대차2우B_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='POSCO': 
        p=plt.plot(x2_past_predict_A005490,y2_past_predict_A005490,label='POSCO_Open')
        p=plt.plot(x2_future_predict_A005490,y2_future_predict_A005490,label='POSCO_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='DB손해보험': 
        p=plt.plot(x2_past_predict_A005830,y2_past_predict_A005830,label='DB손해보험_Open')
        p=plt.plot(x2_future_predict_A005830,y2_future_predict_A005830,label='DB손해보험_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성전자': 
        p=plt.plot(x2_past_predict_A005930,y2_past_predict_A005930,label='삼성전자_Open')
        p=plt.plot(x2_future_predict_A005930,y2_future_predict_A005930,label='삼성전자_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성전자우': 
        p=plt.plot(x2_past_predict_A005935,y2_past_predict_A005935,label='삼성전자우_Open')
        p=plt.plot(x2_future_predict_A005935,y2_future_predict_A005935,label='삼성전자우_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='NH투자증권': 
        p=plt.plot(x2_past_predict_A005940,y2_past_predict_A005940,label='NH투자증권_Open')
        p=plt.plot(x2_future_predict_A005940,y2_future_predict_A005940,label='NH투자증권_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='녹십자': 
        p=plt.plot(x2_past_predict_A006280,y2_past_predict_A006280,label='녹십자_Open')
        p=plt.plot(x2_future_predict_A006280,y2_future_predict_A006280,label='녹십자_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='GS건설': 
        p=plt.plot(x2_past_predict_A006360,y2_past_predict_A006360,label='GS건설_Open')
        p=plt.plot(x2_future_predict_A006360,y2_future_predict_A006360,label='GS건설_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성SDI': 
        p=plt.plot(x2_past_predict_A006400,y2_past_predict_A006400,label='삼성SDI_Open')
        p=plt.plot(x2_future_predict_A006400,y2_future_predict_A006400,label='삼성SDI_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='미래에셋대우': 
        p=plt.plot(x2_past_predict_A006800,y2_past_predict_A006800,label='미래에셋대우_Open')
        p=plt.plot(x2_future_predict_A006800,y2_future_predict_A006800,label='미래에셋대우_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='GS리테일': 
        p=plt.plot(x2_past_predict_A007070,y2_past_predict_A007070,label='GS리테일_Open')
        p=plt.plot(x2_future_predict_A007070,y2_future_predict_A007070,label='GS리테일_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='메리츠증권': 
        p=plt.plot(x2_past_predict_A008560,y2_past_predict_A008560,label='메리츠증권_Open')
        p=plt.plot(x2_future_predict_A008560,y2_future_predict_A008560,label='메리츠증권_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='호텔신라': 
        p=plt.plot(x2_past_predict_A008770,y2_past_predict_A008770,label='호텔신라_Open')
        p=plt.plot(x2_future_predict_A008770,y2_future_predict_A008770,label='호텔신라_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한미사이언스': 
        p=plt.plot(x2_past_predict_A008930,y2_past_predict_A008930,label='한미사이언스_Open')
        p=plt.plot(x2_future_predict_A008930,y2_future_predict_A008930,label='한미사이언스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성전기': 
        p=plt.plot(x2_past_predict_A009150,y2_past_predict_A009150,label='삼성전기_Open')
        p=plt.plot(x2_future_predict_A009150,y2_future_predict_A009150,label='삼성전기_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국조선해양': 
        p=plt.plot(x2_past_predict_A009540,y2_past_predict_A009540,label='한국조선해양_Open')
        p=plt.plot(x2_future_predict_A009540,y2_future_predict_A009540,label='한국조선해양_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한화솔루션': 
        p=plt.plot(x2_past_predict_A009830,y2_past_predict_A009830,label='한화솔루션_Open')
        p=plt.plot(x2_future_predict_A009830,y2_future_predict_A009830,label='한화솔루션_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='고려아연': 
        p=plt.plot(x2_past_predict_A010130,y2_past_predict_A010130,label='고려아연_Open')
        p=plt.plot(x2_future_predict_A010130,y2_future_predict_A010130,label='고려아연_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성중공업': 
        p=plt.plot(x2_past_predict_A010140,y2_past_predict_A010140,label='삼성중공업_Open')
        p=plt.plot(x2_future_predict_A010140,y2_future_predict_A010140,label='삼성중공업_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='S-Oil': 
        p=plt.plot(x2_past_predict_A010950,y2_past_predict_A010950,label='S-Oil_Open')
        p=plt.plot(x2_future_predict_A010950,y2_future_predict_A010950,label='S-Oil_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG이노텍': 
        p=plt.plot(x2_past_predict_A011070,y2_past_predict_A011070,label='LG이노텍_Open')
        p=plt.plot(x2_future_predict_A011070,y2_future_predict_A011070,label='LG이노텍_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='롯데케미칼': 
        p=plt.plot(x2_past_predict_A011170,y2_past_predict_A011170,label='롯데케미칼_Open')
        p=plt.plot(x2_future_predict_A011170,y2_future_predict_A011170,label='롯데케미칼_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='HMM': 
        p=plt.plot(x2_past_predict_A011200,y2_past_predict_A011200,label='HMM_Open')
        p=plt.plot(x2_future_predict_A011200,y2_future_predict_A011200,label='HMM_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='금호석유': 
        p=plt.plot(x2_past_predict_A011780,y2_past_predict_A011780,label='금호석유_Open')
        p=plt.plot(x2_future_predict_A011780,y2_future_predict_A011780,label='금호석유_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SKC': 
        p=plt.plot(x2_past_predict_A011790,y2_past_predict_A011790,label='SKC_Open')
        p=plt.plot(x2_future_predict_A011790,y2_future_predict_A011790,label='SKC_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대모비스': 
        p=plt.plot(x2_past_predict_A012330,y2_past_predict_A012330,label='현대모비스_Open')
        p=plt.plot(x2_future_predict_A012330,y2_future_predict_A012330,label='현대모비스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='더존비즈온': 
        p=plt.plot(x2_past_predict_A012510,y2_past_predict_A012510,label='더존비즈온_Open')
        p=plt.plot(x2_future_predict_A012510,y2_future_predict_A012510,label='더존비즈온_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='에스원': 
        p=plt.plot(x2_past_predict_A012750,y2_past_predict_A012750,label='에스원_Open')
        p=plt.plot(x2_future_predict_A012750,y2_future_predict_A012750,label='에스원_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국전력': 
        p=plt.plot(x2_past_predict_A015760,y2_past_predict_A015760,label='한국전력_Open')
        p=plt.plot(x2_future_predict_A015760,y2_future_predict_A015760,label='한국전력_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성증권': 
        p=plt.plot(x2_past_predict_A016360,y2_past_predict_A016360,label='삼성증권_Open')
        p=plt.plot(x2_future_predict_A016360,y2_future_predict_A016360,label='삼성증권_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK텔레콤': 
        p=plt.plot(x2_past_predict_A017670,y2_past_predict_A017670,label='SK텔레콤_Open')
        p=plt.plot(x2_future_predict_A017670,y2_future_predict_A017670,label='SK텔레콤_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성에스디에스': 
        p=plt.plot(x2_past_predict_A018260,y2_past_predict_A018260,label='삼성에스디에스_Open')
        p=plt.plot(x2_future_predict_A018260,y2_future_predict_A018260,label='삼성에스디에스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한온시스템': 
        p=plt.plot(x2_past_predict_A018880,y2_past_predict_A018880,label='한온시스템_Open')
        p=plt.plot(x2_future_predict_A018880,y2_future_predict_A018880,label='한온시스템_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='코웨이': 
        p=plt.plot(x2_past_predict_A021240,y2_past_predict_A021240,label='코웨이_Open')
        p=plt.plot(x2_future_predict_A021240,y2_future_predict_A021240,label='코웨이_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='롯데쇼핑': 
        p=plt.plot(x2_past_predict_A023530,y2_past_predict_A023530,label='롯데쇼핑_Open')
        p=plt.plot(x2_future_predict_A023530,y2_future_predict_A023530,label='롯데쇼핑_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='기업은행': 
        p=plt.plot(x2_past_predict_A024110,y2_past_predict_A024110,label='기업은행_Open')
        p=plt.plot(x2_future_predict_A024110,y2_future_predict_A024110,label='기업은행_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='동서': 
        p=plt.plot(x2_past_predict_A026960,y2_past_predict_A026960,label='동서_Open')
        p=plt.plot(x2_future_predict_A026960,y2_future_predict_A026960,label='동서_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성물산': 
        p=plt.plot(x2_past_predict_A028260,y2_past_predict_A028260,label='삼성물산_Open')
        p=plt.plot(x2_future_predict_A028260,y2_future_predict_A028260,label='삼성물산_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='팬오션': 
        p=plt.plot(x2_past_predict_A028670,y2_past_predict_A028670label='팬오션_Open')
        p=plt.plot(x2_future_predict_A028670,y2_future_predict_A028670,label='팬오션_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성카드': 
        p=plt.plot(x2_past_predict_A029780,y2_past_predict_A029780,label='삼성카드_Open')
        p=plt.plot(x2_future_predict_A029780,y2_future_predict_A029780,label='삼성카드_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='KT': 
        p=plt.plot(x2_past_predict_A030200,y2_past_predict_A030200,label='KT_Open')
        p=plt.plot(x2_future_predict_A030200,y2_future_predict_A030200label='KT_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG유플러스': 
        p=plt.plot(x2_past_predict_A032640,y2_past_predict_A032640,label='LG유플러스_Open')
        p=plt.plot(x2_future_predict_A032640,y2_future_predict_A032640,label='LG유플러스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='삼성생명': 
        p=plt.plot(x2_past_predict_A032830,y2_past_predict_A032830,label='삼성생명_Open')
        p=plt.plot(x2_future_predict_A032830,y2_future_predict_A032830,label='삼성생명_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='KT&G': 
        p=plt.plot(x2_past_predict_A033780,y2_past_predict_A033780,label='KT&G_Open')
        p=plt.plot(x2_future_predict_A033780,y2_future_predict_A033780,label='KT&G_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='두산중공업': 
        p=plt.plot(x2_past_predict_A034020,y2_past_predict_A034020,label='두산중공업_Open')
        p=plt.plot(x2_future_predict_A034020,y2_future_predict_A034020,label='두산중공업_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG디스플레이': 
        p=plt.plot(x2_past_predict_A034220,y2_past_predict_A034220,label='LG디스플레이_Open')
        p=plt.plot(x2_future_predict_A034220,y2_future_predict_A034220,label='LG디스플레이_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK': 
        p=plt.plot(x2_past_predict_A034730,y2_past_predict_A034730,label='SK_Open')
        p=plt.plot(x2_future_predict_A034730,y2_future_predict_A034730,label='SK_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='강원랜드': 
        p=plt.plot(x2_past_predict_A035250,y2_past_predict_A035250,label='강원랜드_Open')
        p=plt.plot(x2_future_predict_A035250,y2_future_predict_A035250,label='강원랜드_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='NAVER': 
        p=plt.plot(x2_past_predict_A035420,y2_past_predict_A035420,label='NAVER_Open')
        p=plt.plot(x2_future_predict_A035420,y2_future_predict_A035420,label='NAVER_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='카카오': 
        p=plt.plot(x2_past_predict_A035720,y2_past_predict_A035720,label='카카오_Open')
        p=plt.plot(x2_future_predict_A035720,y2_future_predict_A035720,label='카카오_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국가스공사': 
        p=plt.plot(x2_past_predict_A036460,y2_past_predict_A036460,label='한국가스공사_Open')
        p=plt.plot(x2_future_predict_A036460,y2_future_predict_A036460,label='한국가스공사_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='엔씨소프트': 
        p=plt.plot(x2_past_predict_A036570,y2_past_predict_A036570,label='엔씨소프트_Open')
        p=plt.plot(x2_future_predict_A036570,y2_future_predict_A036570,label='엔씨소프트_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='키움증권': 
        p=plt.plot(x2_past_predict_A039490,y2_past_predict_A039490,label='키움증권_Open')
        p=plt.plot(x2_future_predict_A039490,y2_future_predict_A039490,label='키움증권_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국항공우주': 
        p=plt.plot(x2_past_predict_A047810,y2_past_predict_A047810,label='한국항공우주_Open')
        p=plt.plot(x2_future_predict_A047810,y2_future_predict_A047810,label='한국항공우주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG생활건강': 
        p=plt.plot(x2_past_predict_A051900,y2_past_predict_A051900,label='LG생활건강_Open')
        p=plt.plot(x2_future_predict_A051900,y2_future_predict_A051900,label='LG생활건강_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG화학': 
        p=plt.plot(x2_past_predict_A051910,y2_past_predict_A051910,label='LG화학_Open')
        p=plt.plot(x2_future_predict_A051910,y2_future_predict_A051910,label='LG화학_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='신한지주': 
        p=plt.plot(x2_past_predict_A055550,y2_past_predict_A055550,label='신한지주_Open')
        p=plt.plot(x2_future_predict_A055550,y2_future_predict_A055550,label='신한지주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='LG전자': 
        p=plt.plot(x2_past_predict_A066570,y2_past_predict_A066570,label='LG전자_Open')
        p=plt.plot(x2_future_predict_A066570,y2_future_predict_A066570,label='LG전자_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='셀트리온': 
        p=plt.plot(x2_past_predict_A068270,y2_past_predict_A068270,label='셀트리온_Open')
        p=plt.plot(x2_future_predict_A068270,y2_future_predict_A068270,label='셀트리온_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국금융지주': 
        p=plt.plot(x2_past_predict_A071050,y2_past_predict_A071050,label='한국금융지주_Open')
        p=plt.plot(x2_future_predict_A071050,y2_future_predict_A071050,label='한국금융지주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='GS': 
        p=plt.plot(x2_past_predict_A078930,y2_past_predict_A078930,label='GS_Open')
        p=plt.plot(x2_future_predict_A078930,y2_future_predict_A078930,label='GS_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='현대글로비스': 
        p=plt.plot(x2_past_predict_A086280,y2_past_predict_A086280,label='현대글로비스_Open')
        p=plt.plot(x2_future_predict_A086280,y2_future_predict_A086280,label='현대글로비스_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='하나금융지주': 
        p=plt.plot(x2_past_predict_A086790,y2_past_predict_A086790,label='하나금융지주_Open')
        p=plt.plot(x2_future_predict_A086790,y2_future_predict_A086790,label='하나금융지주_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='아모레퍼시픽': 
        p=plt.plot(x2_past_predict_A090430,y2_past_predict_A0904300,label='아모레퍼시픽_Open')
        p=plt.plot(x2_future_predict_A090430,y2_future_predict_A090430,label='아모레퍼시픽_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='SK이노베이션': 
        p=plt.plot(x2_past_predict_A096770,y2_past_predict_A096770,label='SK이노베이션_Open')
        p=plt.plot(x2_future_predict_A096770,y2_future_predict_A096770,label='SK이노베이션_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='CJ제일제당': 
        p=plt.plot(x2_past_predict_A097950,y2_past_predict_A097950,label='CJ제일제당_Open')
        p=plt.plot(x2_future_predict_A097950,y2_future_predict_A097950,label='CJ제일제당_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='KB금융': 
        p=plt.plot(x2_past_predict_A105560,y2_past_predict_A105560,label='KB금융_Open')
        p=plt.plot(x2_future_predict_A105560,y2_future_predict_A105560,label='KB금융_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한미약품': 
        p=plt.plot(x2_past_predict_A128940,y2_past_predict_A128940,label='한미약품_Open')
        p=plt.plot(x2_future_predict_A128940,y2_future_predict_A128940,label='한미약품_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='이마트': 
        p=plt.plot(x2_past_predict_A139480,y2_past_predict_A139480,label='이마트_Open')
        p=plt.plot(x2_future_predict_A139480,y2_future_predict_A139480,label='이마트_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한국타이어앤테크놀로지': 
        p=plt.plot(x2_past_predict_A161390,y2_past_predict_A161390,label='한국타이어앤테크놀로지_Open')
        p=plt.plot(x2_future_predict_A161390,y2_future_predict_A1613900,label='한국타이어앤테크놀로지_Prediction',color='red')
        datacursor(p)
        plt.legend()
    elif stock=='한진칼': 
        p=plt.plot(x2_past_predict_A180640,y2_past_predict_A180640,label='한진칼_Open')
        p=plt.plot(x2_future_predict_A180640,y2_future_predict_A1806400,label='한진칼_Prediction',color='red')
        datacursor(p)
        plt.legend()
    else: 
        p=plt.plot(x2_past_predict_A204320,y2_past_predict_A204320,label='만도_Open')
        p=plt.plot(x2_future_predict_A204320,y2_future_predict_A204320,label='만도_Prediction',color='red')
        datacursor(p)
        plt.legend()

    plt.rc('axes', unicode_minus=False)
    plt.show()

# %%
widgets.interactive(stock_plot2, stock=stock)
# Out:
# interactive(children=(Dropdown(description='stock', options=('유한양행', 'CJ대한통운', '기아차', 'SK하이닉스', '현대건설', '삼성화재'…
